# %% [markdown]
# # **Homework-2**
#
# **Name:** Pavan Pandya
#
# **Email:** pnpandya@iu.edu

# %% [markdown]
# ## **Import Libraries**

# %%
# !pip install librosa
# Out:
# Requirement already satisfied: librosa in /opt/conda/lib/python3.10/site-packages (0.10.2.post1)
# Requirement already satisfied: audioread>=2.1.9 in /opt/conda/lib/python3.10/site-packages (from librosa) (3.0.1)
# Requirement already satisfied: numpy!=1.22.0,!=1.22.1,!=1.22.2,>=1.20.3 in /opt/conda/lib/python3.10/site-packages (from librosa) (1.26.4)
# Requirement already satisfied: scipy>=1.2.0 in /opt/conda/lib/python3.10/site-packages (from librosa) (1.14.1)
# Requirement already satisfied: scikit-learn>=0.20.0 in /opt/conda/lib/python3.10/site-packages (from librosa) (1.2.2)
# Requirement already satisfied: joblib>=0.14 in /opt/conda/lib/python3.10/site-packages (from librosa) (1.4.2)
# Requirement already satisfied: decorator>=4.3.0 in /opt/conda/lib/python3.10/site-packages (from librosa) (5.1.1)
# Requirement already satisfied: numba>=0.51.0 in /opt/conda/lib/python3.10/site-packages (from librosa) (0.60.0)
# Requirement already satisfied: soundfile>=0.12.1 in /opt/conda/lib/python3.10/site-packages (from librosa) (0.12.1)
# Requirement already satisfied: pooch>=1.1 in /opt/conda/lib/python3.10/site-packages (from librosa) (1.8.2)
# Requirement already satisfied: soxr>=0.3.2 in /opt/conda/lib/python3.10/site-packages (from librosa) (0.5.0.post1)
# Requirement already satisfied: typing-extensions>=4.1.1 in /opt/conda/lib/python3.10/site-packages (from librosa) (4.12.2)
# Requirement already satisfied: lazy-loader>=0.1 in /opt/conda/lib/python3.10/site-packages (from librosa) (0.4)
# Requirement already satisfied: msgpack>=1.0 in /opt/conda/lib/python3.10/site-packages (from librosa) (1.0.8)
# Requirement already satisfied: packaging in /opt/conda/lib/python3.10/site-packages (from lazy-loader>=0.1->librosa) (21.3)
# Requirement already satisfied: llvmlite<0.44,>=0.43.0dev0 in /opt/conda/lib/python3.10/site-packages (from numba>=0.51.0->librosa) (0.43.0)
# Requirement already satisfied: platformdirs>=2.5.0 in /opt/conda/lib/python3.10/site-packages (from pooch>=1.1->librosa) (3.11.0)
# Requirement already satisfied: requests>=2.19.0 in /opt/conda/lib/python3.10/site-packages (from pooch>=1.1->librosa) (2.32.3)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /opt/conda/lib/python3.10/site-packages (from scikit-learn>=0.20.0->librosa) (3.5.0)
# Requirement already satisfied: cffi>=1.0 in /opt/conda/lib/python3.10/site-packages (from soundfile>=0.12.1->librosa) (1.16.0)
# Requirement already satisfied: pycparser in /opt/conda/lib/python3.10/site-packages (from cffi>=1.0->soundfile>=0.12.1->librosa) (2.22)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /opt/conda/lib/python3.10/site-packages (from packaging->lazy-loader>=0.1->librosa) (3.1.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /opt/conda/lib/python3.10/site-packages (from requests>=2.19.0->pooch>=1.1->librosa) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /opt/conda/lib/python3.10/site-packages (from requests>=2.19.0->pooch>=1.1->librosa) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /opt/conda/lib/python3.10/site-packages (from requests>=2.19.0->pooch>=1.1->librosa) (1.26.18)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/conda/lib/python3.10/site-packages (from requests>=2.19.0->pooch>=1.1->librosa) (2024.8.30)

# %%
import os
import random
import torch
import torchvision
import torch.nn as nn
import torch.nn.functional as F
import torchvision.transforms as transforms
from torch.utils.data import DataLoader, random_split, Subset, Dataset
import matplotlib.pyplot as plt
import torch.optim as optim
import numpy as np
import librosa
import IPython.display as ipd
import soundfile as sf

# %%
# Set the seed for random number generators
seed = 13
random.seed(seed)
np.random.seed(seed)
torch.manual_seed(seed)

# If using GPU
if torch.cuda.is_available():
    torch.cuda.manual_seed(seed)
    torch.cuda.manual_seed_all(seed)  # For multi-GPU setups
    torch.backends.cudnn.deterministic = True  # To ensure deterministic behavior
    torch.backends.cudnn.benchmark = False

# %% [markdown]
# ## **Get data from Gdrive**

# %%
# import shutil
# from google.colab import drive

# # Mount Google Drive
# drive.mount('/content/drive/')

# # Define the data directory path
# data_dir = '/content/data/'

# # Delete the data directory if it exists
# if os.path.exists(data_dir):
#     shutil.rmtree(data_dir)

# # Unzip the file into the data directory
# !unzip "/content/drive/MyDrive/DLS/Homework-2/data.zip" -d "/content/data/"

# %% [markdown]
# ## **Preparing Data for Q1 & Q2**

# %%
# Set the device to use GPU if available, otherwise use CPU
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# %%
# Ensure the model folder exist
model_dir = "/kaggle/working/model/"
if not os.path.exists(model_dir):
    os.makedirs(model_dir)

# Ensure the output folder exists
output_dir = '/kaggle/working/output'
if not os.path.exists(output_dir):
    os.makedirs(output_dir)

# %%
# Load and preprocess data
def load_and_preprocess(file_path):
    s, sr = librosa.load(file_path, sr=None)
    S = np.abs(librosa.stft(s, n_fft=1024, hop_length=512))
    return S.T, sr

# %%
# Load training data
X, sr = load_and_preprocess('/kaggle/input/assignment-2-dataset/train_dirty_male.wav')
S, _ = load_and_preprocess('/kaggle/input/assignment-2-dataset/train_clean_male.wav')

# %%
# Convert to PyTorch tensors
X_tensor = torch.FloatTensor(X)
S_tensor = torch.FloatTensor(S)

# %%
print("Shape of |S|:", S_tensor.shape)
print("Shape of |X|:", X_tensor.shape)
# Out:
# Shape of |S|: torch.Size([2459, 513])
# Shape of |X|: torch.Size([2459, 513])

# %%
# Load validation data
x_val, sr_val = librosa.load('/kaggle/input/assignment-2-dataset/test_x_01.wav', sr=None)
X_val = np.abs(librosa.stft(x_val, n_fft=1024, hop_length=512))
X_val_tensor = torch.FloatTensor(X_val.T)

s_val_clean, _ = librosa.load('/kaggle/input/assignment-2-dataset/test_s_01.wav', sr=sr_val)

# %%
# Utility function for SNR calculation
def calculate_snr(clean_signal, denoised_signal):
    numerator = np.sum(clean_signal**2)
    denominator = np.sum((clean_signal - denoised_signal)**2) + 1e-20
    snr = 10 * np.log10(numerator / denominator)
    return snr

# %% [markdown]
# ## **Problem-1: Speech Deniosing Using Deep Learning [3 Points]**
#
# **Keywords:** Speech Denoising and Source Separation.
#
# **Task:** Implement DNN with atleast two hidden layers.
# - Build a simple deep learning based speech denoiser that takes a noisy speech spectrum (speech plus chips eating noise) and then produces a cleaned-up speech spectrum.
#
# **Data:** `train_dirty_male.wav` and `train_clean_male.wav` are the noisy speech and its corresponding clean speech we are going to use for training the network.
#
# **Training Steps:**
#
# - Load the and convert them into spectrograms, which are matrix representation of the signals. To achieve this, we need to install `librosa` and use the following code:
#
#   ```python
#   !pip install librosa # in colab, you’ll need to install this
#   import librosa
#   s, sr=librosa.load(‘train_clean_male.wav’, sr=None)
#   S=librosa.stft(s, n_fft=1024, hop_length=512)
#   sn, sr=librosa.load(‘train_dirty_male.wav’, sr=None)
#   X=librosa.stft(sn, n_fft=1024, hop_length=512)
#   ```
#
# - This will give us two matrices ${S}$ and ${X}$ of size `513 X 2459`. This procedure is called `Short-Time Fourier Transform`.
#
# - Then, we need to take their magnitudes by using `np.abs()` or any suitable methods. Let's call them ${|S|}$ and ${|X|}$.
#
# - Train a fully-connected DNN - Experiment with `# of hidden layers, activation function and initialization scheme`. The `input` to the network is a column vector of ${|X|}$ (a 513-dim vector) and the `target` is its corresponding one in ${|S|}$. Also, use `mini-batching`.
#
# - Network should predict `non-negative magnitudes` as output.
#
# **Testing Steps:**
#
# - `test_01_x.wav` is the noisy signal for validation. Load them and apply the `Short-Time Fourier Transform` (STFT) as before.
#
# - Feed the magnitude spectra of this test mixture ${|X_{\text{test}}|}$ to the network and predict their clean magnitude spectra $|\hat{S}_{\text{test}}|$.
#
# - **Note:** We can recover the speech spectrogram of the test signal using `Hadamard Product`.
#
# $$
# \hat{S} = \frac{X_{\text{test}}}{|X_{\text{test}}|} \odot |\hat{S}_{\text{test}}| \tag{1}
# $$
#
# which means you take the phase information of the input noisy signal $\frac{X_{\text{test}}}{|X_{\text{test}}|}$ and use that to recover the clean speech. $\odot$ stands for the Hadamard product and the division is element-wise, too.
#
# - Recover the time domain speech signal by applying an inverse-STFT on $\hat{S}_{\text{test}}$, which will give us a vector. Let's call this cleanedd-up test speech signal $\hat{s}_{\text{test}}$.
#
# - Then, calculate Signal-to-Noise Ratio (SNR) comparing it with the ground truth speech using below code:
#
#     ```python
#     librosa.output.write_wav(‘test_s_01_recons.wav’, sh_test, sr)
#
#     or
#
#     import soundfile as sf
#     sf.write(‘test_s_01_recons.wav’, sh_test, sr)
#     ```
# - We can compute SNR if we know the ground-truth source. Load `test_01_s.wav`. This is the ground-truth clean signal buried in `test_01_x.wav`. Compute the SNR of the predicted validation signal by comparing it to `test_01_s.wav`, but do not include this example to your training process. Once the training process is done, or even in the middle of training epochs, you apply your model to this validation example, and compute the SNR value. That way, you can simulate the testing environment, although it doesn’t guarantee that the model will work well on the test example, because the validation example can be different from the test set. This approach is related to the `early stopping technique` explained in `M03 S37`. Use this validation signal to prevent overfitting. By the way, SNR is defined as follows:
#
# $$
# \text{SNR} = 10 \log_{10} \left( \frac{\sum_t s^2(t)}{\sum_t \left( s(t) - \hat{s}(t) \right)^2} \right) \tag{2}
# $$
#
# where ${s(t)}$ and $\hat{s(t)}$ are the ground-truth clean speech and the recovered one in the time domain, respectively. Be careful with the division and logarithm: you don’t want your denominator to be zero or anything inside the log function to be zero. Adding a very small number, e.g., ${1 \times e^{-20}}$, is a good idea to prevent it.
#
# **Outcome:** Do the same testing procedure for `test_02_x.wav`. Grading will be based on the denoised version of `test_02_x.wav` and Submit the audio file.

# %%
# Define the DNN model
class SpeechDenoiserDNN(nn.Module):
    def __init__(self, input_size, hidden_size1, hidden_size2, output_size):
        super(SpeechDenoiserDNN, self).__init__()
        self.fc1 = nn.Linear(input_size, hidden_size1)
        self.fc2 = nn.Linear(hidden_size1, hidden_size2)
        self.fc3 = nn.Linear(hidden_size2, output_size)
        self.leaky_relu = nn.LeakyReLU(negative_slope=0.01)
        self.relu = nn.ReLU()

    def forward(self, x):
        x = self.leaky_relu(self.fc1(x))
        x = self.leaky_relu(self.fc2(x))
        x = self.relu(self.fc3(x))
        return x

# %%
# Initialize model, loss function, and optimizer
input_size = S.shape[1]
hidden_size1 = 512
hidden_size2 = 512
output_size = S.shape[1]
learning_rate = 0.001

# %%
q1_model = SpeechDenoiserDNN(input_size, hidden_size1, hidden_size2, output_size)
q1_criterion = nn.MSELoss()
q1_optimizer = optim.Adam(q1_model.parameters(), lr=learning_rate)

# %%
# Training loop
num_epochs = 300
batch_size = 64
patience = 10  # for early stopping

# %%
# Training
q1_best_snr = float('-inf')
epochs_without_improvement = 0

for epoch in range(num_epochs):
    q1_model.train()
    total_loss = 0
    num_batches = X_tensor.shape[0] // batch_size

    # Shuffle data
    indices = torch.randperm(X_tensor.shape[0])
    X_shuffled = X_tensor[indices]
    S_shuffled = S_tensor[indices]

    for i in range(num_batches):
        start_idx = i * batch_size
        end_idx = start_idx + batch_size

        batch_X = X_shuffled[start_idx:end_idx]
        batch_S = S_shuffled[start_idx:end_idx]

        q1_optimizer.zero_grad()
        outputs = q1_model(batch_X)
        loss = q1_criterion(outputs, batch_S)
        loss.backward()
        q1_optimizer.step()

        total_loss += loss.item()

    # Validation
    q1_model.eval()
    with torch.no_grad():
        S_hat_val = q1_model(X_val_tensor).numpy().T
        X_val_complex = librosa.stft(x_val, n_fft=1024, hop_length=512)
        S_hat_val_full = X_val_complex / np.abs(X_val_complex) * S_hat_val
        s_hat_val = librosa.istft(S_hat_val_full, hop_length=512, length=len(x_val))
        snr_val = calculate_snr(s_val_clean, s_hat_val)

    print(f'Epoch [{epoch+1}/{num_epochs}], Loss: {total_loss/num_batches:.4f}, Validation SNR: {snr_val:.2f} dB')

    # Early stopping
    if snr_val > q1_best_snr:
        q1_best_snr = snr_val
        model_dir = '/kaggle/working/model'
        if not os.path.exists(model_dir):
            os.makedirs(model_dir)
        torch.save(q1_model.state_dict(), os.path.join(model_dir, 'q1_best_model.pth'))
        epochs_without_improvement = 0
    else:
        epochs_without_improvement += 1
        if epochs_without_improvement >= patience:
            print("Early stopping")
            break
# Out:
# Epoch [1/300], Loss: 0.0568, Validation SNR: 2.88 dB
# Epoch [2/300], Loss: 0.0277, Validation SNR: 3.87 dB
# Epoch [3/300], Loss: 0.0186, Validation SNR: 4.94 dB
# Epoch [4/300], Loss: 0.0153, Validation SNR: 5.18 dB
# Epoch [5/300], Loss: 0.0122, Validation SNR: 5.69 dB
# Epoch [6/300], Loss: 0.0104, Validation SNR: 6.22 dB
# Epoch [7/300], Loss: 0.0095, Validation SNR: 6.23 dB
# Epoch [8/300], Loss: 0.0091, Validation SNR: 6.50 dB
# Epoch [9/300], Loss: 0.0082, Validation SNR: 6.51 dB
# Epoch [10/300], Loss: 0.0084, Validation SNR: 6.49 dB
# Epoch [11/300], Loss: 0.0077, Validation SNR: 6.65 dB
# Epoch [12/300], Loss: 0.0072, Validation SNR: 6.96 dB
# Epoch [13/300], Loss: 0.0065, Validation SNR: 6.87 dB
# Epoch [14/300], Loss: 0.0062, Validation SNR: 6.81 dB
# Epoch [15/300], Loss: 0.0058, Validation SNR: 6.92 dB
# Epoch [16/300], Loss: 0.0062, Validation SNR: 7.09 dB
# Epoch [17/300], Loss: 0.0056, Validation SNR: 7.15 dB
# Epoch [18/300], Loss: 0.0052, Validation SNR: 7.34 dB
# Epoch [19/300], Loss: 0.0049, Validation SNR: 7.19 dB
# Epoch [20/300], Loss: 0.0049, Validation SNR: 7.48 dB
# Epoch [21/300], Loss: 0.0052, Validation SNR: 7.36 dB
# Epoch [22/300], Loss: 0.0049, Validation SNR: 7.50 dB
# Epoch [23/300], Loss: 0.0046, Validation SNR: 7.20 dB
# Epoch [24/300], Loss: 0.0050, Validation SNR: 7.35 dB
# Epoch [25/300], Loss: 0.0060, Validation SNR: 7.42 dB
# Epoch [26/300], Loss: 0.0059, Validation SNR: 7.08 dB
# Epoch [27/300], Loss: 0.0051, Validation SNR: 7.62 dB
# Epoch [28/300], Loss: 0.0046, Validation SNR: 7.76 dB
# Epoch [29/300], Loss: 0.0041, Validation SNR: 7.66 dB
# Epoch [30/300], Loss: 0.0039, Validation SNR: 7.70 dB
# Epoch [31/300], Loss: 0.0039, Validation SNR: 7.57 dB
# Epoch [32/300], Loss: 0.0040, Validation SNR: 7.96 dB
# Epoch [33/300], Loss: 0.0040, Validation SNR: 7.47 dB
# Epoch [34/300], Loss: 0.0044, Validation SNR: 7.82 dB
# Epoch [35/300], Loss: 0.0044, Validation SNR: 7.92 dB
# Epoch [36/300], Loss: 0.0043, Validation SNR: 7.94 dB
# Epoch [37/300], Loss: 0.0043, Validation SNR: 7.36 dB
# Epoch [38/300], Loss: 0.0047, Validation SNR: 7.80 dB
# Epoch [39/300], Loss: 0.0047, Validation SNR: 7.69 dB
# Epoch [40/300], Loss: 0.0052, Validation SNR: 7.29 dB
# Epoch [41/300], Loss: 0.0047, Validation SNR: 7.89 dB
# Epoch [42/300], Loss: 0.0042, Validation SNR: 7.61 dB
# Early stopping

# %%
# Calculate Best Validation SNR
print(f"Best Validation SNR: {q1_best_snr:.2f} dB")
# Out:
# Best Validation SNR: 7.96 dB

# %%
# Function to denoise a test file
def denoise_test_file_q1(q1_model, file_path):
    x_test, sr = librosa.load(file_path, sr=None)
    X_test = np.abs(librosa.stft(x_test, n_fft=1024, hop_length=512))
    X_test_tensor = torch.FloatTensor(X_test.T)

    q1_model.eval()
    with torch.no_grad():
        S_hat_test = q1_model(X_test_tensor).numpy().T

    # Reconstruct using phase of the original noisy signal
    X_test_complex = librosa.stft(x_test, n_fft=1024, hop_length=512)
    S_hat = X_test_complex / np.abs(X_test_complex) * S_hat_test
    s_hat = librosa.istft(S_hat, hop_length=512, length=len(x_test))

    return s_hat, sr

# %%
# Process and save test files
for test_file in ['test_x_01', 'test_x_02']:
    s_hat, sr = denoise_test_file_q1(q1_model, f'/kaggle/input/assignment-2-dataset/{test_file}.wav')
    output_file = f'/kaggle/working/output/q1_{test_file.replace("x", "s")}_recons.wav'
    sf.write(output_file, s_hat, sr)

    # Calculate SNR for test_01
    if test_file == 'test_x_01':
        s_noisy , _ = librosa.load('/kaggle/input/assignment-2-dataset/test_x_01.wav', sr=None)
        s_clean, _ = librosa.load('/kaggle/input/assignment-2-dataset/test_s_01.wav', sr=None)
        snr = calculate_snr(s_clean, s_noisy)
        print(f"SNR for {test_file}: {snr:.2f} dB")

print("Denoising complete. Output files saved in the specified directory.")
# Out:
# SNR for test_x_01: 13.23 dB
# Denoising complete. Output files saved in the specified directory.

# %%
print("Original Test Audio File: test_x_01.wav")
ipd.Audio("/kaggle/input/assignment-2-dataset/test_x_01.wav")
# Out:
# Original Test Audio File: test_x_01.wav
#                 <audio  controls="controls" >
#                     <source src="data:audio/x-wav;base64,..." type="audio/x-wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
print("Reconstructed Audio File: q1_test_s_01_recons.wav")
ipd.Audio("/kaggle/working/output/q1_test_s_01_recons.wav")
# Out:
# Reconstructed Audio File: q1_test_s_01_recons.wav
#                 <audio  controls="controls" >
#                     <source src="data:audio/x-wav;base64,..." type="audio/x-wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
print("Original Test Audio File: test_x_02.wav")
ipd.Audio("/kaggle/input/assignment-2-dataset/test_x_02.wav")
# Out:
# Original Test Audio File: test_x_02.wav
#                 <audio  controls="controls" >
#                     <source src="data:audio/x-wav;base64,..." type="audio/x-wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
print("Reconstructed Audio File: q1_test_s_02_recons.wav")
ipd.Audio("/kaggle/working/output/q1_test_s_02_recons.wav")
# Out:
# Reconstructed Audio File: q1_test_s_02_recons.wav
#                 <audio  controls="controls" >
#                     <source src="data:audio/x-wav;base64,..." type="audio/x-wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %% [markdown]
# ## **Problem 2: Speech Denoising Using 1D CNN [4 points]**
#
# **Keywords:** 1D CNN, STFT magnitude domain, Speech Denoising
#
# **Task:** Implement a 1D CNN that performs speech denoising in the STFT magnitude domain.
#
# **Data:** Same as Problem 1 - `train_dirty_male.wav` and `train_clean_male.wav`
#
# **Training Steps:**
#
# 1. Install and load librosa as in Problem 1.
#
# 2. Obtain magnitude spectrograms |X| and |S| using STFT:
#
#    ```python
#    import librosa
#    import numpy as np
#
#    s, sr = librosa.load('train_clean_male.wav', sr=None)
#    S = np.abs(librosa.stft(s, n_fft=1024, hop_length=512))
#
#    sn, sr = librosa.load('train_dirty_male.wav', sr=None)
#    X = np.abs(librosa.stft(sn, n_fft=1024, hop_length=512))
#    ```
#
# 3. Transpose matrices for CNN input: |X|⊤ and |S|⊤
#
# 4. Design 1D CNN architecture:
#    - Input shape: [B × 1 × 1 × 513] (B = batch size)
#    - Kernel size: 1 × D or D (depending on implementation)
#    - First layer output: [B × K × 1 × (513 - D + 1)] (K = number of kernels)
#    - Final output: [B × 513] (clean magnitude spectra approximation)
#
# 5. Implement CNN layers:
#    - Use few kernels and hidden layers
#    - Apply striding (>1) to reduce dimensionality after each CNN layer
#    - Consider maxpooling with striding
#    - Flatten last feature map and add linear layer to reduce to 513 dimensions
#    - Apply activation functions at every layer, including the last
#
# 6. Train the model:
#    - Use mini-batching
#    - Experiment with various optimization techniques
#
# **Testing Steps:**
#
# 1. Use the same test signal as in Problem 1 (`test_01_x.wav`).
#
# 2. Apply STFT and obtain magnitude spectrogram for the test signal.
#
# 3. Feed the test magnitude spectrogram through the trained 1D CNN.
#
# 4. Reconstruct the time-domain signal using the phase of the original noisy signal (as in Problem 1).
#
# 5. Compute SNR using the same method as in Problem 1.
#
# 6. Apply the same procedure to `test_02_x.wav`.
#
# **Outcome:** Submit the denoised version of `test_02_x.wav`.
#
# **Important Considerations:**
#
# - Avoid zero-padding in CNN layers
# - Be careful with dimensionality management, especially for the final FC layer
# - The CNN operates along the frequency axis of the spectrogram
# - Adjust stride and pooling to manage feature map size effectively
#
# $$
# \text{SNR} = 10 \log_{10} \left( \frac{\sum_t s^2(t)}{\sum_t \left( s(t) - \hat{s}(t) \right)^2} \right) \tag{1}
# $$
#
# Where s(t) is the ground-truth clean speech and ŝ(t) is the recovered speech in the time domain.

# %%
# Convert to PyTorch tensors
X_tensor = torch.FloatTensor(X).unsqueeze(1)  # Add channel dimension
S_tensor = torch.FloatTensor(S)

# %%
print("Shape of |S|:", S_tensor.shape)
print("Shape of |X|:", X_tensor.shape)
# Out:
# Shape of |S|: torch.Size([2459, 513])
# Shape of |X|: torch.Size([2459, 1, 513])

# %%
# Define the 1D CNN model
class SpeechDenoiser1DCNN(nn.Module):
    def __init__(self, input_size):
        super(SpeechDenoiser1DCNN, self).__init__()
        # CNN operates along the frequency axis of the spectrogram
        self.conv1 = nn.Conv1d(1, 32, kernel_size=5, stride=1)
        self.pool1 = nn.MaxPool1d(kernel_size=2, stride=2)
        self.conv2 = nn.Conv1d(32, 64, kernel_size=5, stride=1)
        self.pool2 = nn.MaxPool1d(kernel_size=2, stride=2)
        self.conv3 = nn.Conv1d(64, 128, kernel_size=5, stride=1)
        self.fc = nn.Linear(121 * (input_size // 4), input_size) # 128 * 121 = 15488 --> Final Shape (15488, 513)
        self.leaky_relu = nn.LeakyReLU(negative_slope=0.01)
        self.relu = nn.ReLU()

    def forward(self, x):
        x = self.leaky_relu(self.conv1(x))
        x = self.pool1(x)
        x = self.leaky_relu(self.conv2(x))
        x = self.pool2(x)
        x = self.leaky_relu(self.conv3(x))
        x = x.view(x.size(0), -1)  # Flatten
        x = self.relu(self.fc(x))  # Ensure non-negative output
        return x

# %%
# Initialize model, loss function, and optimizer
learning_rate = 0.001

q2_model = SpeechDenoiser1DCNN(S.shape[1])
q2_criterion = nn.MSELoss()
q2_optimizer = optim.Adam(q2_model.parameters(), lr=learning_rate)

# %%
# Training loop
num_epochs = 300
batch_size = 64
patience = 10  # for early stopping

# Load validation data
X_val_tensor = X_val_tensor.unsqueeze(1)

q2_best_snr = float('-inf')
epochs_without_improvement = 0

# %%
for epoch in range(num_epochs):
    q2_model.train()
    total_loss = 0
    num_batches = X_tensor.shape[0] // batch_size

    # Shuffle data
    indices = torch.randperm(X_tensor.shape[0])
    X_shuffled = X_tensor[indices]
    S_shuffled = S_tensor[indices]

    for i in range(num_batches):
        start_idx = i * batch_size
        end_idx = start_idx + batch_size

        batch_X = X_shuffled[start_idx:end_idx]
        batch_S = S_shuffled[start_idx:end_idx]

        q2_optimizer.zero_grad()
        outputs = q2_model(batch_X)
        loss = q2_criterion(outputs, batch_S)
        loss.backward()
        q2_optimizer.step()

        total_loss += loss.item()

    # Validation
    q2_model.eval()
    with torch.no_grad():
        S_hat_val = q2_model(X_val_tensor).squeeze(1).numpy().T
        X_val_complex = librosa.stft(x_val, n_fft=1024, hop_length=512)
        S_hat_val_full = X_val_complex / np.abs(X_val_complex) * S_hat_val
        s_hat_val = librosa.istft(S_hat_val_full, hop_length=512, length=len(x_val))
        snr_val = calculate_snr(s_val_clean, s_hat_val)

    print(f'Epoch [{epoch + 1}/{num_epochs}], Loss: {total_loss / num_batches:.4f}, Validation SNR: {snr_val:.2f} dB')

    # Early stopping
    if snr_val > q2_best_snr:
        q2_best_snr = snr_val
        model_dir = '/kaggle/working/model'
        if not os.path.exists(model_dir):
            os.makedirs(model_dir)
        torch.save(q2_model.state_dict(), os.path.join(model_dir, 'q2_best_model.pth'))
        epochs_without_improvement = 0
    else:
        epochs_without_improvement += 1
        if epochs_without_improvement >= patience:
            print("Early stopping")
            break
# Out:
# Epoch [1/300], Loss: 0.0622, Validation SNR: 3.24 dB
# Epoch [2/300], Loss: 0.0261, Validation SNR: 5.13 dB
# Epoch [3/300], Loss: 0.0173, Validation SNR: 6.01 dB
# Epoch [4/300], Loss: 0.0140, Validation SNR: 6.51 dB
# Epoch [5/300], Loss: 0.0124, Validation SNR: 6.77 dB
# Epoch [6/300], Loss: 0.0113, Validation SNR: 7.24 dB
# Epoch [7/300], Loss: 0.0115, Validation SNR: 6.69 dB
# Epoch [8/300], Loss: 0.0109, Validation SNR: 7.54 dB
# Epoch [9/300], Loss: 0.0104, Validation SNR: 7.55 dB
# Epoch [10/300], Loss: 0.0098, Validation SNR: 7.50 dB
# Epoch [11/300], Loss: 0.0095, Validation SNR: 7.49 dB
# Epoch [12/300], Loss: 0.0093, Validation SNR: 7.72 dB
# Epoch [13/300], Loss: 0.0093, Validation SNR: 7.81 dB
# Epoch [14/300], Loss: 0.0094, Validation SNR: 7.67 dB
# Epoch [15/300], Loss: 0.0092, Validation SNR: 7.64 dB
# Epoch [16/300], Loss: 0.0091, Validation SNR: 7.85 dB
# Epoch [17/300], Loss: 0.0090, Validation SNR: 7.83 dB
# Epoch [18/300], Loss: 0.0090, Validation SNR: 7.89 dB
# Epoch [19/300], Loss: 0.0087, Validation SNR: 7.72 dB
# Epoch [20/300], Loss: 0.0086, Validation SNR: 7.80 dB
# Epoch [21/300], Loss: 0.0086, Validation SNR: 7.81 dB
# Epoch [22/300], Loss: 0.0086, Validation SNR: 7.79 dB
# Epoch [23/300], Loss: 0.0085, Validation SNR: 7.77 dB
# Epoch [24/300], Loss: 0.0084, Validation SNR: 8.03 dB
# Epoch [25/300], Loss: 0.0083, Validation SNR: 7.91 dB
# Epoch [26/300], Loss: 0.0089, Validation SNR: 7.84 dB
# Epoch [27/300], Loss: 0.0090, Validation SNR: 7.93 dB
# Epoch [28/300], Loss: 0.0084, Validation SNR: 8.04 dB
# Epoch [29/300], Loss: 0.0081, Validation SNR: 7.89 dB
# Epoch [30/300], Loss: 0.0079, Validation SNR: 8.10 dB
# Epoch [31/300], Loss: 0.0077, Validation SNR: 7.92 dB
# Epoch [32/300], Loss: 0.0077, Validation SNR: 8.00 dB
# Epoch [33/300], Loss: 0.0076, Validation SNR: 7.98 dB
# Epoch [34/300], Loss: 0.0075, Validation SNR: 8.08 dB
# Epoch [35/300], Loss: 0.0075, Validation SNR: 7.97 dB
# Epoch [36/300], Loss: 0.0075, Validation SNR: 7.91 dB
# Epoch [37/300], Loss: 0.0074, Validation SNR: 8.06 dB
# Epoch [38/300], Loss: 0.0075, Validation SNR: 8.02 dB
# Epoch [39/300], Loss: 0.0075, Validation SNR: 7.99 dB
# Epoch [40/300], Loss: 0.0074, Validation SNR: 8.00 dB
# Early stopping

# %%
# Best Validation SNR
print(f"Best Validation SNR: {q2_best_snr:.2f} dB")
# Out:
# Best Validation SNR: 8.10 dB

# %%
# Function to denoise a test file
def denoise_test_file_q2(q2_model, file_path):
    x_test, sr = librosa.load(file_path, sr=None)
    X_test = np.abs(librosa.stft(x_test, n_fft=1024, hop_length=512))
    X_test_tensor = torch.FloatTensor(X_test.T).unsqueeze(1)

    q2_model.eval()
    with torch.no_grad():
        S_hat_test = q2_model(X_test_tensor).squeeze(1).numpy().T

    # Reconstruct using phase of the original noisy signal
    X_test_complex = librosa.stft(x_test, n_fft=1024, hop_length=512)
    S_hat = X_test_complex / np.abs(X_test_complex) * S_hat_test
    s_hat = librosa.istft(S_hat, hop_length=512, length=len(x_test))

    return s_hat, sr

# %%
# Process and save test files
for test_file in ['test_x_01', 'test_x_02']:
    s_hat, sr = denoise_test_file_q2(q2_model, f'/kaggle/input/assignment-2-dataset/{test_file}.wav')
    output_file = f'/kaggle/working/output/q2_{test_file.replace("x", "s")}_recons.wav'
    sf.write(output_file, s_hat, sr)

    # Calculate SNR for test_01
    if test_file == 'test_x_01':
        s_noisy , _ = librosa.load('/kaggle/input/assignment-2-dataset/test_x_01.wav', sr=None)
        s_clean, _ = librosa.load('/kaggle/input/assignment-2-dataset/test_s_01.wav', sr=None)
        snr = calculate_snr(s_clean, s_noisy)
        print(f"SNR for {test_file}: {snr:.2f} dB")

print("Denoising complete. Output files saved in the specified directory.")
# Out:
# SNR for test_x_01: 13.23 dB
# Denoising complete. Output files saved in the specified directory.

# %%
print("Original Test Audio File: test_x_01.wav")
ipd.Audio("/kaggle/input/assignment-2-dataset/test_x_01.wav")
# Out:
# Original Test Audio File: test_x_01.wav
#                 <audio  controls="controls" >
#                     <source src="data:audio/x-wav;base64,..." type="audio/x-wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
print("Reconstructed Audio File: q2_test_s_01_recons.wav")
ipd.Audio("/kaggle/working/output/q2_test_s_01_recons.wav")
# Out:
# Reconstructed Audio File: q2_test_s_01_recons.wav
#                 <audio  controls="controls" >
#                     <source src="data:audio/x-wav;base64,..." type="audio/x-wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
print("Original Test Audio File: test_x_02.wav")
ipd.Audio("/kaggle/input/assignment-2-dataset/test_x_02.wav")
# Out:
# Original Test Audio File: test_x_02.wav
#                 <audio  controls="controls" >
#                     <source src="data:audio/x-wav;base64,..." type="audio/x-wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
print("Reconstructed Audio File: q2_test_s_02_recons.wav")
ipd.Audio("/kaggle/working/output/q2_test_s_02_recons.wav")
# Out:
# Reconstructed Audio File: q2_test_s_02_recons.wav
#                 <audio  controls="controls" >
#                     <source src="data:audio/x-wav;base64,..." type="audio/x-wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %% [markdown]
# ## **Problem 3: Data Augmentation [4 points]**
#
# **Dataset: CIFAR-10**
#
# - 10 visual object classes
# - Download from [https://www.cs.toronto.edu/~kriz/cifar.html](https://www.cs.toronto.edu/~kriz/cifar.html)
# - Set aside 5,000 training examples for validation
#
# **Baseline CNN Classifier**
#
# 1. Preprocess images:
#    - Reshape to 32 x 32 x 3 tensors
#    - Convert 8-bit integers (0-255) to floats (0-1)
#    - Rescale to [-1, 1] range
#
# 2. Architecture:
#    - Conv2D: 10 kernels, 5x5x3, stride=1
#    - MaxPooling: 2x2, stride=2
#    - Conv2D: 10 kernels, 5x5x10, stride=1
#    - MaxPooling: 2x2, stride=2
#    - Fully-connected: [flattened] x 20
#    - Fully-connected: 20 x 10
#    - Softmax output
#
# 3. Training:
#    - ReLU activation
#    - He initialization
#    - Adam optimizer (learning rate = 0.001)
#    - Record validation accuracy per epoch
#    - Plot validation accuracy over epochs
#
# **Augmented Dataset Classifier**
#
# 1. Create 4 augmented datasets:
#    - #1: Brighten by 10% (clip at 1.0)
#    - #2: Darken by 10%
#    - #3: Horizontal flip
#    - #4: Original images
#
# 2. Merge augmented datasets:
#    - 45,000 original + 135,000 augmented = 180,000 total
#    - Rescale to [-1, 1] range
#    - Visualize samples to verify augmentations
#
# 3. Train new network:
#    - Use same architecture as baseline
#    - Train on full augmented dataset
#    - Record validation accuracy per epoch
#
# **Comparison**
#
# - Plot validation accuracy curves for baseline and augmented models
# - Run for 200 epochs
# - Analyze improvement from data augmentation
#
# **Code Snippets**
#
# ```python
# # Brightness augmentation
# augmented_1 = np.minimum(1.1 * X, 1)
#
# # Darkness augmentation
# augmented_2 = 0.9 * X
#
# # Horizontal flip
# augmented_3 = X[:, :, ::-1, :]
#
# # Merge datasets
# augmented_full = np.concatenate([X, augmented_1, augmented_2, augmented_3], axis=0)
#
# # Rescale to [-1, 1]
# augmented_full = (augmented_full - 0.5) * 2
# ```
#
# **Key Points**
#
# - Data augmentation increases dataset size 4x
# - Maintain original labels for augmented images
# - Visualize augmented images to verify correctness
# - Compare validation performance between baseline and augmented models
# - No need to run final test set evaluation

# %%
# CNN architecture
class SimpleCNN(nn.Module):
    def __init__(self, num_classes=10):
        super(SimpleCNN, self).__init__()
        self.conv1 = nn.Conv2d(3, 10, kernel_size=5, stride=1)
        self.pool = nn.MaxPool2d(2, 2)
        self.conv2 = nn.Conv2d(10, 10, kernel_size=5, stride=1)
        self.fc1 = nn.Linear(10 * 5 * 5, 20)
        self.fc2 = nn.Linear(20, num_classes)

        self._initialize_weights()

    def forward(self, x):
        x = self.pool(torch.relu(self.conv1(x)))
        x = self.pool(torch.relu(self.conv2(x)))
        x = x.view(-1, 10 * 5 * 5)
        x = torch.relu(self.fc1(x))
        x = self.fc2(x)
        return x

    def _initialize_weights(self):
        for m in self.modules():
            if isinstance(m, nn.Conv2d) or isinstance(m, nn.Linear):
                nn.init.kaiming_normal_(m.weight, mode='fan_out', nonlinearity='relu')
                if m.bias is not None:
                    nn.init.constant_(m.bias, 0)

# %%
# Training function
def train_model(model, trainloader, valloader, criterion, optimizer, num_epochs, model_save_path):
    device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
    model = model.to(device)

    val_accuracies = []
    best_val_accuracy = 0

    for epoch in range(num_epochs):
        model.train()
        running_loss = 0.0
        for inputs, labels in trainloader:
            inputs, labels = inputs.to(device), labels.to(device)
            optimizer.zero_grad()
            outputs = model(inputs)
            loss = criterion(outputs, labels)
            loss.backward()
            optimizer.step()
            running_loss += loss.item()

        model.eval()
        correct = 0
        total = 0
        with torch.no_grad():
            for inputs, labels in valloader:
                inputs, labels = inputs.to(device), labels.to(device)
                outputs = model(inputs)
                _, predicted = torch.max(outputs.data, 1)
                total += labels.size(0)
                correct += (predicted == labels).sum().item()

        val_accuracy = 100 * correct / total
        val_accuracies.append(val_accuracy)

        print(f'Epoch {epoch+1}, Loss: {running_loss/len(trainloader):.3f}, Val Accuracy: {val_accuracy:.2f}%')

        # Save the model if it's the best so far
        if val_accuracy > best_val_accuracy:
            best_val_accuracy = val_accuracy
            torch.save(model.state_dict(), model_save_path)

    print(f"Model saved with validation accuracy: {best_val_accuracy:.2f}%")

    return val_accuracies

# %%
# Visualization function
def imshow(img, title):
    img = img/2 + 0.5 # UnNormalize the image
    npimg = img.numpy()
    plt.imshow(np.transpose(npimg, (1, 2, 0)))
    plt.title(title)
    plt.axis('off')

# %% [markdown]
# ### **Part 1: Baseline Model**

# %%
# Data loading and preprocessing
transform = transforms.Compose([
    transforms.ToTensor(),
    transforms.Normalize((0.5, 0.5, 0.5), (0.5, 0.5, 0.5))  # This scales to [-1, 1]
])

# %%
trainset = torchvision.datasets.CIFAR10(root='./data', train=True, download=True, transform=transform)
# testset = torchvision.datasets.CIFAR10(root='./data', train=False, download=True, transform=transform)
# Out:
# Downloading https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz to ./data/cifar-10-python.tar.gz
# 100%|██████████| 170498071/170498071 [00:03<00:00, 49214245.96it/s]
# Extracting ./data/cifar-10-python.tar.gz to ./data

# %%
# Set aside 5,000 training examples for validation
train_size = len(trainset) - 5000
val_size = 5000
trainset, valset = torch.utils.data.random_split(trainset, [train_size, val_size])

# %%
# Create data loaders
batch_size = 64
trainloader = torch.utils.data.DataLoader(trainset, batch_size=batch_size, shuffle=True)
valloader = torch.utils.data.DataLoader(valset, batch_size=batch_size, shuffle=False)

# %%
next(iter(trainloader))[0].shape
# Out:
# torch.Size([64, 3, 32, 32])

# %%
# Initialize the model, loss function, and optimizer
model = SimpleCNN(num_classes=10)
criterion = nn.CrossEntropyLoss()
optimizer = optim.Adam(model.parameters(), lr=0.001)

# %%
# Set up model save path
model_save_dir = '/kaggle/working/model'
baseline_model_save_path = os.path.join(model_save_dir, 'q3_baseline_model.pth')

# %%
# Train the model
num_epochs = 200
baseline_val_accuracies = train_model(model, trainloader, valloader, criterion, optimizer, num_epochs, baseline_model_save_path)
# Out:
# Epoch 1, Loss: 1.930, Val Accuracy: 38.62%
# Epoch 2, Loss: 1.557, Val Accuracy: 44.96%
# Epoch 3, Loss: 1.434, Val Accuracy: 47.08%
# Epoch 4, Loss: 1.365, Val Accuracy: 50.50%
# Epoch 5, Loss: 1.305, Val Accuracy: 52.42%
# Epoch 6, Loss: 1.251, Val Accuracy: 54.14%
# Epoch 7, Loss: 1.215, Val Accuracy: 54.96%
# Epoch 8, Loss: 1.173, Val Accuracy: 56.54%
# Epoch 9, Loss: 1.146, Val Accuracy: 56.48%
# Epoch 10, Loss: 1.121, Val Accuracy: 58.26%
# Epoch 11, Loss: 1.099, Val Accuracy: 58.78%
# Epoch 12, Loss: 1.086, Val Accuracy: 59.42%
# Epoch 13, Loss: 1.065, Val Accuracy: 58.82%
# Epoch 14, Loss: 1.052, Val Accuracy: 59.34%
# Epoch 15, Loss: 1.034, Val Accuracy: 60.54%
# Epoch 16, Loss: 1.026, Val Accuracy: 60.98%
# Epoch 17, Loss: 1.015, Val Accuracy: 61.96%
# Epoch 18, Loss: 1.006, Val Accuracy: 61.02%
# Epoch 19, Loss: 0.996, Val Accuracy: 60.72%
# Epoch 20, Loss: 0.989, Val Accuracy: 61.72%
# Epoch 21, Loss: 0.982, Val Accuracy: 61.74%
# Epoch 22, Loss: 0.969, Val Accuracy: 62.02%
# Epoch 23, Loss: 0.966, Val Accuracy: 62.06%
# Epoch 24, Loss: 0.960, Val Accuracy: 61.10%
# Epoch 25, Loss: 0.956, Val Accuracy: 61.24%
# Epoch 26, Loss: 0.943, Val Accuracy: 62.66%
# Epoch 27, Loss: 0.944, Val Accuracy: 62.80%
# Epoch 28, Loss: 0.940, Val Accuracy: 62.28%
# Epoch 29, Loss: 0.932, Val Accuracy: 62.92%
# Epoch 30, Loss: 0.925, Val Accuracy: 62.60%
# Epoch 31, Loss: 0.922, Val Accuracy: 62.34%
# Epoch 32, Loss: 0.922, Val Accuracy: 63.14%
# Epoch 33, Loss: 0.919, Val Accuracy: 63.52%
# Epoch 34, Loss: 0.914, Val Accuracy: 62.36%
# Epoch 35, Loss: 0.907, Val Accuracy: 62.78%
# Epoch 36, Loss: 0.904, Val Accuracy: 63.04%
# Epoch 37, Loss: 0.905, Val Accuracy: 63.04%
# Epoch 38, Loss: 0.898, Val Accuracy: 63.44%
# Epoch 39, Loss: 0.893, Val Accuracy: 62.96%
# Epoch 40, Loss: 0.896, Val Accuracy: 63.60%
# Epoch 41, Loss: 0.887, Val Accuracy: 64.34%
# Epoch 42, Loss: 0.886, Val Accuracy: 63.50%
# Epoch 43, Loss: 0.885, Val Accuracy: 62.36%
# Epoch 44, Loss: 0.882, Val Accuracy: 64.18%
# Epoch 45, Loss: 0.882, Val Accuracy: 62.54%
# Epoch 46, Loss: 0.878, Val Accuracy: 63.52%
# Epoch 47, Loss: 0.876, Val Accuracy: 63.88%
# Epoch 48, Loss: 0.875, Val Accuracy: 63.26%
# Epoch 49, Loss: 0.872, Val Accuracy: 63.84%
# Epoch 50, Loss: 0.867, Val Accuracy: 64.04%
# Epoch 51, Loss: 0.865, Val Accuracy: 64.10%
# Epoch 52, Loss: 0.865, Val Accuracy: 64.74%
# Epoch 53, Loss: 0.861, Val Accuracy: 63.80%
# Epoch 54, Loss: 0.858, Val Accuracy: 62.52%
# Epoch 55, Loss: 0.858, Val Accuracy: 62.84%
# Epoch 56, Loss: 0.858, Val Accuracy: 63.94%
# Epoch 57, Loss: 0.853, Val Accuracy: 63.28%
# Epoch 58, Loss: 0.853, Val Accuracy: 64.20%
# Epoch 59, Loss: 0.851, Val Accuracy: 63.94%
# Epoch 60, Loss: 0.851, Val Accuracy: 63.58%
# Epoch 61, Loss: 0.851, Val Accuracy: 62.88%
# Epoch 62, Loss: 0.847, Val Accuracy: 64.48%
# Epoch 63, Loss: 0.845, Val Accuracy: 63.90%
# Epoch 64, Loss: 0.843, Val Accuracy: 64.54%
# Epoch 65, Loss: 0.841, Val Accuracy: 63.34%
# Epoch 66, Loss: 0.842, Val Accuracy: 64.32%
# Epoch 67, Loss: 0.839, Val Accuracy: 63.86%
# Epoch 68, Loss: 0.834, Val Accuracy: 64.74%
# Epoch 69, Loss: 0.838, Val Accuracy: 63.54%
# Epoch 70, Loss: 0.833, Val Accuracy: 64.32%
# Epoch 71, Loss: 0.832, Val Accuracy: 62.22%
# Epoch 72, Loss: 0.832, Val Accuracy: 63.08%
# Epoch 73, Loss: 0.830, Val Accuracy: 63.78%
# Epoch 74, Loss: 0.830, Val Accuracy: 63.20%
# Epoch 75, Loss: 0.826, Val Accuracy: 63.02%
# Epoch 76, Loss: 0.827, Val Accuracy: 63.34%
# Epoch 77, Loss: 0.826, Val Accuracy: 63.84%
# Epoch 78, Loss: 0.828, Val Accuracy: 64.68%
# Epoch 79, Loss: 0.819, Val Accuracy: 63.82%
# Epoch 80, Loss: 0.821, Val Accuracy: 64.98%
# Epoch 81, Loss: 0.827, Val Accuracy: 64.18%
# Epoch 82, Loss: 0.819, Val Accuracy: 63.94%
# Epoch 83, Loss: 0.822, Val Accuracy: 63.48%
# Epoch 84, Loss: 0.817, Val Accuracy: 64.26%
# Epoch 85, Loss: 0.818, Val Accuracy: 62.76%
# Epoch 86, Loss: 0.816, Val Accuracy: 64.08%
# Epoch 87, Loss: 0.812, Val Accuracy: 63.26%
# Epoch 88, Loss: 0.811, Val Accuracy: 64.18%
# Epoch 89, Loss: 0.813, Val Accuracy: 63.12%
# Epoch 90, Loss: 0.816, Val Accuracy: 64.18%
# Epoch 91, Loss: 0.812, Val Accuracy: 64.56%
# Epoch 92, Loss: 0.812, Val Accuracy: 64.04%
# Epoch 93, Loss: 0.808, Val Accuracy: 63.84%
# Epoch 94, Loss: 0.806, Val Accuracy: 63.96%
# Epoch 95, Loss: 0.806, Val Accuracy: 64.58%
# Epoch 96, Loss: 0.807, Val Accuracy: 63.38%
# Epoch 97, Loss: 0.805, Val Accuracy: 63.84%
# Epoch 98, Loss: 0.809, Val Accuracy: 63.32%
# Epoch 99, Loss: 0.803, Val Accuracy: 64.06%
# Epoch 100, Loss: 0.802, Val Accuracy: 64.06%
# Epoch 101, Loss: 0.803, Val Accuracy: 64.14%
# Epoch 102, Loss: 0.798, Val Accuracy: 62.66%
# Epoch 103, Loss: 0.802, Val Accuracy: 63.30%
# Epoch 104, Loss: 0.798, Val Accuracy: 64.42%
# Epoch 106, Loss: 0.796, Val Accuracy: 63.00%
# Epoch 107, Loss: 0.797, Val Accuracy: 63.78%
# Epoch 108, Loss: 0.799, Val Accuracy: 63.10%
# Epoch 109, Loss: 0.798, Val Accuracy: 64.40%
# Epoch 110, Loss: 0.795, Val Accuracy: 63.88%
# Epoch 111, Loss: 0.799, Val Accuracy: 63.44%
# Epoch 112, Loss: 0.793, Val Accuracy: 62.92%
# Epoch 113, Loss: 0.793, Val Accuracy: 64.52%
# Epoch 114, Loss: 0.791, Val Accuracy: 63.78%
# Epoch 115, Loss: 0.790, Val Accuracy: 64.54%
# Epoch 116, Loss: 0.788, Val Accuracy: 64.34%
# Epoch 117, Loss: 0.786, Val Accuracy: 64.78%
# Epoch 118, Loss: 0.785, Val Accuracy: 64.00%
# Epoch 119, Loss: 0.788, Val Accuracy: 63.96%
# Epoch 120, Loss: 0.787, Val Accuracy: 63.66%
# Epoch 121, Loss: 0.791, Val Accuracy: 63.94%
# Epoch 122, Loss: 0.784, Val Accuracy: 63.36%
# Epoch 123, Loss: 0.783, Val Accuracy: 63.92%
# Epoch 124, Loss: 0.786, Val Accuracy: 63.90%
# Epoch 125, Loss: 0.788, Val Accuracy: 63.74%
# Epoch 126, Loss: 0.784, Val Accuracy: 63.58%
# Epoch 127, Loss: 0.784, Val Accuracy: 64.16%
# Epoch 128, Loss: 0.785, Val Accuracy: 64.22%
# Epoch 129, Loss: 0.784, Val Accuracy: 63.68%
# Epoch 130, Loss: 0.778, Val Accuracy: 63.82%
# Epoch 131, Loss: 0.785, Val Accuracy: 62.08%
# Epoch 132, Loss: 0.780, Val Accuracy: 64.02%
# Epoch 133, Loss: 0.778, Val Accuracy: 63.42%
# Epoch 134, Loss: 0.783, Val Accuracy: 63.76%
# Epoch 135, Loss: 0.782, Val Accuracy: 63.86%
# Epoch 136, Loss: 0.776, Val Accuracy: 63.48%
# Epoch 137, Loss: 0.779, Val Accuracy: 64.60%
# Epoch 138, Loss: 0.775, Val Accuracy: 64.24%
# Epoch 139, Loss: 0.774, Val Accuracy: 63.74%
# Epoch 140, Loss: 0.776, Val Accuracy: 64.10%
# Epoch 141, Loss: 0.777, Val Accuracy: 64.24%
# Epoch 142, Loss: 0.771, Val Accuracy: 64.48%
# Epoch 143, Loss: 0.775, Val Accuracy: 63.78%
# Epoch 144, Loss: 0.774, Val Accuracy: 63.66%
# Epoch 145, Loss: 0.772, Val Accuracy: 63.46%
# Epoch 146, Loss: 0.773, Val Accuracy: 63.66%
# Epoch 147, Loss: 0.770, Val Accuracy: 63.66%
# Epoch 148, Loss: 0.772, Val Accuracy: 62.50%
# Epoch 149, Loss: 0.773, Val Accuracy: 64.12%
# Epoch 150, Loss: 0.771, Val Accuracy: 64.14%
# Epoch 151, Loss: 0.770, Val Accuracy: 64.06%
# Epoch 152, Loss: 0.769, Val Accuracy: 62.86%
# Epoch 153, Loss: 0.770, Val Accuracy: 64.56%
# Epoch 154, Loss: 0.766, Val Accuracy: 64.04%
# Epoch 155, Loss: 0.769, Val Accuracy: 64.06%
# Epoch 156, Loss: 0.767, Val Accuracy: 64.08%
# Epoch 157, Loss: 0.767, Val Accuracy: 63.24%
# Epoch 158, Loss: 0.763, Val Accuracy: 64.22%
# Epoch 159, Loss: 0.765, Val Accuracy: 63.70%
# Epoch 160, Loss: 0.770, Val Accuracy: 63.32%
# Epoch 161, Loss: 0.764, Val Accuracy: 64.08%
# Epoch 162, Loss: 0.766, Val Accuracy: 63.18%
# Epoch 163, Loss: 0.765, Val Accuracy: 63.98%
# Epoch 164, Loss: 0.762, Val Accuracy: 63.84%
# Epoch 165, Loss: 0.765, Val Accuracy: 63.26%
# Epoch 166, Loss: 0.767, Val Accuracy: 63.18%
# Epoch 167, Loss: 0.764, Val Accuracy: 64.10%
# Epoch 168, Loss: 0.760, Val Accuracy: 63.44%
# Epoch 169, Loss: 0.762, Val Accuracy: 63.82%
# Epoch 170, Loss: 0.760, Val Accuracy: 63.76%
# Epoch 171, Loss: 0.764, Val Accuracy: 63.96%
# Epoch 172, Loss: 0.764, Val Accuracy: 64.10%
# Epoch 173, Loss: 0.758, Val Accuracy: 64.42%
# Epoch 174, Loss: 0.761, Val Accuracy: 63.28%
# Epoch 175, Loss: 0.761, Val Accuracy: 64.24%
# Epoch 176, Loss: 0.760, Val Accuracy: 64.74%
# Epoch 177, Loss: 0.760, Val Accuracy: 64.16%
# Epoch 178, Loss: 0.758, Val Accuracy: 64.02%
# Epoch 179, Loss: 0.759, Val Accuracy: 63.94%
# Epoch 180, Loss: 0.761, Val Accuracy: 64.10%
# Epoch 181, Loss: 0.759, Val Accuracy: 64.08%
# Epoch 182, Loss: 0.761, Val Accuracy: 63.52%
# Epoch 183, Loss: 0.759, Val Accuracy: 63.70%
# Epoch 184, Loss: 0.758, Val Accuracy: 64.10%
# Epoch 185, Loss: 0.755, Val Accuracy: 64.46%
# Epoch 186, Loss: 0.755, Val Accuracy: 63.76%
# Epoch 187, Loss: 0.758, Val Accuracy: 63.92%
# Epoch 188, Loss: 0.754, Val Accuracy: 64.10%
# Epoch 189, Loss: 0.755, Val Accuracy: 63.68%
# Epoch 190, Loss: 0.758, Val Accuracy: 63.32%
# Epoch 191, Loss: 0.752, Val Accuracy: 64.00%
# Epoch 192, Loss: 0.756, Val Accuracy: 64.16%
# Epoch 193, Loss: 0.755, Val Accuracy: 64.08%
# Epoch 194, Loss: 0.752, Val Accuracy: 63.34%
# Epoch 195, Loss: 0.754, Val Accuracy: 63.80%
# Epoch 196, Loss: 0.754, Val Accuracy: 63.80%
# Epoch 197, Loss: 0.752, Val Accuracy: 64.38%
# Epoch 198, Loss: 0.753, Val Accuracy: 64.16%
# Epoch 199, Loss: 0.755, Val Accuracy: 63.74%
# Epoch 200, Loss: 0.754, Val Accuracy: 63.54%
# Model saved with validation accuracy: 64.98%

# %%
# Plot validation accuracy
plt.figure(figsize=(10, 5))
plt.plot(range(1, num_epochs+1), baseline_val_accuracies)
plt.title('Baseline Model: Validation Accuracy over Epochs')
plt.xlabel('Epoch')
plt.ylabel('Validation Accuracy (%)')
plt.show()

# %% [markdown]
# ### **Part 2: Data Augmentation Model**

# %%
# Custom transforms for data augmentation
class BrightenImage(object):
    def __call__(self, img):
        return torch.clamp(1.1 * img, 0, 1)  # Brighten and clamp to [0, 1]

class DarkenImage(object):
    def __call__(self, img):
        return torch.clamp(0.9 * img, 0, 1)  # Darken and clamp to [0, 1]

# %%
# Normalization transformation to scale to [-1, +1] after augmentations
normalize = transforms.Normalize((0.5, 0.5, 0.5), (0.5, 0.5, 0.5))

# Prepare transformation pipelines for each augmented dataset
transform_original = transforms.Compose([transforms.ToTensor(), normalize])  # Converts to [0, 1] and then normalizes to [-1, +1]
transform_brighten = transforms.Compose([transforms.ToTensor(), BrightenImage(), normalize])  # Apply brightening and then normalize
transform_darken = transforms.Compose([transforms.ToTensor(), DarkenImage(), normalize])  # Apply darkening and then normalize
transform_flip = transforms.Compose([transforms.ToTensor(), transforms.RandomHorizontalFlip(p=1.0), normalize])  # Apply flipping and normalize

# %%
# Load the original CIFAR-10 dataset
trainset_original = torchvision.datasets.CIFAR10(root='./data', train=True, download=True, transform=transform_original)
# Out:
# Files already downloaded and verified

# %%
# Create the three augmented datasets
trainset_brighten = torchvision.datasets.CIFAR10(root='./data', train=True, download=True, transform=transform_brighten)
trainset_darken = torchvision.datasets.CIFAR10(root='./data', train=True, download=True, transform=transform_darken)
trainset_flip = torchvision.datasets.CIFAR10(root='./data', train=True, download=True, transform=transform_flip)
# Out:
# Files already downloaded and verified
# Files already downloaded and verified
# Files already downloaded and verified

# %%
# Merge the original and augmented datasets into one large dataset
augmented_trainset = torch.utils.data.ConcatDataset([trainset_original, trainset_brighten, trainset_darken, trainset_flip])
trainset, _ = torch.utils.data.random_split(augmented_trainset, [train_size*4, val_size*4])

# %%
# Print the total number of images in the trainset
print(f"Total number of images in the trainset: {len(trainset)}")
# Out:
# Total number of images in the trainset: 180000

# %% [markdown]
# **Note:** I am using the same valloader defined above and use in the part-a.

# %%
# Create data loaders
batch_size = 64
augmented_trainloader = torch.utils.data.DataLoader(trainset, batch_size=batch_size, shuffle=True)

# %%
# Create DataLoaders for each augmented dataset
bright_loader = torch.utils.data.DataLoader(trainset_brighten, batch_size=1, shuffle=False)
dark_loader = torch.utils.data.DataLoader(trainset_darken, batch_size=1, shuffle=False)
flip_loader = torch.utils.data.DataLoader(trainset_flip, batch_size=1, shuffle=False)
original_loader = torch.utils.data.DataLoader(trainset_original, batch_size=1, shuffle=False)

# %%
# Get images and labels
bright_image, _ = next(iter(bright_loader))
dark_image, _ = next(iter(dark_loader))
flip_image, _ = next(iter(flip_loader))
original_image, _ = next(iter(original_loader))

# %%
# Visualize a few augmented images
plt.figure(figsize=(10, 10))

plt.subplot(2, 2, 1)
imshow(original_image[0], "Original")

plt.subplot(2, 2, 2)
imshow(bright_image[0], "Brighter")

plt.subplot(2, 2, 3)
imshow(dark_image[0], "Darker")

plt.subplot(2, 2, 4)
imshow(flip_image[0], "Flipped")

plt.tight_layout()
plt.show()

# %%
# Initialize a fresh model, loss function, and optimizer
augmented_model = SimpleCNN(num_classes=10)
criterion = nn.CrossEntropyLoss()
optimizer = optim.Adam(augmented_model.parameters(), lr=0.001)

# %%
# Set up model save path
augmented_model_save_path = os.path.join(model_save_dir, 'q3_augmented_model.pth')

# %%
# Train the model on augmented dataset
num_epochs = 200
augmented_val_accuracies = train_model(augmented_model, augmented_trainloader, valloader, criterion, optimizer, num_epochs, augmented_model_save_path)
# Out:
# Epoch 1, Loss: 1.565, Val Accuracy: 50.50%
# Epoch 2, Loss: 1.259, Val Accuracy: 59.08%
# Epoch 3, Loss: 1.133, Val Accuracy: 62.04%
# Epoch 4, Loss: 1.064, Val Accuracy: 64.50%
# Epoch 5, Loss: 1.021, Val Accuracy: 65.36%
# Epoch 6, Loss: 0.991, Val Accuracy: 67.72%
# Epoch 7, Loss: 0.970, Val Accuracy: 68.16%
# Epoch 8, Loss: 0.953, Val Accuracy: 68.24%
# Epoch 9, Loss: 0.941, Val Accuracy: 67.46%
# Epoch 10, Loss: 0.929, Val Accuracy: 68.22%
# Epoch 11, Loss: 0.919, Val Accuracy: 69.14%
# Epoch 12, Loss: 0.912, Val Accuracy: 68.68%
# Epoch 13, Loss: 0.906, Val Accuracy: 69.06%
# Epoch 14, Loss: 0.898, Val Accuracy: 69.82%
# Epoch 15, Loss: 0.890, Val Accuracy: 70.56%
# Epoch 16, Loss: 0.885, Val Accuracy: 70.68%
# Epoch 17, Loss: 0.881, Val Accuracy: 71.12%
# Epoch 18, Loss: 0.875, Val Accuracy: 70.54%
# Epoch 19, Loss: 0.872, Val Accuracy: 71.38%
# Epoch 20, Loss: 0.866, Val Accuracy: 70.92%
# Epoch 21, Loss: 0.866, Val Accuracy: 70.70%
# Epoch 22, Loss: 0.861, Val Accuracy: 70.94%
# Epoch 23, Loss: 0.858, Val Accuracy: 70.84%
# Epoch 24, Loss: 0.854, Val Accuracy: 71.48%
# Epoch 25, Loss: 0.851, Val Accuracy: 71.62%
# Epoch 26, Loss: 0.849, Val Accuracy: 71.42%
# Epoch 27, Loss: 0.846, Val Accuracy: 71.08%
# Epoch 28, Loss: 0.842, Val Accuracy: 72.02%
# Epoch 29, Loss: 0.841, Val Accuracy: 70.42%
# Epoch 30, Loss: 0.841, Val Accuracy: 70.90%
# Epoch 31, Loss: 0.836, Val Accuracy: 71.78%
# Epoch 32, Loss: 0.835, Val Accuracy: 71.78%
# Epoch 33, Loss: 0.831, Val Accuracy: 71.98%
# Epoch 34, Loss: 0.831, Val Accuracy: 71.32%
# Epoch 35, Loss: 0.829, Val Accuracy: 72.12%
# Epoch 36, Loss: 0.828, Val Accuracy: 71.72%
# Epoch 37, Loss: 0.827, Val Accuracy: 71.56%
# Epoch 38, Loss: 0.825, Val Accuracy: 72.18%
# Epoch 39, Loss: 0.824, Val Accuracy: 71.12%
# Epoch 40, Loss: 0.821, Val Accuracy: 72.30%
# Epoch 41, Loss: 0.820, Val Accuracy: 72.38%
# Epoch 42, Loss: 0.819, Val Accuracy: 70.98%
# Epoch 43, Loss: 0.817, Val Accuracy: 72.68%
# Epoch 44, Loss: 0.817, Val Accuracy: 72.64%
# Epoch 45, Loss: 0.816, Val Accuracy: 72.14%
# Epoch 46, Loss: 0.815, Val Accuracy: 71.86%
# Epoch 47, Loss: 0.813, Val Accuracy: 71.04%
# Epoch 48, Loss: 0.812, Val Accuracy: 73.10%
# Epoch 49, Loss: 0.811, Val Accuracy: 72.18%
# Epoch 50, Loss: 0.810, Val Accuracy: 72.72%
# Epoch 51, Loss: 0.809, Val Accuracy: 72.38%
# Epoch 52, Loss: 0.810, Val Accuracy: 72.20%
# Epoch 53, Loss: 0.809, Val Accuracy: 72.26%
# Epoch 54, Loss: 0.805, Val Accuracy: 71.30%
# Epoch 55, Loss: 0.805, Val Accuracy: 73.56%
# Epoch 56, Loss: 0.805, Val Accuracy: 72.74%
# Epoch 57, Loss: 0.804, Val Accuracy: 72.12%
# Epoch 58, Loss: 0.803, Val Accuracy: 72.12%
# Epoch 59, Loss: 0.803, Val Accuracy: 72.84%
# Epoch 60, Loss: 0.802, Val Accuracy: 72.02%
# Epoch 61, Loss: 0.802, Val Accuracy: 71.48%
# Epoch 62, Loss: 0.801, Val Accuracy: 72.56%
# Epoch 63, Loss: 0.799, Val Accuracy: 72.04%
# Epoch 64, Loss: 0.799, Val Accuracy: 72.74%
# Epoch 65, Loss: 0.798, Val Accuracy: 72.42%
# Epoch 66, Loss: 0.798, Val Accuracy: 72.54%
# Epoch 67, Loss: 0.798, Val Accuracy: 73.50%
# Epoch 68, Loss: 0.797, Val Accuracy: 72.76%
# Epoch 69, Loss: 0.796, Val Accuracy: 72.64%
# Epoch 70, Loss: 0.795, Val Accuracy: 72.70%
# Epoch 71, Loss: 0.794, Val Accuracy: 72.34%
# Epoch 72, Loss: 0.794, Val Accuracy: 73.44%
# Epoch 73, Loss: 0.794, Val Accuracy: 71.24%
# Epoch 74, Loss: 0.793, Val Accuracy: 72.92%
# Epoch 75, Loss: 0.793, Val Accuracy: 71.48%
# Epoch 76, Loss: 0.792, Val Accuracy: 72.44%
# Epoch 77, Loss: 0.792, Val Accuracy: 73.94%
# Epoch 78, Loss: 0.792, Val Accuracy: 73.08%
# Epoch 79, Loss: 0.792, Val Accuracy: 72.44%
# Epoch 80, Loss: 0.790, Val Accuracy: 73.62%
# Epoch 81, Loss: 0.792, Val Accuracy: 73.30%
# Epoch 82, Loss: 0.788, Val Accuracy: 73.32%
# Epoch 83, Loss: 0.789, Val Accuracy: 72.98%
# Epoch 84, Loss: 0.788, Val Accuracy: 73.34%
# Epoch 85, Loss: 0.789, Val Accuracy: 73.52%
# Epoch 86, Loss: 0.788, Val Accuracy: 73.72%
# Epoch 87, Loss: 0.787, Val Accuracy: 72.76%
# Epoch 88, Loss: 0.787, Val Accuracy: 72.60%
# Epoch 89, Loss: 0.786, Val Accuracy: 72.98%
# Epoch 90, Loss: 0.787, Val Accuracy: 73.08%
# Epoch 91, Loss: 0.786, Val Accuracy: 73.68%
# Epoch 92, Loss: 0.786, Val Accuracy: 72.52%
# Epoch 93, Loss: 0.786, Val Accuracy: 72.92%
# Epoch 94, Loss: 0.786, Val Accuracy: 72.54%
# Epoch 95, Loss: 0.784, Val Accuracy: 74.04%
# Epoch 96, Loss: 0.785, Val Accuracy: 73.42%
# Epoch 97, Loss: 0.784, Val Accuracy: 72.96%
# Epoch 98, Loss: 0.783, Val Accuracy: 73.66%
# Epoch 99, Loss: 0.783, Val Accuracy: 73.70%
# Epoch 100, Loss: 0.783, Val Accuracy: 73.08%
# Epoch 101, Loss: 0.782, Val Accuracy: 73.06%
# Epoch 102, Loss: 0.782, Val Accuracy: 73.62%
# Epoch 103, Loss: 0.782, Val Accuracy: 72.88%
# Epoch 104, Loss: 0.782, Val Accuracy: 72.10%
# Epoch 105, Loss: 0.781, Val Accuracy: 72.18%
# Epoch 106, Loss: 0.781, Val Accuracy: 73.46%
# Epoch 107, Loss: 0.781, Val Accuracy: 74.02%
# Epoch 108, Loss: 0.781, Val Accuracy: 72.94%
# Epoch 109, Loss: 0.780, Val Accuracy: 72.86%
# Epoch 110, Loss: 0.779, Val Accuracy: 72.64%
# Epoch 111, Loss: 0.781, Val Accuracy: 73.22%
# Epoch 112, Loss: 0.779, Val Accuracy: 72.50%
# Epoch 113, Loss: 0.780, Val Accuracy: 73.68%
# Epoch 114, Loss: 0.779, Val Accuracy: 73.08%
# Epoch 115, Loss: 0.779, Val Accuracy: 74.06%
# Epoch 116, Loss: 0.777, Val Accuracy: 73.66%
# Epoch 117, Loss: 0.778, Val Accuracy: 73.66%
# Epoch 118, Loss: 0.778, Val Accuracy: 73.20%
# Epoch 119, Loss: 0.777, Val Accuracy: 72.68%
# Epoch 120, Loss: 0.779, Val Accuracy: 73.96%
# Epoch 121, Loss: 0.776, Val Accuracy: 73.34%
# Epoch 122, Loss: 0.778, Val Accuracy: 73.66%
# Epoch 123, Loss: 0.778, Val Accuracy: 73.24%
# Epoch 124, Loss: 0.778, Val Accuracy: 73.06%
# Epoch 125, Loss: 0.776, Val Accuracy: 74.24%
# Epoch 126, Loss: 0.777, Val Accuracy: 74.64%
# Epoch 127, Loss: 0.775, Val Accuracy: 73.70%
# Epoch 128, Loss: 0.776, Val Accuracy: 73.76%
# Epoch 129, Loss: 0.775, Val Accuracy: 73.62%
# Epoch 130, Loss: 0.776, Val Accuracy: 73.10%
# Epoch 131, Loss: 0.776, Val Accuracy: 72.46%
# Epoch 132, Loss: 0.775, Val Accuracy: 72.80%
# Epoch 133, Loss: 0.775, Val Accuracy: 73.38%
# Epoch 134, Loss: 0.775, Val Accuracy: 74.28%
# Epoch 135, Loss: 0.775, Val Accuracy: 73.64%
# Epoch 136, Loss: 0.775, Val Accuracy: 73.62%
# Epoch 137, Loss: 0.774, Val Accuracy: 73.66%
# Epoch 138, Loss: 0.776, Val Accuracy: 72.44%
# Epoch 139, Loss: 0.774, Val Accuracy: 73.96%
# Epoch 140, Loss: 0.775, Val Accuracy: 74.52%
# Epoch 141, Loss: 0.773, Val Accuracy: 73.90%
# Epoch 142, Loss: 0.774, Val Accuracy: 73.46%
# Epoch 143, Loss: 0.774, Val Accuracy: 74.60%
# Epoch 144, Loss: 0.773, Val Accuracy: 73.54%
# Epoch 145, Loss: 0.773, Val Accuracy: 74.32%
# Epoch 146, Loss: 0.772, Val Accuracy: 72.84%
# Epoch 147, Loss: 0.773, Val Accuracy: 74.30%
# Epoch 148, Loss: 0.773, Val Accuracy: 73.24%
# Epoch 149, Loss: 0.772, Val Accuracy: 73.98%
# Epoch 150, Loss: 0.773, Val Accuracy: 74.28%
# Epoch 151, Loss: 0.771, Val Accuracy: 73.92%
# Epoch 152, Loss: 0.772, Val Accuracy: 74.18%
# Epoch 153, Loss: 0.773, Val Accuracy: 73.24%
# Epoch 154, Loss: 0.771, Val Accuracy: 73.76%
# Epoch 155, Loss: 0.771, Val Accuracy: 73.78%
# Epoch 156, Loss: 0.771, Val Accuracy: 74.14%
# Epoch 157, Loss: 0.771, Val Accuracy: 73.42%
# Epoch 158, Loss: 0.771, Val Accuracy: 74.42%
# Epoch 159, Loss: 0.770, Val Accuracy: 74.18%
# Epoch 160, Loss: 0.771, Val Accuracy: 73.92%
# Epoch 161, Loss: 0.770, Val Accuracy: 73.58%
# Epoch 162, Loss: 0.771, Val Accuracy: 73.18%
# Epoch 163, Loss: 0.770, Val Accuracy: 74.44%
# Epoch 164, Loss: 0.769, Val Accuracy: 74.52%
# Epoch 165, Loss: 0.771, Val Accuracy: 73.66%
# Epoch 166, Loss: 0.770, Val Accuracy: 74.14%
# Epoch 167, Loss: 0.770, Val Accuracy: 73.98%
# Epoch 168, Loss: 0.770, Val Accuracy: 73.94%
# Epoch 169, Loss: 0.770, Val Accuracy: 74.36%
# Epoch 170, Loss: 0.770, Val Accuracy: 74.24%
# Epoch 171, Loss: 0.769, Val Accuracy: 72.72%
# Epoch 172, Loss: 0.769, Val Accuracy: 74.24%
# Epoch 173, Loss: 0.769, Val Accuracy: 73.80%
# Epoch 174, Loss: 0.769, Val Accuracy: 74.62%
# Epoch 175, Loss: 0.769, Val Accuracy: 74.18%
# Epoch 176, Loss: 0.768, Val Accuracy: 73.28%
# Epoch 177, Loss: 0.769, Val Accuracy: 73.70%
# Epoch 178, Loss: 0.769, Val Accuracy: 74.28%
# Epoch 179, Loss: 0.768, Val Accuracy: 73.84%
# Epoch 180, Loss: 0.768, Val Accuracy: 74.38%
# Epoch 181, Loss: 0.769, Val Accuracy: 74.26%
# Epoch 182, Loss: 0.769, Val Accuracy: 74.22%
# Epoch 183, Loss: 0.767, Val Accuracy: 71.68%
# Epoch 184, Loss: 0.769, Val Accuracy: 74.48%
# Epoch 185, Loss: 0.767, Val Accuracy: 74.60%
# Epoch 186, Loss: 0.768, Val Accuracy: 74.46%
# Epoch 187, Loss: 0.769, Val Accuracy: 74.24%
# Epoch 188, Loss: 0.767, Val Accuracy: 73.10%
# Epoch 189, Loss: 0.767, Val Accuracy: 74.12%
# Epoch 190, Loss: 0.767, Val Accuracy: 74.12%
# Epoch 191, Loss: 0.766, Val Accuracy: 73.70%
# Epoch 192, Loss: 0.768, Val Accuracy: 74.56%
# Epoch 193, Loss: 0.767, Val Accuracy: 73.90%
# Epoch 194, Loss: 0.767, Val Accuracy: 73.42%
# Epoch 195, Loss: 0.767, Val Accuracy: 73.30%
# Epoch 196, Loss: 0.767, Val Accuracy: 73.94%
# Epoch 197, Loss: 0.768, Val Accuracy: 73.18%
# Epoch 198, Loss: 0.767, Val Accuracy: 74.46%
# Epoch 199, Loss: 0.767, Val Accuracy: 73.98%
# Epoch 200, Loss: 0.765, Val Accuracy: 74.54%
# Model saved with validation accuracy: 74.64%

# %%
# Plot validation accuracy for both models
plt.figure(figsize=(10, 5))
plt.plot(range(1, num_epochs+1), baseline_val_accuracies, label='Baseline Model')
plt.plot(range(1, num_epochs+1), augmented_val_accuracies, label='Augmented Model')
plt.title('Validation Accuracy over Epochs')
plt.xlabel('Epoch')
plt.ylabel('Validation Accuracy (%)')
plt.legend()
plt.show()

# %% [markdown]
# ## **Problem 4: Self-Supervised Learning via Pretext Tasks [4 points]**
#
# **Scenario:** CIFAR10 classification with limited labeled data (50 examples per class, 500 total)
#
# **Pretext Task**
#
# 1. Set aside 500 examples from the training set
# 2. Use remaining 49,500 training examples as unlabeled data
# 3. Create three classes:
#    - Class 0: Original unlabeled images
#    - Class 1: Vertically flipped images
#    - Class 2: 90-degree counter-clockwise rotated images
# 4. Train network:
#    - Use same setup/architecture as Problem 3
#    - Run about 100 epochs
#    - Store model parameters
#
# **Baseline Classifier**
#
# 1. Train from scratch on 500 CIFAR10 dataset
# 2. Use original 10-class classification
# 3. Use same architecture/setup as pretext task
# 4. Choose reasonable initializer (e.g., He initializer)
# 5. Use test set (10,000 examples) as validation set
# 6. Record accuracy values every 100 epochs
#
# **Transfer Learning Task**
#
# 1. Train on same 500 CIFAR10 dataset
# 2. Reload weights from pretext network
# 3. Transfer all parameters except final softmax layer
# 4. Randomly initialize last layer with He initializer
# 5. Adjust learning rates:
#    - Transferred layers: 1e-5 or 1e-6
#    - Last softmax layer: 1e-3 (default)
# 6. Report test accuracy every 100 epochs
#
# **Comparison**
#
# 1. Run both experiments for 10,000 epochs
# 2. Record validation (test) accuracy every 100 epochs
# 3. Draw two graphs comparing baseline and finetuning methods
# 4. Expect improvement from self-supervised features

# %%
# Define transforms
transform = transforms.Compose([
    transforms.ToTensor(),
    transforms.Normalize((0.5, 0.5, 0.5), (0.5, 0.5, 0.5))
])

# %%
# Load CIFAR10 dataset
full_trainset = torchvision.datasets.CIFAR10(root='./data', train=True, download=True, transform=transform)
# Out:
# Downloading https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz to ./data/cifar-10-python.tar.gz
# 100%|██████████| 170498071/170498071 [00:03<00:00, 48055847.00it/s]
# Extracting ./data/cifar-10-python.tar.gz to ./data

# %%
# Create a subset with 50 examples per class (500 total)
indices = []
examples_per_class = 50
for class_id in range(10):
    class_indices = (torch.tensor(full_trainset.targets) == class_id).nonzero().squeeze()
    indices.extend(class_indices[-examples_per_class:].tolist())  # Take the last 50 examples of each class

# %%
# Create the subset
trainset = Subset(full_trainset, indices)

# %%
# Create DataLoader
batch_size = 128
trainloader = DataLoader(trainset, batch_size=batch_size, shuffle=True, num_workers=2)

# %%
print(f"Number of training examples: {len(trainset)}")
# Out:
# Number of training examples: 500

# %% [markdown]
# ### **Pretext Task**

# %%
# Create the pretext dataset
class PretextDataset(Dataset):
    def __init__(self, dataset):
        self.dataset = dataset

    def __len__(self):
        return len(self.dataset) * 3

    def __getitem__(self, idx):
        original_idx = idx % len(self.dataset)
        img, _ = self.dataset[original_idx]
        
        if idx < len(self.dataset):
            # Class 0: Original image
            return img, 0
        elif idx < 2 * len(self.dataset):
            # Class 1: Vertically flipped image
            return transforms.functional.vflip(img), 1
        else:
            # Class 2: 90 degree counter-clockwise rotated image
            return transforms.functional.rotate(img, 90), 2

# %%
# Create the pretext dataset using the remaining 49,500 examples
remaining_indices = list(set(range(len(full_trainset))) - set(indices))
remaining_dataset = Subset(full_trainset, remaining_indices)
pretext_dataset = PretextDataset(remaining_dataset)
pretext_loader = DataLoader(pretext_dataset, batch_size=128, shuffle=True, num_workers=2)

# %%
# Number of Images in Pretext Dataset
print(f"Number of images in pretext_dataset: {len(pretext_dataset)}")
# Out:
# Number of images in pretext_dataset: 148500

# %%
q4_pretext_model = SimpleCNN(num_classes=3)

# %%
# Training setup
q4_pretext_model = q4_pretext_model.to(device)
criterion = nn.CrossEntropyLoss()
optimizer = optim.Adam(q4_pretext_model.parameters(), lr=0.001)

# %%
# Training loop
num_epochs = 100
for epoch in range(num_epochs):
    q4_pretext_model.train()
    running_loss = 0.0
    correct = 0
    total = 0
    for i, data in enumerate(pretext_loader, 0):
        inputs, labels = data[0].to(device), data[1].to(device)
        
        optimizer.zero_grad()
        outputs = q4_pretext_model(inputs)
        loss = criterion(outputs, labels)
        loss.backward()
        optimizer.step()
        
        running_loss += loss.item()
        _, predicted = outputs.max(1)
        total += labels.size(0)
        correct += predicted.eq(labels).sum().item()
        
    epoch_loss = running_loss / len(pretext_loader)
    epoch_acc = 100. * correct / total
    print(f'Epoch {epoch + 1}, Loss: {epoch_loss:.3f}, Accuracy: {epoch_acc:.2f}%')

print('Finished Training')
# Out:
# Epoch 1, Loss: 0.942, Accuracy: 53.66%
# Epoch 2, Loss: 0.824, Accuracy: 61.43%
# Epoch 3, Loss: 0.769, Accuracy: 65.14%
# Epoch 4, Loss: 0.736, Accuracy: 67.26%
# Epoch 5, Loss: 0.713, Accuracy: 68.43%
# Epoch 6, Loss: 0.697, Accuracy: 69.30%
# Epoch 7, Loss: 0.684, Accuracy: 69.99%
# Epoch 8, Loss: 0.673, Accuracy: 70.65%
# Epoch 9, Loss: 0.664, Accuracy: 71.02%
# Epoch 10, Loss: 0.656, Accuracy: 71.43%
# Epoch 11, Loss: 0.649, Accuracy: 71.85%
# Epoch 12, Loss: 0.642, Accuracy: 72.06%
# Epoch 13, Loss: 0.637, Accuracy: 72.50%
# Epoch 14, Loss: 0.632, Accuracy: 72.63%
# Epoch 15, Loss: 0.628, Accuracy: 72.76%
# Epoch 16, Loss: 0.622, Accuracy: 73.01%
# Epoch 17, Loss: 0.620, Accuracy: 73.25%
# Epoch 18, Loss: 0.616, Accuracy: 73.48%
# Epoch 19, Loss: 0.613, Accuracy: 73.59%
# Epoch 20, Loss: 0.609, Accuracy: 73.89%
# Epoch 21, Loss: 0.605, Accuracy: 73.99%
# Epoch 22, Loss: 0.604, Accuracy: 74.08%
# Epoch 23, Loss: 0.601, Accuracy: 74.17%
# Epoch 24, Loss: 0.597, Accuracy: 74.37%
# Epoch 25, Loss: 0.596, Accuracy: 74.49%
# Epoch 26, Loss: 0.593, Accuracy: 74.49%
# Epoch 27, Loss: 0.591, Accuracy: 74.63%
# Epoch 28, Loss: 0.590, Accuracy: 74.69%
# Epoch 29, Loss: 0.587, Accuracy: 75.00%
# Epoch 30, Loss: 0.587, Accuracy: 74.87%
# Epoch 31, Loss: 0.584, Accuracy: 74.92%
# Epoch 32, Loss: 0.582, Accuracy: 75.06%
# Epoch 33, Loss: 0.582, Accuracy: 75.25%
# Epoch 34, Loss: 0.579, Accuracy: 75.26%
# Epoch 35, Loss: 0.578, Accuracy: 75.30%
# Epoch 36, Loss: 0.576, Accuracy: 75.43%
# Epoch 37, Loss: 0.576, Accuracy: 75.45%
# Epoch 38, Loss: 0.575, Accuracy: 75.46%
# Epoch 39, Loss: 0.573, Accuracy: 75.51%
# Epoch 40, Loss: 0.571, Accuracy: 75.66%
# Epoch 41, Loss: 0.571, Accuracy: 75.62%
# Epoch 42, Loss: 0.569, Accuracy: 75.78%
# Epoch 43, Loss: 0.568, Accuracy: 75.79%
# Epoch 44, Loss: 0.567, Accuracy: 75.87%
# Epoch 45, Loss: 0.566, Accuracy: 75.97%
# Epoch 46, Loss: 0.566, Accuracy: 75.98%
# Epoch 47, Loss: 0.566, Accuracy: 75.92%
# Epoch 48, Loss: 0.563, Accuracy: 76.05%
# Epoch 49, Loss: 0.563, Accuracy: 76.11%
# Epoch 50, Loss: 0.561, Accuracy: 76.22%
# Epoch 51, Loss: 0.562, Accuracy: 76.14%
# Epoch 52, Loss: 0.560, Accuracy: 76.31%
# Epoch 53, Loss: 0.560, Accuracy: 76.20%
# Epoch 54, Loss: 0.559, Accuracy: 76.27%
# Epoch 55, Loss: 0.558, Accuracy: 76.31%
# Epoch 56, Loss: 0.557, Accuracy: 76.35%
# Epoch 57, Loss: 0.558, Accuracy: 76.30%
# Epoch 58, Loss: 0.557, Accuracy: 76.33%
# Epoch 59, Loss: 0.554, Accuracy: 76.47%
# Epoch 60, Loss: 0.556, Accuracy: 76.50%
# Epoch 61, Loss: 0.555, Accuracy: 76.47%
# Epoch 62, Loss: 0.555, Accuracy: 76.62%
# Epoch 63, Loss: 0.554, Accuracy: 76.53%
# Epoch 64, Loss: 0.552, Accuracy: 76.56%
# Epoch 65, Loss: 0.553, Accuracy: 76.53%
# Epoch 66, Loss: 0.550, Accuracy: 76.60%
# Epoch 67, Loss: 0.552, Accuracy: 76.64%
# Epoch 68, Loss: 0.550, Accuracy: 76.69%
# Epoch 69, Loss: 0.551, Accuracy: 76.75%
# Epoch 70, Loss: 0.550, Accuracy: 76.73%
# Epoch 71, Loss: 0.550, Accuracy: 76.71%
# Epoch 72, Loss: 0.548, Accuracy: 76.73%
# Epoch 73, Loss: 0.549, Accuracy: 76.85%
# Epoch 74, Loss: 0.548, Accuracy: 76.77%
# Epoch 75, Loss: 0.549, Accuracy: 76.73%
# Epoch 76, Loss: 0.548, Accuracy: 76.76%
# Epoch 77, Loss: 0.546, Accuracy: 76.96%
# Epoch 78, Loss: 0.545, Accuracy: 76.94%
# Epoch 79, Loss: 0.545, Accuracy: 77.00%
# Epoch 80, Loss: 0.545, Accuracy: 76.98%
# Epoch 81, Loss: 0.544, Accuracy: 77.06%
# Epoch 82, Loss: 0.544, Accuracy: 76.96%
# Epoch 83, Loss: 0.544, Accuracy: 76.90%
# Epoch 84, Loss: 0.544, Accuracy: 77.00%
# Epoch 85, Loss: 0.543, Accuracy: 76.99%
# Epoch 86, Loss: 0.543, Accuracy: 77.05%
# Epoch 87, Loss: 0.544, Accuracy: 76.89%
# Epoch 88, Loss: 0.542, Accuracy: 76.94%
# Epoch 89, Loss: 0.542, Accuracy: 77.04%
# Epoch 90, Loss: 0.541, Accuracy: 77.10%
# Epoch 91, Loss: 0.540, Accuracy: 77.20%
# Epoch 92, Loss: 0.540, Accuracy: 77.20%
# Epoch 93, Loss: 0.540, Accuracy: 77.10%
# Epoch 94, Loss: 0.541, Accuracy: 77.14%
# Epoch 95, Loss: 0.539, Accuracy: 77.23%
# Epoch 96, Loss: 0.539, Accuracy: 77.21%
# Epoch 97, Loss: 0.540, Accuracy: 77.15%
# Epoch 98, Loss: 0.538, Accuracy: 77.19%
# Epoch 99, Loss: 0.538, Accuracy: 77.27%
# Epoch 100, Loss: 0.539, Accuracy: 77.34%
# Finished Training

# %%
# Save the model
torch.save(q4_pretext_model.state_dict(), '/kaggle/working/model/q4_pretext_model.pth')
print('Model saved as q4_pretext_model.pth')
# Out:
# Model saved as q4_pretext_model.pth

# %% [markdown]
# ### **Baseline Task**

# %%
# Create the test set (which we'll use as validation)
testset = torchvision.datasets.CIFAR10(root='./data', train=False, download=True, transform=transform)
testloader = DataLoader(testset, batch_size=100, shuffle=False, num_workers=2)
# Out:
# Files already downloaded and verified

# %%
# Use the existing SimpleCNN model
q4_baseline_model = SimpleCNN(num_classes=10)  # 10 classes for CIFAR10
q4_baseline_model = q4_baseline_model.to(device)

# %%
# Loss and optimizer
criterion = nn.CrossEntropyLoss()
optimizer = optim.Adam(q4_baseline_model.parameters(), lr=0.001)

# %%
# Training loop
num_epochs = 10000
baseline_accuracies = []
training_losses = []

for epoch in range(num_epochs):
    q4_baseline_model.train()
    running_loss = 0.0
    for inputs, labels in trainloader:
        inputs, labels = inputs.to(device), labels.to(device)
        optimizer.zero_grad()
        outputs = q4_baseline_model(inputs)
        loss = criterion(outputs, labels)
        loss.backward()
        optimizer.step()
        running_loss += loss.item()
    
    # Calculate average training loss for this epoch
    avg_train_loss = running_loss / len(trainloader)
    training_losses.append(avg_train_loss)
    
    # Evaluate on test set (used as validation) every 100 epochs
    if (epoch + 1) % 100 == 0:
        q4_baseline_model.eval()
        correct = 0
        total = 0
        with torch.no_grad():
            for inputs, labels in testloader:
                inputs, labels = inputs.to(device), labels.to(device)
                outputs = q4_baseline_model(inputs)
                _, predicted = outputs.max(1)
                total += labels.size(0)
                correct += predicted.eq(labels).sum().item()
        
        accuracy = 100 * correct / total
        baseline_accuracies.append(accuracy)
        print(f'Epoch [{epoch+1}/{num_epochs}], Training Loss: {avg_train_loss:.4f}, Validation Accuracy: {accuracy:.2f}%')

print('Finished Training')
# Out:
# Epoch [100/10000], Training Loss: 0.5640, Validation Accuracy: 26.98%
# Epoch [200/10000], Training Loss: 0.0565, Validation Accuracy: 27.40%
# Epoch [300/10000], Training Loss: 0.0112, Validation Accuracy: 27.52%
# Epoch [400/10000], Training Loss: 0.0040, Validation Accuracy: 27.57%
# Epoch [500/10000], Training Loss: 0.0020, Validation Accuracy: 27.53%
# Epoch [600/10000], Training Loss: 0.0011, Validation Accuracy: 27.57%
# Epoch [700/10000], Training Loss: 0.0007, Validation Accuracy: 27.40%
# Epoch [800/10000], Training Loss: 0.0005, Validation Accuracy: 27.59%
# Epoch [900/10000], Training Loss: 0.0003, Validation Accuracy: 27.68%
# Epoch [1000/10000], Training Loss: 0.0002, Validation Accuracy: 27.78%
# Epoch [1100/10000], Training Loss: 0.0002, Validation Accuracy: 27.79%
# Epoch [1200/10000], Training Loss: 0.0001, Validation Accuracy: 27.76%
# Epoch [1300/10000], Training Loss: 0.0001, Validation Accuracy: 27.79%
# Epoch [1400/10000], Training Loss: 0.0001, Validation Accuracy: 27.82%
# Epoch [1500/10000], Training Loss: 0.0001, Validation Accuracy: 27.82%
# Epoch [1600/10000], Training Loss: 0.0000, Validation Accuracy: 27.89%
# Epoch [1700/10000], Training Loss: 0.0000, Validation Accuracy: 27.93%
# Epoch [1800/10000], Training Loss: 0.0000, Validation Accuracy: 27.96%
# Epoch [1900/10000], Training Loss: 0.0000, Validation Accuracy: 28.01%
# Epoch [2000/10000], Training Loss: 0.0000, Validation Accuracy: 28.00%
# Epoch [2100/10000], Training Loss: 0.0000, Validation Accuracy: 27.98%
# Epoch [2200/10000], Training Loss: 0.0000, Validation Accuracy: 27.94%
# Epoch [2300/10000], Training Loss: 0.0000, Validation Accuracy: 27.88%
# Epoch [2400/10000], Training Loss: 0.0000, Validation Accuracy: 27.92%
# Epoch [2500/10000], Training Loss: 0.0000, Validation Accuracy: 27.88%
# Epoch [2600/10000], Training Loss: 0.0000, Validation Accuracy: 27.95%
# Epoch [2700/10000], Training Loss: 0.0000, Validation Accuracy: 27.95%
# Epoch [2800/10000], Training Loss: 0.0000, Validation Accuracy: 27.98%
# Epoch [2900/10000], Training Loss: 0.0000, Validation Accuracy: 27.99%
# Epoch [3000/10000], Training Loss: 0.0000, Validation Accuracy: 27.96%
# Epoch [3100/10000], Training Loss: 0.0000, Validation Accuracy: 27.97%
# Epoch [3200/10000], Training Loss: 0.0000, Validation Accuracy: 27.99%
# Epoch [3300/10000], Training Loss: 0.0000, Validation Accuracy: 28.03%
# Epoch [3400/10000], Training Loss: 0.0000, Validation Accuracy: 27.97%
# Epoch [3500/10000], Training Loss: 0.0000, Validation Accuracy: 28.03%
# Epoch [3600/10000], Training Loss: 0.0000, Validation Accuracy: 28.07%
# Epoch [3700/10000], Training Loss: 0.0000, Validation Accuracy: 28.08%
# Epoch [3800/10000], Training Loss: 0.0000, Validation Accuracy: 28.09%
# Epoch [3900/10000], Training Loss: 0.0000, Validation Accuracy: 28.05%
# Epoch [4000/10000], Training Loss: 0.0000, Validation Accuracy: 27.96%
# Epoch [4100/10000], Training Loss: 0.0000, Validation Accuracy: 27.91%
# Epoch [4200/10000], Training Loss: 0.0000, Validation Accuracy: 27.90%
# Epoch [4300/10000], Training Loss: 0.0000, Validation Accuracy: 27.99%
# Epoch [4400/10000], Training Loss: 0.0000, Validation Accuracy: 28.03%
# Epoch [4500/10000], Training Loss: 0.0000, Validation Accuracy: 27.97%
# Epoch [4600/10000], Training Loss: 0.0000, Validation Accuracy: 27.94%
# Epoch [4700/10000], Training Loss: 0.0000, Validation Accuracy: 27.94%
# Epoch [4800/10000], Training Loss: 0.0000, Validation Accuracy: 27.84%
# Epoch [4900/10000], Training Loss: 0.0000, Validation Accuracy: 27.97%
# Epoch [5000/10000], Training Loss: 0.0000, Validation Accuracy: 28.00%
# Epoch [5100/10000], Training Loss: 0.0000, Validation Accuracy: 27.90%
# Epoch [5200/10000], Training Loss: 0.0000, Validation Accuracy: 27.87%
# Epoch [5300/10000], Training Loss: 0.0000, Validation Accuracy: 27.92%
# Epoch [5400/10000], Training Loss: 0.0000, Validation Accuracy: 27.60%
# Epoch [5500/10000], Training Loss: 0.0000, Validation Accuracy: 27.54%
# Epoch [5600/10000], Training Loss: 0.0000, Validation Accuracy: 27.39%
# Epoch [5700/10000], Training Loss: 0.0000, Validation Accuracy: 27.61%
# Epoch [5800/10000], Training Loss: 0.0000, Validation Accuracy: 27.58%
# Epoch [5900/10000], Training Loss: 0.0000, Validation Accuracy: 27.66%
# Epoch [6000/10000], Training Loss: 0.0000, Validation Accuracy: 27.68%
# Epoch [6100/10000], Training Loss: 0.0000, Validation Accuracy: 27.75%
# Epoch [6200/10000], Training Loss: 0.0000, Validation Accuracy: 27.71%
# Epoch [6300/10000], Training Loss: 0.0000, Validation Accuracy: 27.70%
# Epoch [6400/10000], Training Loss: 0.0000, Validation Accuracy: 27.75%
# Epoch [6500/10000], Training Loss: 0.0000, Validation Accuracy: 27.74%
# Epoch [6600/10000], Training Loss: 0.0000, Validation Accuracy: 27.73%
# Epoch [6700/10000], Training Loss: 0.0000, Validation Accuracy: 27.72%
# Epoch [6800/10000], Training Loss: 0.0000, Validation Accuracy: 27.72%
# Epoch [6900/10000], Training Loss: 0.0000, Validation Accuracy: 27.69%
# Epoch [7000/10000], Training Loss: 0.0000, Validation Accuracy: 27.71%
# Epoch [7100/10000], Training Loss: 0.0000, Validation Accuracy: 27.73%
# Epoch [7200/10000], Training Loss: 0.0000, Validation Accuracy: 27.77%
# Epoch [7300/10000], Training Loss: 0.0000, Validation Accuracy: 27.78%
# Epoch [7400/10000], Training Loss: 0.0000, Validation Accuracy: 27.76%
# Epoch [7500/10000], Training Loss: 0.0000, Validation Accuracy: 27.84%
# Epoch [7600/10000], Training Loss: 0.0000, Validation Accuracy: 27.86%
# Epoch [7700/10000], Training Loss: 0.0000, Validation Accuracy: 27.88%
# Epoch [7800/10000], Training Loss: 0.0000, Validation Accuracy: 27.89%
# Epoch [7900/10000], Training Loss: 0.0000, Validation Accuracy: 27.86%
# Epoch [8000/10000], Training Loss: 0.0000, Validation Accuracy: 27.89%
# Epoch [8100/10000], Training Loss: 0.0000, Validation Accuracy: 27.90%
# Epoch [8200/10000], Training Loss: 0.0000, Validation Accuracy: 27.89%
# Epoch [8300/10000], Training Loss: 0.0000, Validation Accuracy: 27.89%
# Epoch [8400/10000], Training Loss: 0.0000, Validation Accuracy: 27.84%
# Epoch [8500/10000], Training Loss: 0.0000, Validation Accuracy: 27.84%
# Epoch [8600/10000], Training Loss: 0.0000, Validation Accuracy: 27.90%
# Epoch [8700/10000], Training Loss: 0.0000, Validation Accuracy: 27.88%
# Epoch [8800/10000], Training Loss: 0.0000, Validation Accuracy: 27.83%
# Epoch [8900/10000], Training Loss: 0.0000, Validation Accuracy: 27.83%
# Epoch [9000/10000], Training Loss: 0.0000, Validation Accuracy: 27.86%
# Epoch [9100/10000], Training Loss: 0.0000, Validation Accuracy: 27.84%
# Epoch [9200/10000], Training Loss: 0.0000, Validation Accuracy: 27.81%
# Epoch [9300/10000], Training Loss: 0.0000, Validation Accuracy: 27.81%
# Epoch [9400/10000], Training Loss: 0.0000, Validation Accuracy: 27.76%
# Epoch [9500/10000], Training Loss: 0.0000, Validation Accuracy: 27.76%
# Epoch [9600/10000], Training Loss: 0.0000, Validation Accuracy: 27.81%
# Epoch [9700/10000], Training Loss: 0.0000, Validation Accuracy: 27.84%
# Epoch [9800/10000], Training Loss: 0.0000, Validation Accuracy: 27.88%
# Epoch [9900/10000], Training Loss: 0.0000, Validation Accuracy: 27.94%
# Epoch [10000/10000], Training Loss: 0.0000, Validation Accuracy: 27.91%
# Finished Training

# %%
# Plot the accuracies
plt.figure(figsize=(10, 5))
plt.plot(range(100, num_epochs + 1, 100), baseline_accuracies)
plt.title('Validation Accuracy over Epochs')
plt.xlabel('Epochs')
plt.ylabel('Accuracy (%)')
plt.yticks([i for i in range(20, 40, 2)])
plt.grid(True)
plt.show()

# %%
# Save the model
torch.save(q4_baseline_model.state_dict(), '/kaggle/working/model/q4_baseline_model.pth')
print('Model saved as q4_baseline_model.pth')
# Out:
# Model saved as q4_baseline_model.pth

# %% [markdown]
# ### **Self Learning Task**

# %%
def load_pretrained_weights(model, pretrained_path):
    model.load_state_dict(torch.load(pretrained_path))
    model.fc2 = nn.Linear(20, 10)
    
    nn.init.kaiming_normal_(model.fc2.weight, nonlinearity='relu')
    if model.fc2.bias is not None:
        nn.init.constant_(model.fc2.bias, 0)

# %%
# Function to prepare the optimizer with different learning rates for layers
def create_optimizer(model):
    new_params = ['fc2.weight', 'fc2.bias']
    new_params_list = []
    old_params_list = []

    # Separate parameters for the classifier and other layers
    for name, param in model.named_parameters():
        if name in new_params:
            new_params_list.append(param)
        else:
            old_params_list.append(param)
    
    # Define optimizer with different learning rates
    optimizer = optim.Adam([
        {'params': old_params_list, 'lr': 1e-6},  # Small LR for pretrained layers
        {'params': new_params_list, 'lr': 0.001}  # Higher LR for new layers
    ])
    
    return optimizer

# %%
# Instantiate the model
transfer_model = SimpleCNN(num_classes=3)

# %%
# Load pretrained weights and initialize new layers
load_pretrained_weights(transfer_model, '/kaggle/working/model/q4_pretext_model.pth')
# Out:
# /tmp/ipykernel_30/803301260.py:2: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   model.load_state_dict(torch.load(pretrained_path))

# %%
transfer_model.to(device)
# Out:
# SimpleCNN(
#   (conv1): Conv2d(3, 10, kernel_size=(5, 5), stride=(1, 1))
#   (pool): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   (conv2): Conv2d(10, 10, kernel_size=(5, 5), stride=(1, 1))
#   (fc1): Linear(in_features=250, out_features=20, bias=True)
#   (fc2): Linear(in_features=20, out_features=10, bias=True)
# )

# %%
# Prepare optimizer with different learning rates
optimizer = create_optimizer(transfer_model)

# %%
# Function to train and validate the model
def train_model(model, train_loader, test_loader, optimizer, num_epochs=10000):
    criterion = nn.CrossEntropyLoss()
    finetuning_accuracies = []
    
    for epoch in range(num_epochs):
        model.train()
        running_loss = 0.0
        
        # Training phase
        for inputs, labels in train_loader:
            inputs, labels = inputs.to(device), labels.to(device)
            optimizer.zero_grad()
            
            outputs = model(inputs)
            loss = criterion(outputs, labels)
            loss.backward()
            optimizer.step()
            
            running_loss += loss.item()
        
        # Calculate average loss for the epoch
        avg_train_loss = running_loss / len(train_loader)

        # Validation phase every 100 epochs
        if (epoch + 1) % 100 == 0:
            model.eval()
            correct, total = 0, 0
            running_val_loss = 0.0
            
            with torch.no_grad():
                for inputs, labels in test_loader:
                    inputs, labels = inputs.to(device), labels.to(device)
                    outputs = model(inputs)
                    
                    # Compute validation loss
                    val_loss = criterion(outputs, labels)
                    running_val_loss += val_loss.item()

                    _, predicted = outputs.max(1)
                    total += labels.size(0)
                    correct += predicted.eq(labels).sum().item()

            # Calculate validation accuracy and average loss
            accuracy = 100 * correct / total
            avg_val_loss = running_val_loss / len(test_loader)

            # Print epoch information with loss and accuracy
            print(f'Epoch [{epoch+1}/{num_epochs}] | '
                  f'Training Loss: {avg_train_loss:.4f} | '
                  f'Validation Loss: {avg_val_loss:.4f} | '
                  f'Validation Accuracy: {accuracy:.2f}%')

            finetuning_accuracies.append(accuracy)

    print('Training complete')
    return finetuning_accuracies

# %%
# Train the model
finetuning_accuracies = train_model(transfer_model, trainloader, testloader, optimizer)
# Out:
# Epoch [100/10000] | Training Loss: 3.4372 | Validation Loss: 3.8613 | Validation Accuracy: 17.04%
# Epoch [200/10000] | Training Loss: 1.9900 | Validation Loss: 2.3861 | Validation Accuracy: 23.47%
# Epoch [300/10000] | Training Loss: 1.7576 | Validation Loss: 2.1039 | Validation Accuracy: 26.45%
# Epoch [400/10000] | Training Loss: 1.7205 | Validation Loss: 2.0833 | Validation Accuracy: 27.32%
# Epoch [500/10000] | Training Loss: 1.7105 | Validation Loss: 2.0960 | Validation Accuracy: 27.33%
# Epoch [600/10000] | Training Loss: 1.7002 | Validation Loss: 2.1124 | Validation Accuracy: 27.44%
# Epoch [700/10000] | Training Loss: 1.6889 | Validation Loss: 2.1286 | Validation Accuracy: 27.34%
# Epoch [800/10000] | Training Loss: 1.6755 | Validation Loss: 2.1455 | Validation Accuracy: 27.28%
# Epoch [900/10000] | Training Loss: 1.6683 | Validation Loss: 2.1636 | Validation Accuracy: 27.52%
# Epoch [1000/10000] | Training Loss: 1.6618 | Validation Loss: 2.1812 | Validation Accuracy: 27.73%
# Epoch [1100/10000] | Training Loss: 1.6522 | Validation Loss: 2.1982 | Validation Accuracy: 27.63%
# Epoch [1200/10000] | Training Loss: 1.6457 | Validation Loss: 2.2152 | Validation Accuracy: 27.78%
# Epoch [1300/10000] | Training Loss: 1.6351 | Validation Loss: 2.2337 | Validation Accuracy: 27.81%
# Epoch [1400/10000] | Training Loss: 1.6265 | Validation Loss: 2.2521 | Validation Accuracy: 28.19%
# Epoch [1500/10000] | Training Loss: 1.6162 | Validation Loss: 2.2696 | Validation Accuracy: 27.88%
# Epoch [1600/10000] | Training Loss: 1.6087 | Validation Loss: 2.2920 | Validation Accuracy: 28.20%
# Epoch [1700/10000] | Training Loss: 1.6006 | Validation Loss: 2.3163 | Validation Accuracy: 28.22%
# Epoch [1800/10000] | Training Loss: 1.5913 | Validation Loss: 2.3399 | Validation Accuracy: 28.34%
# Epoch [1900/10000] | Training Loss: 1.5839 | Validation Loss: 2.3645 | Validation Accuracy: 28.33%
# Epoch [2000/10000] | Training Loss: 1.5782 | Validation Loss: 2.3908 | Validation Accuracy: 28.46%
# Epoch [2100/10000] | Training Loss: 1.5702 | Validation Loss: 2.4169 | Validation Accuracy: 28.57%
# Epoch [2200/10000] | Training Loss: 1.5593 | Validation Loss: 2.4433 | Validation Accuracy: 28.69%
# Epoch [2300/10000] | Training Loss: 1.5544 | Validation Loss: 2.4700 | Validation Accuracy: 28.76%
# Epoch [2400/10000] | Training Loss: 1.5473 | Validation Loss: 2.4995 | Validation Accuracy: 28.86%
# Epoch [2500/10000] | Training Loss: 1.5392 | Validation Loss: 2.5307 | Validation Accuracy: 28.91%
# Epoch [2600/10000] | Training Loss: 1.5334 | Validation Loss: 2.5654 | Validation Accuracy: 28.93%
# Epoch [2700/10000] | Training Loss: 1.5254 | Validation Loss: 2.5988 | Validation Accuracy: 28.96%
# Epoch [2800/10000] | Training Loss: 1.5200 | Validation Loss: 2.6373 | Validation Accuracy: 28.88%
# Epoch [2900/10000] | Training Loss: 1.5119 | Validation Loss: 2.6732 | Validation Accuracy: 29.11%
# Epoch [3000/10000] | Training Loss: 1.5058 | Validation Loss: 2.7113 | Validation Accuracy: 29.17%
# Epoch [3100/10000] | Training Loss: 1.4963 | Validation Loss: 2.7516 | Validation Accuracy: 29.29%
# Epoch [3200/10000] | Training Loss: 1.4889 | Validation Loss: 2.7915 | Validation Accuracy: 29.29%
# Epoch [3300/10000] | Training Loss: 1.4859 | Validation Loss: 2.8316 | Validation Accuracy: 29.37%
# Epoch [3400/10000] | Training Loss: 1.4809 | Validation Loss: 2.8749 | Validation Accuracy: 29.37%
# Epoch [3500/10000] | Training Loss: 1.4694 | Validation Loss: 2.9192 | Validation Accuracy: 29.30%
# Epoch [3600/10000] | Training Loss: 1.4623 | Validation Loss: 2.9651 | Validation Accuracy: 29.47%
# Epoch [3700/10000] | Training Loss: 1.4585 | Validation Loss: 3.0126 | Validation Accuracy: 29.65%
# Epoch [3800/10000] | Training Loss: 1.4557 | Validation Loss: 3.0600 | Validation Accuracy: 29.52%
# Epoch [3900/10000] | Training Loss: 1.4466 | Validation Loss: 3.1083 | Validation Accuracy: 29.55%
# Epoch [4000/10000] | Training Loss: 1.4450 | Validation Loss: 3.1563 | Validation Accuracy: 29.56%
# Epoch [4100/10000] | Training Loss: 1.4380 | Validation Loss: 3.2063 | Validation Accuracy: 29.57%
# Epoch [4200/10000] | Training Loss: 1.4317 | Validation Loss: 3.2664 | Validation Accuracy: 29.77%
# Epoch [4300/10000] | Training Loss: 1.4249 | Validation Loss: 3.3298 | Validation Accuracy: 29.76%
# Epoch [4400/10000] | Training Loss: 1.4203 | Validation Loss: 3.3871 | Validation Accuracy: 29.76%
# Epoch [4500/10000] | Training Loss: 1.4099 | Validation Loss: 3.4422 | Validation Accuracy: 29.78%
# Epoch [4600/10000] | Training Loss: 1.4097 | Validation Loss: 3.4982 | Validation Accuracy: 29.83%
# Epoch [4700/10000] | Training Loss: 1.4021 | Validation Loss: 3.5529 | Validation Accuracy: 29.81%
# Epoch [4800/10000] | Training Loss: 1.3964 | Validation Loss: 3.6056 | Validation Accuracy: 29.79%
# Epoch [4900/10000] | Training Loss: 1.3900 | Validation Loss: 3.6568 | Validation Accuracy: 29.75%
# Epoch [5000/10000] | Training Loss: 1.3832 | Validation Loss: 3.7102 | Validation Accuracy: 29.74%
# Epoch [5100/10000] | Training Loss: 1.3792 | Validation Loss: 3.7646 | Validation Accuracy: 29.90%
# Epoch [5200/10000] | Training Loss: 1.3764 | Validation Loss: 3.8248 | Validation Accuracy: 29.59%
# Epoch [5300/10000] | Training Loss: 1.3723 | Validation Loss: 3.8856 | Validation Accuracy: 29.63%
# Epoch [5400/10000] | Training Loss: 1.3642 | Validation Loss: 3.9477 | Validation Accuracy: 29.48%
# Epoch [5500/10000] | Training Loss: 1.3601 | Validation Loss: 4.0104 | Validation Accuracy: 29.58%
# Epoch [5600/10000] | Training Loss: 1.3541 | Validation Loss: 4.0719 | Validation Accuracy: 29.60%
# Epoch [5700/10000] | Training Loss: 1.3518 | Validation Loss: 4.1355 | Validation Accuracy: 29.57%
# Epoch [5800/10000] | Training Loss: 1.3450 | Validation Loss: 4.1933 | Validation Accuracy: 29.64%
# Epoch [5900/10000] | Training Loss: 1.3398 | Validation Loss: 4.2549 | Validation Accuracy: 29.64%
# Epoch [6000/10000] | Training Loss: 1.3352 | Validation Loss: 4.3189 | Validation Accuracy: 29.77%
# Epoch [6100/10000] | Training Loss: 1.3314 | Validation Loss: 4.3877 | Validation Accuracy: 29.65%
# Epoch [6200/10000] | Training Loss: 1.3249 | Validation Loss: 4.4622 | Validation Accuracy: 29.67%
# Epoch [6300/10000] | Training Loss: 1.3185 | Validation Loss: 4.5284 | Validation Accuracy: 29.58%
# Epoch [6400/10000] | Training Loss: 1.3125 | Validation Loss: 4.5933 | Validation Accuracy: 29.60%
# Epoch [6500/10000] | Training Loss: 1.3096 | Validation Loss: 4.6575 | Validation Accuracy: 29.58%
# Epoch [6600/10000] | Training Loss: 1.3049 | Validation Loss: 4.7193 | Validation Accuracy: 29.54%
# Epoch [6700/10000] | Training Loss: 1.3021 | Validation Loss: 4.7812 | Validation Accuracy: 29.55%
# Epoch [6800/10000] | Training Loss: 1.2929 | Validation Loss: 4.8452 | Validation Accuracy: 29.64%
# Epoch [6900/10000] | Training Loss: 1.2892 | Validation Loss: 4.9071 | Validation Accuracy: 29.60%
# Epoch [7000/10000] | Training Loss: 1.2844 | Validation Loss: 4.9691 | Validation Accuracy: 29.44%
# Epoch [7100/10000] | Training Loss: 1.2805 | Validation Loss: 5.0283 | Validation Accuracy: 29.44%
# Epoch [7200/10000] | Training Loss: 1.2780 | Validation Loss: 5.0909 | Validation Accuracy: 29.34%
# Epoch [7300/10000] | Training Loss: 1.2695 | Validation Loss: 5.1529 | Validation Accuracy: 29.35%
# Epoch [7400/10000] | Training Loss: 1.2710 | Validation Loss: 5.2159 | Validation Accuracy: 29.39%
# Epoch [7500/10000] | Training Loss: 1.2605 | Validation Loss: 5.2778 | Validation Accuracy: 29.39%
# Epoch [7600/10000] | Training Loss: 1.2578 | Validation Loss: 5.3403 | Validation Accuracy: 29.48%
# Epoch [7700/10000] | Training Loss: 1.2560 | Validation Loss: 5.4060 | Validation Accuracy: 29.43%
# Epoch [7800/10000] | Training Loss: 1.2511 | Validation Loss: 5.4708 | Validation Accuracy: 29.43%
# Epoch [7900/10000] | Training Loss: 1.2509 | Validation Loss: 5.5374 | Validation Accuracy: 29.43%
# Epoch [8000/10000] | Training Loss: 1.2472 | Validation Loss: 5.5990 | Validation Accuracy: 29.50%
# Epoch [8100/10000] | Training Loss: 1.2410 | Validation Loss: 5.6622 | Validation Accuracy: 29.52%
# Epoch [8200/10000] | Training Loss: 1.2356 | Validation Loss: 5.7235 | Validation Accuracy: 29.51%
# Epoch [8300/10000] | Training Loss: 1.2327 | Validation Loss: 5.7876 | Validation Accuracy: 29.59%
# Epoch [8400/10000] | Training Loss: 1.2319 | Validation Loss: 5.8508 | Validation Accuracy: 29.56%
# Epoch [8500/10000] | Training Loss: 1.2234 | Validation Loss: 5.9115 | Validation Accuracy: 29.63%
# Epoch [8600/10000] | Training Loss: 1.2230 | Validation Loss: 5.9725 | Validation Accuracy: 29.62%
# Epoch [8700/10000] | Training Loss: 1.2197 | Validation Loss: 6.0359 | Validation Accuracy: 29.71%
# Epoch [8800/10000] | Training Loss: 1.2145 | Validation Loss: 6.0985 | Validation Accuracy: 29.57%
# Epoch [8900/10000] | Training Loss: 1.2115 | Validation Loss: 6.1569 | Validation Accuracy: 29.47%
# Epoch [9000/10000] | Training Loss: 1.2104 | Validation Loss: 6.2169 | Validation Accuracy: 29.63%
# Epoch [9100/10000] | Training Loss: 1.2070 | Validation Loss: 6.2784 | Validation Accuracy: 29.56%
# Epoch [9200/10000] | Training Loss: 1.2004 | Validation Loss: 6.3399 | Validation Accuracy: 29.52%
# Epoch [9300/10000] | Training Loss: 1.1985 | Validation Loss: 6.4018 | Validation Accuracy: 29.48%
# Epoch [9400/10000] | Training Loss: 1.1945 | Validation Loss: 6.4620 | Validation Accuracy: 29.63%
# Epoch [9500/10000] | Training Loss: 1.1931 | Validation Loss: 6.5215 | Validation Accuracy: 29.60%
# Epoch [9600/10000] | Training Loss: 1.1869 | Validation Loss: 6.5831 | Validation Accuracy: 29.52%
# Epoch [9700/10000] | Training Loss: 1.1806 | Validation Loss: 6.6460 | Validation Accuracy: 29.48%
# Epoch [9800/10000] | Training Loss: 1.1804 | Validation Loss: 6.7122 | Validation Accuracy: 29.54%
# Epoch [9900/10000] | Training Loss: 1.1766 | Validation Loss: 6.7766 | Validation Accuracy: 29.60%
# Epoch [10000/10000] | Training Loss: 1.1731 | Validation Loss: 6.8331 | Validation Accuracy: 29.62%
# Training complete

# %%
# Plot the accuracies
plt.figure(figsize=(10, 5))
plt.plot(range(100, num_epochs + 1, 100), finetuning_accuracies)
plt.title('Validation Accuracy over Epochs (Transfer Learning)')
plt.xlabel('Epochs')
plt.ylabel('Accuracy (%)')
plt.grid(True)
plt.show()

# %%
# Save the model
torch.save(q4_transfer_learning_model.state_dict(), '/kaggle/working/model/q4_transfer_learning_model.pth')
print('Model saved as q4_transfer_learning_model.pth')
# Out:
# Model saved as q4_transfer_learning_model.pth

# %% [markdown]
# ### **Comparison**

# %%
epochs = range(100, 10001, 100)

plt.figure(figsize=(12, 6))
plt.plot(epochs, baseline_accuracies, label='Baseline')
plt.plot(epochs, finetuning_accuracies, label='Fine-tuning')

plt.title('Comparison of Baseline and Fine-tuning Methods', fontsize=16)
plt.xlabel('Epochs', fontsize=14)
plt.ylabel('Validation Accuracy (%)', fontsize=14)
plt.legend(fontsize=12)
plt.grid(True, linestyle='--', alpha=0.7)

plt.tick_params(axis='both', which='major', labelsize=12)

plt.tight_layout()
plt.show()
