# %% [markdown]
# # **Assignment-4**
#
# **Name:** Pavan Pandya
#
# **Email:** pnpandya@iu.edu

# %% [markdown]
# ## **Setup**

# %%
import os
import json
import pickle
import numpy as np
import matplotlib.pyplot as plt
import torch
import torch.nn as nn
import torch.optim as optim
import torchvision
import torchvision.transforms as transforms
from torch.utils.data import DataLoader, Dataset, random_split, TensorDataset

import multiprocessing
num_workers = multiprocessing.cpu_count() - 2
import warnings
warnings.filterwarnings('ignore')

# %%
# Get cpu, gpu or mps device for training.
device = (
    "cuda"
    if torch.cuda.is_available()
    else "mps"
    if torch.backends.mps.is_available()
    else "cpu"
)
print(f"Using {device} device")
# Out:
# Using cuda device

# %%
import random

def set_seed(seed=42):
    # Set Python's random seed
    random.seed(seed)
    
    # Set NumPy's random seed
    np.random.seed(seed)
    
    # Set PyTorch's random seed for CPU
    torch.manual_seed(seed)
    
    # Set PyTorch's random seed for GPU (if using)
    if torch.cuda.is_available():
        torch.cuda.manual_seed(seed)
        torch.cuda.manual_seed_all(seed)  # For multi-GPU setups
    
    # Ensure PyTorch operations are deterministic
    torch.backends.cudnn.deterministic = True
    torch.backends.cudnn.benchmark = False

# Set the seed
set_seed(42)

# %%
# Define the directory paths
model_dir = '/kaggle/working/model'
output_dir = '/kaggle/working/output'

# Function to check and create directory
def create_directory(directory_path):
    if not os.path.exists(directory_path):
        os.makedirs(directory_path)
        print(f"Directory created: {directory_path}")
    else:
        print(f"Directory already exists: {directory_path}")
        
# Ensure the directory exists
create_directory(model_dir)
create_directory(output_dir)
# Out:
# Directory created: /kaggle/working/model
# Directory created: /kaggle/working/output

# %% [markdown]
# ## **Problem 1: RNNs as a generative model**

# %%
# Load MNIST dataset
transform = transforms.Compose([transforms.ToTensor()])
mnist_train_dataset = torchvision.datasets.MNIST(root='./data', train=True, download=True, transform=transform)
mnist_test_dataset = torchvision.datasets.MNIST(root='./data', train=False, transform=transform)
# Out:
# Downloading http://yann.lecun.com/exdb/mnist/train-images-idx3-ubyte.gz
# Failed to download (trying next):
# HTTP Error 403: Forbidden
#
# Downloading https://ossci-datasets.s3.amazonaws.com/mnist/train-images-idx3-ubyte.gz
# Downloading https://ossci-datasets.s3.amazonaws.com/mnist/train-images-idx3-ubyte.gz to ./data/MNIST/raw/train-images-idx3-ubyte.gz
# 100%|██████████| 9912422/9912422 [00:00<00:00, 38249074.49it/s]
# Extracting ./data/MNIST/raw/train-images-idx3-ubyte.gz to ./data/MNIST/raw
#
# Downloading http://yann.lecun.com/exdb/mnist/train-labels-idx1-ubyte.gz
# Failed to download (trying next):
# HTTP Error 403: Forbidden
#
# Downloading https://ossci-datasets.s3.amazonaws.com/mnist/train-labels-idx1-ubyte.gz
# Downloading https://ossci-datasets.s3.amazonaws.com/mnist/train-labels-idx1-ubyte.gz to ./data/MNIST/raw/train-labels-idx1-ubyte.gz
# 100%|██████████| 28881/28881 [00:00<00:00, 1140637.42it/s]
# Extracting ./data/MNIST/raw/train-labels-idx1-ubyte.gz to ./data/MNIST/raw
#
# Downloading http://yann.lecun.com/exdb/mnist/t10k-images-idx3-ubyte.gz
# Failed to download (trying next):
# HTTP Error 403: Forbidden
#
# Downloading https://ossci-datasets.s3.amazonaws.com/mnist/t10k-images-idx3-ubyte.gz
# Downloading https://ossci-datasets.s3.amazonaws.com/mnist/t10k-images-idx3-ubyte.gz to ./data/MNIST/raw/t10k-images-idx3-ubyte.gz
# 100%|██████████| 1648877/1648877 [00:00<00:00, 10592087.05it/s]
# Extracting ./data/MNIST/raw/t10k-images-idx3-ubyte.gz to ./data/MNIST/raw
#
# Downloading http://yann.lecun.com/exdb/mnist/t10k-labels-idx1-ubyte.gz
# Failed to download (trying next):
# HTTP Error 403: Forbidden
#
# Downloading https://ossci-datasets.s3.amazonaws.com/mnist/t10k-labels-idx1-ubyte.gz
# Downloading https://ossci-datasets.s3.amazonaws.com/mnist/t10k-labels-idx1-ubyte.gz to ./data/MNIST/raw/t10k-labels-idx1-ubyte.gz
# 100%|██████████| 4542/4542 [00:00<00:00, 2636021.69it/s]
# Extracting ./data/MNIST/raw/t10k-labels-idx1-ubyte.gz to ./data/MNIST/raw

# %%
def convert_to_patch_dataset(dataset, patch_size=7, num_patches=16):
    patches_list = []
    labels_list = []
    
    for image, label in dataset:
        # Ensure image is a 2D tensor (remove batch dimension if present)
        if image.dim() == 3:
            image = image.squeeze(0)
        
        # Extract patches 
        patches = image.unfold(0, patch_size, patch_size) \
                      .unfold(1, patch_size, patch_size) \
                      .reshape(num_patches, patch_size * patch_size)
        
        patches_list.append(patches)
        labels_list.append(label)
    
    # Convert lists to tensors
    patches_tensor = torch.stack(patches_list)
    labels_tensor = torch.tensor(labels_list)
    
    # Create a new TensorDataset
    return TensorDataset(patches_tensor, labels_tensor)

# %%
# Split the dataset
q1_val_size = 10000
q1_train_set, q1_val_set = random_split(mnist_train_dataset, [q1_val_size, len(mnist_train_dataset) - q1_val_size])
batch_size = 100

q1_train_loader = DataLoader(convert_to_patch_dataset(q1_train_set), batch_size=batch_size, shuffle=True, num_workers=num_workers, pin_memory=True)
q1_test_loader = DataLoader(convert_to_patch_dataset(mnist_test_dataset), batch_size=batch_size, shuffle=False, num_workers=num_workers, pin_memory=True)
q1_val_loader = DataLoader(convert_to_patch_dataset(q1_val_set), batch_size=batch_size, shuffle=False, num_workers=num_workers, pin_memory=True)

# %%
# Check the shape of the first batch to verify
print("First batch tensor shape:", next(iter(q1_train_loader))[0].shape)  # Should be (100, 16, 49)
# Out:
# First batch tensor shape: torch.Size([100, 16, 49])

# %%
class LSTMModel(nn.Module):
    def __init__(self, input_size=49, hidden_size=256, num_layers=3, output_size=49):
        super(LSTMModel, self).__init__()
        self.num_layers = num_layers
        self.hidden_size = hidden_size
        self.lstm = nn.LSTM(input_size, hidden_size, num_layers, batch_first=True)
        self.fc = nn.Linear(hidden_size, output_size)
        self.activation = nn.Tanh() 

        # Initialize weights and biases
        self._init_weights()

    def _init_weights(self):
        for layer in self.modules():
            if isinstance(layer, nn.LSTM):
                for name, param in layer.named_parameters():
                    if "weight_ih" in name:
                        nn.init.kaiming_uniform_(param.data, nonlinearity="relu")
                    elif "weight_hh" in name:
                        nn.init.orthogonal_(param.data)
                    elif "bias" in name:
                        nn.init.zeros_(param.data)
            elif isinstance(layer, nn.Linear):
                nn.init.kaiming_uniform_(layer.weight, nonlinearity="relu")
                nn.init.zeros_(layer.bias) 

    def forward(self, x, hidden=None):
        out, hidden = self.lstm(x, hidden)
        out = self.fc(out)
        out = self.activation(out)
        return out, hidden

# %%
def train_q1_model(model, train_batches, val_batches, criterion, optimizer, device, num_epochs=50, patience=5):
    model.to(device)

    total_train_losses = []
    total_val_losses = []
    best_val_loss = float('inf')  
    epochs_without_improvement = 0  
    best_model = None

    for epoch in range(num_epochs):
        model.train()  
        total_train_loss = 0

        # Training loop for each batch
        for i, (batch_tensor, _) in enumerate(train_batches):
            batch_tensor = batch_tensor.to(device)

            # Define input sequence (X1:15) and target sequence (X2:16)
            input_seq = batch_tensor[:, :15, :]   # Shape: (batch_size, 15, 49)
            target_seq = batch_tensor[:, 1:16, :]  # Shape: (batch_size, 15, 49)
            
            # Forward pass
            optimizer.zero_grad()
            output, _ = model(input_seq)  # Shape: (batch_size, 15, 49)
            
            # Compute loss
            loss = criterion(output, target_seq)
            
            # Backward pass and optimization
            loss.backward()
            optimizer.step()
            
            total_train_loss += loss.item()

        # Average training loss per batch
        avg_train_loss = total_train_loss / len(train_batches)
        total_train_losses.append(avg_train_loss)
        
        # Validation
        model.eval() 
        total_val_loss = 0
        with torch.no_grad():  
            for i, (batch_tensor, _) in enumerate(val_batches):
                batch_tensor = batch_tensor.to(device)
                
                # Define input sequence (X1:15) and target sequence (X2:16)
                input_seq = batch_tensor[:, :15, :]   # Shape: (batch_size, 15, 49)
                target_seq = batch_tensor[:, 1:16, :]  # Shape: (batch_size, 15, 49)
                
                # Forward pass
                output, _ = model(input_seq)  # Shape: (batch_size, 15, 49)
            
                # Compute loss
                loss = criterion(output, target_seq)
                total_val_loss += loss.item()

        # Average val loss per batch
        avg_val_loss = total_val_loss / len(val_batches)
        total_val_losses.append(avg_val_loss)
        
        # Print epoch results
        print(f'Epoch [{epoch + 1}/{num_epochs}], Train Loss: {avg_train_loss:.4f}, Val Loss: {avg_val_loss:.4f}')
        
        # Early stopping check
        if avg_val_loss < best_val_loss:
            best_val_loss = avg_val_loss
            epochs_without_improvement = 0
            best_model = model.state_dict()
        else:
            epochs_without_improvement += 1
            if epochs_without_improvement >= patience:
                print(f"Early stopping after {epoch + 1} epochs. Validation loss stopped improving.")
                # Save the best model before breaking the loop
                torch.save(best_model, "/kaggle/working/model/q1_best_model.pth")
                break
        
        # If the loop completes without early stopping, save the best model
        if epochs_without_improvement < patience:
            torch.save(best_model, "/kaggle/working/model/q1_best_model.pth")

    return total_train_losses, total_val_losses

# %%
q1_model = LSTMModel().to(device)
q1_criterion = nn.MSELoss()
q1_optimizer = optim.Adam(q1_model.parameters(), lr=0.0005)
patience = 5
num_epochs = 200

# %%
# Train the model
q1_train_losses, q1_val_losses = train_q1_model(q1_model, q1_train_loader, q1_val_loader, q1_criterion, q1_optimizer, device, num_epochs, patience)
# Out:
# Epoch [1/200], Train Loss: 0.0833, Val Loss: 0.0641
# Epoch [2/200], Train Loss: 0.0568, Val Loss: 0.0511
# Epoch [3/200], Train Loss: 0.0483, Val Loss: 0.0458
# Epoch [4/200], Train Loss: 0.0441, Val Loss: 0.0427
# Epoch [5/200], Train Loss: 0.0415, Val Loss: 0.0407
# Epoch [6/200], Train Loss: 0.0396, Val Loss: 0.0392
# Epoch [7/200], Train Loss: 0.0383, Val Loss: 0.0382
# Epoch [8/200], Train Loss: 0.0373, Val Loss: 0.0371
# Epoch [9/200], Train Loss: 0.0363, Val Loss: 0.0366
# Epoch [10/200], Train Loss: 0.0356, Val Loss: 0.0361
# Epoch [11/200], Train Loss: 0.0349, Val Loss: 0.0353
# Epoch [12/200], Train Loss: 0.0342, Val Loss: 0.0350
# Epoch [13/200], Train Loss: 0.0337, Val Loss: 0.0346
# Epoch [14/200], Train Loss: 0.0333, Val Loss: 0.0343
# Epoch [15/200], Train Loss: 0.0328, Val Loss: 0.0339
# Epoch [16/200], Train Loss: 0.0324, Val Loss: 0.0337
# Epoch [17/200], Train Loss: 0.0321, Val Loss: 0.0334
# Epoch [18/200], Train Loss: 0.0317, Val Loss: 0.0332
# Epoch [19/200], Train Loss: 0.0313, Val Loss: 0.0329
# Epoch [20/200], Train Loss: 0.0311, Val Loss: 0.0327
# Epoch [21/200], Train Loss: 0.0307, Val Loss: 0.0325
# Epoch [22/200], Train Loss: 0.0304, Val Loss: 0.0324
# Epoch [23/200], Train Loss: 0.0301, Val Loss: 0.0324
# Epoch [24/200], Train Loss: 0.0299, Val Loss: 0.0324
# Epoch [25/200], Train Loss: 0.0296, Val Loss: 0.0319
# Epoch [26/200], Train Loss: 0.0294, Val Loss: 0.0322
# Epoch [27/200], Train Loss: 0.0291, Val Loss: 0.0320
# Epoch [28/200], Train Loss: 0.0289, Val Loss: 0.0318
# Epoch [29/200], Train Loss: 0.0287, Val Loss: 0.0316
# Epoch [30/200], Train Loss: 0.0284, Val Loss: 0.0317
# Epoch [31/200], Train Loss: 0.0283, Val Loss: 0.0314
# Epoch [32/200], Train Loss: 0.0280, Val Loss: 0.0314
# Epoch [33/200], Train Loss: 0.0278, Val Loss: 0.0314
# Epoch [34/200], Train Loss: 0.0276, Val Loss: 0.0312
# Epoch [35/200], Train Loss: 0.0274, Val Loss: 0.0313
# Epoch [36/200], Train Loss: 0.0272, Val Loss: 0.0316
# Epoch [37/200], Train Loss: 0.0271, Val Loss: 0.0313
# Epoch [38/200], Train Loss: 0.0268, Val Loss: 0.0312
# Epoch [39/200], Train Loss: 0.0266, Val Loss: 0.0311
# Epoch [40/200], Train Loss: 0.0264, Val Loss: 0.0311
# Epoch [41/200], Train Loss: 0.0263, Val Loss: 0.0313
# Epoch [42/200], Train Loss: 0.0261, Val Loss: 0.0312
# Epoch [43/200], Train Loss: 0.0259, Val Loss: 0.0310
# Epoch [44/200], Train Loss: 0.0257, Val Loss: 0.0310
# Epoch [45/200], Train Loss: 0.0255, Val Loss: 0.0311
# Epoch [46/200], Train Loss: 0.0254, Val Loss: 0.0312
# Epoch [47/200], Train Loss: 0.0252, Val Loss: 0.0311
# Epoch [48/200], Train Loss: 0.0250, Val Loss: 0.0311
# Epoch [49/200], Train Loss: 0.0248, Val Loss: 0.0311
# Early stopping after 49 epochs. Validation loss stopped improving.

# %%
# Plot the train_loss vs test_loss
plt.figure(figsize=(8, 6))
plt.plot(range(1, len(q1_train_losses) + 1), q1_train_losses, label='Train Loss', color='r')
plt.plot(range(1, len(q1_val_losses) + 1), q1_val_losses, label='Val Loss', color='b')
plt.xlabel('Epochs')
plt.ylabel('MSE')
plt.title('Train Loss vs Val Loss')
plt.legend()
plt.grid(True)
plt.show()

# %%
q1_best_model = LSTMModel().to(device)
q1_best_model.load_state_dict(torch.load("/kaggle/working/model/q1_best_model.pth"))
# Out:
# <All keys matched successfully>

# %%
def sample_by_class(dataloader, sample_size):
    class_samples = {}
    for data, labels in dataloader:
        for i in range(len(labels)):
            label = labels[i].item()
            if label not in class_samples:
                class_samples[label] = []
            if len(class_samples[label]) < sample_size:
                class_samples[label].append((data[i], label))
        if all(len(class_samples[label]) >= sample_size for label in class_samples):
            break
    return class_samples

# %%
def reconstruct_image_from_patches(patches):
    image = np.zeros((28, 28))
    patch_size = 7
    
    for patch_idx, patch_data in enumerate(patches):
        row = (patch_idx // 4) * patch_size
        col = (patch_idx % 4) * patch_size
        
        image[row:row+patch_size, col:col+patch_size] = patch_data.reshape(patch_size, patch_size)
    
    return image

# %%
def generate_image(model, device, patches):
    model.eval()
    patches = patches.to(device)
    
    # Initialize with the first 8 input patches
    top_half_patches = patches[:8].unsqueeze(0).to(device)
    predicted_patches = []

    with torch.no_grad():
        # Predict the 9th patch
        pred_patch, hidden_state = model(top_half_patches)
        predicted_patches.append(pred_patch[:, 7:8, :]) 

        # Predict patches 10 to 16 iteratively
        for _ in range(1, 8):
            pred_patch, hidden_state = model(predicted_patches[-1], hidden_state)
            predicted_patches.append(pred_patch)

    # Combine all 16 patches into a single 7x7 image
    all_patches = [top_half_patches[:, i, :].reshape(7, 7) for i in range(8)] + [patch.reshape(7, 7) for patch in predicted_patches]

    # Form rows by concatenating 4 patches each
    rows = [torch.cat(all_patches[i:i+4], dim=1) for i in range(0, 16, 4)]

    # Combine rows to generate the final image
    generated_image = torch.cat(rows, dim=0)

    return generated_image.detach().cpu().numpy()

# %%
class_samples = sample_by_class(q1_test_loader, 10)

# %%
# Verify elements
for k in class_samples.keys():
    print(f"{k} has {len(class_samples[k])} elements.")
# Out:
# 7 has 10 elements.
# 2 has 10 elements.
# 1 has 10 elements.
# 0 has 10 elements.
# 4 has 10 elements.
# 9 has 10 elements.
# 5 has 10 elements.
# 6 has 10 elements.
# 3 has 10 elements.
# 8 has 10 elements.

# %%
# Stores test images in a 28x28 shape, used for showing original image
generated_images = []
original_images = []

for digit in range(10):
    for img, _ in class_samples[digit]:
        original_images.append(reconstruct_image_from_patches(img.cpu().numpy()))
        # Reconstruct the original image
        generated_images.append(generate_image(q1_best_model, device, img))

# %%
# Display the original image
plt.imshow(original_images[31], cmap='gray')
plt.axis('off')  
plt.show()

# %%
# Display the generated image
plt.imshow(generated_images[31], cmap='gray')
plt.axis('off')  
plt.show()

# %%
def visualize_images(original_images, generated_images, rows=10, cols=10):
    assert len(original_images) == len(generated_images), "Input lists must have the same length"
    total_images = len(original_images) 
    row, col = 10, 10
    
    # Plot Original Images
    plt.figure(figsize=(10, 8))
    plt.suptitle("Original Images")
    for i in range(total_images):
        plt.subplot(rows, cols, i + 1)
        plt.imshow(original_images[i], cmap='gray')
        plt.axis('off')
    plt.tight_layout()
    plt.show()
    
    # Plot Generated Images
    plt.figure(figsize=(10, 8))
    plt.suptitle("Generated Images")
    for i in range(total_images):
        plt.subplot(rows, cols, i + 1)
        plt.imshow(generated_images[i], cmap='gray')
        plt.axis('off')
    plt.tight_layout()
    plt.show()

# %%
# Visualize the images
visualize_images(original_images, generated_images)

# %% [markdown]
# ## **Problem 2: Variational Autoencoders on Poor Sevens**

# %%
def load_data(train_data_file, test_data_file):
    # Load data from pickle files
    with open(train_data_file, 'rb') as f:
        train_data = pickle.load(f)
    
    with open(test_data_file, 'rb') as f:
        test_data = pickle.load(f)
    
    return train_data, test_data

# %%
def prepare_dataset(train_data, test_data):
    # Combine train and test data
    x = np.concatenate((train_data, test_data), axis=0)
    return x

# %%
class Q2Dataset(Dataset):
    def __init__(self, data):
        self.data = torch.tensor(data, dtype=torch.float32).reshape(data.shape[0], -1)
    
    def __len__(self):
        return len(self.data)
    
    def __getitem__(self, idx):
        return self.data[idx]

# %%
# Load data
q2_train_data, q2_test_data = load_data("/kaggle/input/hw5-data-file/hw5_te7.pkl", 
                                "/kaggle/input/hw5-data-file/hw5_tr7.pkl")

# %%
# Prepare dataset
processed_data = prepare_dataset(q2_train_data, q2_test_data)

# %%
# Create DataLoader
batch_size = 100
q2_train_loader = DataLoader(Q2Dataset(processed_data), 
                             batch_size=batch_size, 
                             shuffle=True)

# %%
# Print batch information
q2_batch_x = next(iter(q2_train_loader))
print("Training Data Batch Shape: ", list(q2_batch_x.shape))
# Out:
# Training Data Batch Shape:  [100, 784]

# %%
class VAE(nn.Module):
    def __init__(self, input_dim=784, hidden_dim=200, latent_dim=3):
        super(VAE, self).__init__()
        
        self.encoder = self._build_encoder(input_dim, hidden_dim, latent_dim)
        self.decoder = self._build_decoder(latent_dim, hidden_dim, input_dim)
        
        self.mean = nn.Linear(hidden_dim, latent_dim)
        self.log_var = nn.Linear(hidden_dim, latent_dim)
        
        self._init_weights()

    def _build_encoder(self, input_dim, hidden_dim, latent_dim):
        return nn.Sequential(
            nn.Linear(input_dim, 400),
            nn.LeakyReLU(0.2),
            nn.Linear(400, hidden_dim),
            nn.LeakyReLU(0.2)
        )

    def _build_decoder(self, latent_dim, hidden_dim, output_dim):
        return nn.Sequential(
            nn.Linear(latent_dim, hidden_dim),
            nn.LeakyReLU(0.2),
            nn.Linear(hidden_dim, 400),
            nn.LeakyReLU(0.2),
            nn.Linear(400, output_dim),
            nn.Sigmoid()
        )

    def _init_weights(self):
        for m in self.modules():
            if isinstance(m, nn.Linear):
                nn.init.xavier_uniform_(m.weight)
                nn.init.zeros_(m.bias)

    def encode(self, x):
        h = self.encoder(x)
        return self.mean(h), self.log_var(h)

    def reparameterize(self, mu, log_var):
        std = torch.exp(0.5 * log_var)
        eps = torch.randn_like(std)
        return mu + eps * std

    def decode(self, z):
        return self.decoder(z)

    def forward(self, x):
        mu, log_var = self.encode(x)
        z = self.reparameterize(mu, log_var)
        return self.decode(z), mu, log_var

# %%
def vae_loss(x_recon, x, mu, log_var, reconstruction_type='mse'):
    def kl_divergence(mu, log_var):
        return -0.5 * torch.sum(1 + log_var - mu.pow(2) - log_var.exp())
    
    if reconstruction_type == 'mse':
        reconstruction_loss = nn.MSELoss(reduction='sum')(x_recon, x)
    elif reconstruction_type == 'bce':
        reconstruction_loss = nn.BCELoss(reduction='sum')(x_recon, x)
    else:
        raise ValueError("Unsupported reconstruction loss type")
    
    kl_div = kl_divergence(mu, log_var)
    total_loss = reconstruction_loss + kl_div
    
    return total_loss, reconstruction_loss, kl_div

# %%
def train_q2_model(model, train_loader, optimizer, device, num_epochs=200):
    model.to(device)
    train_losses = []

    for epoch in range(num_epochs):
        model.train()
        epoch_loss = 0.0
        epoch_recon_loss = 0.0
        num_batches = 0
    
        for input_batch in train_loader:
            input_batch = input_batch.to(device)
            
            optimizer.zero_grad()
            
            x_recon, mu, log_var = model(input_batch)
            total_loss, recon_loss, kl_div = vae_loss(x_recon, input_batch, mu, log_var)
            
            total_loss.backward()
            optimizer.step()
    
            epoch_loss += total_loss.item()
            epoch_recon_loss += recon_loss.item()
            num_batches += 1
    
        avg_epoch_loss = epoch_loss / num_batches
        avg_recon_loss = epoch_recon_loss / num_batches
        train_losses.append(avg_epoch_loss)
    
        print(f'Epoch [{epoch + 1}/{num_epochs}], Train Loss: {avg_epoch_loss:.4f}, Recon Loss: {avg_recon_loss:.4f}')
    
    return train_losses

# %%
q2_model = VAE().to(device)
q2_optimizer = torch.optim.Adam(q2_model.parameters(), lr=0.001)

# %%
q2_train_losses = train_q2_model(q2_model, q2_train_loader, q2_optimizer, device, num_epochs=200)
# Out:
# Epoch [1/200], Train Loss: 6513.8823, Recon Loss: 6107.2024
# Epoch [2/200], Train Loss: 4206.5305, Recon Loss: 3926.7103
# Epoch [3/200], Train Loss: 3638.6622, Recon Loss: 3274.8593
# Epoch [4/200], Train Loss: 3425.8730, Recon Loss: 3018.7937
# Epoch [5/200], Train Loss: 3319.1655, Recon Loss: 2889.0321
# Epoch [6/200], Train Loss: 3240.4562, Recon Loss: 2797.9764
# Epoch [7/200], Train Loss: 3185.4731, Recon Loss: 2728.8068
# Epoch [8/200], Train Loss: 3148.3521, Recon Loss: 2680.9363
# Epoch [9/200], Train Loss: 3115.6249, Recon Loss: 2637.7085
# Epoch [10/200], Train Loss: 3092.4181, Recon Loss: 2609.2764
# Epoch [11/200], Train Loss: 3066.7865, Recon Loss: 2575.0434
# Epoch [12/200], Train Loss: 3048.0545, Recon Loss: 2555.2015
# Epoch [13/200], Train Loss: 3035.7220, Recon Loss: 2530.9615
# Epoch [14/200], Train Loss: 3018.8335, Recon Loss: 2512.4254
# Epoch [15/200], Train Loss: 3008.5822, Recon Loss: 2496.2303
# Epoch [16/200], Train Loss: 2992.0759, Recon Loss: 2478.7589
# Epoch [17/200], Train Loss: 2995.3235, Recon Loss: 2475.3723
# Epoch [18/200], Train Loss: 2979.4717, Recon Loss: 2460.0769
# Epoch [19/200], Train Loss: 2969.6504, Recon Loss: 2447.2998
# Epoch [20/200], Train Loss: 2963.3423, Recon Loss: 2440.0386
# Epoch [21/200], Train Loss: 2951.4005, Recon Loss: 2428.0015
# Epoch [22/200], Train Loss: 2947.9985, Recon Loss: 2421.4474
# Epoch [23/200], Train Loss: 2939.3268, Recon Loss: 2410.5283
# Epoch [24/200], Train Loss: 2944.9829, Recon Loss: 2413.3797
# Epoch [25/200], Train Loss: 2934.9193, Recon Loss: 2404.4680
# Epoch [26/200], Train Loss: 2921.4917, Recon Loss: 2387.5570
# Epoch [27/200], Train Loss: 2919.5504, Recon Loss: 2385.3029
# Epoch [28/200], Train Loss: 2920.0406, Recon Loss: 2387.0040
# Epoch [29/200], Train Loss: 2913.1266, Recon Loss: 2374.1746
# Epoch [30/200], Train Loss: 2900.9517, Recon Loss: 2363.6367
# Epoch [31/200], Train Loss: 2900.1545, Recon Loss: 2362.1774
# Epoch [32/200], Train Loss: 2903.5586, Recon Loss: 2359.6621
# Epoch [33/200], Train Loss: 2892.5119, Recon Loss: 2349.8418
# Epoch [34/200], Train Loss: 2891.2850, Recon Loss: 2350.1315
# Epoch [35/200], Train Loss: 2888.2115, Recon Loss: 2345.3245
# Epoch [36/200], Train Loss: 2876.8775, Recon Loss: 2335.5933
# Epoch [37/200], Train Loss: 2876.5138, Recon Loss: 2332.4544
# Epoch [38/200], Train Loss: 2874.1375, Recon Loss: 2330.7372
# Epoch [39/200], Train Loss: 2871.6137, Recon Loss: 2327.3791
# Epoch [40/200], Train Loss: 2866.4143, Recon Loss: 2320.9758
# Epoch [41/200], Train Loss: 2859.7275, Recon Loss: 2313.7844
# Epoch [42/200], Train Loss: 2858.8734, Recon Loss: 2311.7444
# Epoch [43/200], Train Loss: 2854.2116, Recon Loss: 2305.6148
# Epoch [44/200], Train Loss: 2851.1425, Recon Loss: 2304.6536
# Epoch [45/200], Train Loss: 2854.3227, Recon Loss: 2307.4514
# Epoch [46/200], Train Loss: 2849.3432, Recon Loss: 2299.3413
# Epoch [47/200], Train Loss: 2841.9629, Recon Loss: 2292.5958
# Epoch [48/200], Train Loss: 2840.3974, Recon Loss: 2290.0102
# Epoch [49/200], Train Loss: 2835.5281, Recon Loss: 2282.5146
# Epoch [50/200], Train Loss: 2831.1003, Recon Loss: 2281.1932
# Epoch [51/200], Train Loss: 2830.1025, Recon Loss: 2277.5026
# Epoch [52/200], Train Loss: 2828.0649, Recon Loss: 2273.0070
# Epoch [53/200], Train Loss: 2825.5077, Recon Loss: 2270.3131
# Epoch [54/200], Train Loss: 2822.9952, Recon Loss: 2269.9307
# Epoch [55/200], Train Loss: 2818.7721, Recon Loss: 2263.4056
# Epoch [56/200], Train Loss: 2821.7037, Recon Loss: 2265.9230
# Epoch [57/200], Train Loss: 2814.4736, Recon Loss: 2258.8364
# Epoch [58/200], Train Loss: 2813.5238, Recon Loss: 2256.1775
# Epoch [59/200], Train Loss: 2810.9940, Recon Loss: 2252.7370
# Epoch [60/200], Train Loss: 2811.7927, Recon Loss: 2254.0920
# Epoch [61/200], Train Loss: 2810.2973, Recon Loss: 2251.6525
# Epoch [62/200], Train Loss: 2805.2824, Recon Loss: 2247.1166
# Epoch [63/200], Train Loss: 2805.5561, Recon Loss: 2245.4675
# Epoch [64/200], Train Loss: 2803.4712, Recon Loss: 2240.1494
# Epoch [65/200], Train Loss: 2798.6444, Recon Loss: 2238.6176
# Epoch [66/200], Train Loss: 2794.2448, Recon Loss: 2232.7196
# Epoch [67/200], Train Loss: 2789.4653, Recon Loss: 2227.8194
# Epoch [68/200], Train Loss: 2794.2594, Recon Loss: 2231.4959
# Epoch [69/200], Train Loss: 2789.2894, Recon Loss: 2227.1974
# Epoch [70/200], Train Loss: 2786.9903, Recon Loss: 2225.7644
# Epoch [71/200], Train Loss: 2787.7679, Recon Loss: 2219.1878
# Epoch [72/200], Train Loss: 2786.6908, Recon Loss: 2223.1987
# Epoch [73/200], Train Loss: 2786.0485, Recon Loss: 2215.6331
# Epoch [74/200], Train Loss: 2782.7881, Recon Loss: 2216.0065
# Epoch [75/200], Train Loss: 2781.9271, Recon Loss: 2212.7987
# Epoch [76/200], Train Loss: 2782.3210, Recon Loss: 2211.9079
# Epoch [77/200], Train Loss: 2774.8188, Recon Loss: 2210.6425
# Epoch [78/200], Train Loss: 2777.4001, Recon Loss: 2209.8090
# Epoch [79/200], Train Loss: 2773.6445, Recon Loss: 2204.9942
# Epoch [80/200], Train Loss: 2776.0165, Recon Loss: 2207.1456
# Epoch [81/200], Train Loss: 2772.5666, Recon Loss: 2201.2659
# Epoch [82/200], Train Loss: 2770.7026, Recon Loss: 2197.4027
# Epoch [83/200], Train Loss: 2766.1132, Recon Loss: 2195.6299
# Epoch [84/200], Train Loss: 2761.8461, Recon Loss: 2187.1737
# Epoch [85/200], Train Loss: 2762.6014, Recon Loss: 2190.4376
# Epoch [86/200], Train Loss: 2760.1252, Recon Loss: 2188.3459
# Epoch [87/200], Train Loss: 2759.9585, Recon Loss: 2186.9651
# Epoch [88/200], Train Loss: 2761.3335, Recon Loss: 2189.1425
# Epoch [89/200], Train Loss: 2756.9251, Recon Loss: 2183.3526
# Epoch [90/200], Train Loss: 2751.5333, Recon Loss: 2181.0980
# Epoch [91/200], Train Loss: 2751.4373, Recon Loss: 2177.5009
# Epoch [92/200], Train Loss: 2752.2469, Recon Loss: 2176.7009
# Epoch [93/200], Train Loss: 2748.3569, Recon Loss: 2176.7923
# Epoch [94/200], Train Loss: 2746.7514, Recon Loss: 2171.3514
# Epoch [95/200], Train Loss: 2750.3359, Recon Loss: 2172.9198
# Epoch [96/200], Train Loss: 2751.2698, Recon Loss: 2172.5641
# Epoch [97/200], Train Loss: 2741.4872, Recon Loss: 2165.8997
# Epoch [98/200], Train Loss: 2742.6191, Recon Loss: 2168.8634
# Epoch [99/200], Train Loss: 2744.4330, Recon Loss: 2166.3675
# Epoch [100/200], Train Loss: 2741.8650, Recon Loss: 2165.1603
# Epoch [101/200], Train Loss: 2743.8109, Recon Loss: 2162.9436
# Epoch [102/200], Train Loss: 2739.3982, Recon Loss: 2163.4349
# Epoch [103/200], Train Loss: 2737.3136, Recon Loss: 2159.8535
# Epoch [104/200], Train Loss: 2734.4497, Recon Loss: 2156.0072
# Epoch [105/200], Train Loss: 2734.7464, Recon Loss: 2155.1241
# Epoch [106/200], Train Loss: 2737.5721, Recon Loss: 2155.2842
# Epoch [107/200], Train Loss: 2732.0051, Recon Loss: 2151.7887
# Epoch [108/200], Train Loss: 2730.3862, Recon Loss: 2148.6347
# Epoch [109/200], Train Loss: 2727.8063, Recon Loss: 2147.9434
# Epoch [110/200], Train Loss: 2727.9929, Recon Loss: 2146.7248
# Epoch [111/200], Train Loss: 2729.4365, Recon Loss: 2146.7437
# Epoch [112/200], Train Loss: 2731.6002, Recon Loss: 2143.8310
# Epoch [113/200], Train Loss: 2722.9844, Recon Loss: 2141.3046
# Epoch [114/200], Train Loss: 2718.8041, Recon Loss: 2136.0452
# Epoch [115/200], Train Loss: 2721.7454, Recon Loss: 2136.5736
# Epoch [116/200], Train Loss: 2722.4542, Recon Loss: 2137.1474
# Epoch [117/200], Train Loss: 2725.7760, Recon Loss: 2137.8101
# Epoch [118/200], Train Loss: 2724.0659, Recon Loss: 2136.2939
# Epoch [119/200], Train Loss: 2722.1059, Recon Loss: 2135.9040
# Epoch [120/200], Train Loss: 2719.2645, Recon Loss: 2135.9693
# Epoch [121/200], Train Loss: 2716.5537, Recon Loss: 2127.6494
# Epoch [122/200], Train Loss: 2711.9574, Recon Loss: 2125.9947
# Epoch [123/200], Train Loss: 2714.3014, Recon Loss: 2127.5707
# Epoch [124/200], Train Loss: 2711.2087, Recon Loss: 2123.3273
# Epoch [125/200], Train Loss: 2713.1291, Recon Loss: 2123.9842
# Epoch [126/200], Train Loss: 2708.0367, Recon Loss: 2119.9411
# Epoch [127/200], Train Loss: 2708.9180, Recon Loss: 2120.2595
# Epoch [128/200], Train Loss: 2708.1513, Recon Loss: 2121.1391
# Epoch [129/200], Train Loss: 2709.7450, Recon Loss: 2119.6176
# Epoch [130/200], Train Loss: 2712.3283, Recon Loss: 2117.5254
# Epoch [131/200], Train Loss: 2710.1123, Recon Loss: 2117.6029
# Epoch [132/200], Train Loss: 2703.6308, Recon Loss: 2115.4130
# Epoch [133/200], Train Loss: 2705.8754, Recon Loss: 2114.2655
# Epoch [134/200], Train Loss: 2704.1531, Recon Loss: 2111.2218
# Epoch [135/200], Train Loss: 2701.4796, Recon Loss: 2109.8833
# Epoch [136/200], Train Loss: 2699.8079, Recon Loss: 2106.5832
# Epoch [137/200], Train Loss: 2697.6617, Recon Loss: 2106.7295
# Epoch [138/200], Train Loss: 2707.7507, Recon Loss: 2113.9563
# Epoch [139/200], Train Loss: 2697.1191, Recon Loss: 2104.3606
# Epoch [140/200], Train Loss: 2698.2134, Recon Loss: 2103.4687
# Epoch [141/200], Train Loss: 2695.9868, Recon Loss: 2104.2958
# Epoch [142/200], Train Loss: 2698.2856, Recon Loss: 2105.9213
# Epoch [143/200], Train Loss: 2694.6610, Recon Loss: 2100.7530
# Epoch [144/200], Train Loss: 2700.6492, Recon Loss: 2103.0157
# Epoch [145/200], Train Loss: 2694.6846, Recon Loss: 2097.7857
# Epoch [146/200], Train Loss: 2695.2631, Recon Loss: 2098.7974
# Epoch [147/200], Train Loss: 2689.0466, Recon Loss: 2097.4481
# Epoch [148/200], Train Loss: 2691.3654, Recon Loss: 2096.8436
# Epoch [149/200], Train Loss: 2687.8527, Recon Loss: 2095.6803
# Epoch [150/200], Train Loss: 2686.5201, Recon Loss: 2091.6009
# Epoch [151/200], Train Loss: 2690.3354, Recon Loss: 2096.4335
# Epoch [152/200], Train Loss: 2690.9942, Recon Loss: 2095.0441
# Epoch [153/200], Train Loss: 2684.1547, Recon Loss: 2089.3892
# Epoch [154/200], Train Loss: 2686.3974, Recon Loss: 2090.0707
# Epoch [155/200], Train Loss: 2684.7028, Recon Loss: 2086.8275
# Epoch [156/200], Train Loss: 2687.4686, Recon Loss: 2087.6667
# Epoch [157/200], Train Loss: 2690.3551, Recon Loss: 2091.7037
# Epoch [158/200], Train Loss: 2688.1376, Recon Loss: 2084.5703
# Epoch [159/200], Train Loss: 2684.9728, Recon Loss: 2086.3649
# Epoch [160/200], Train Loss: 2681.1036, Recon Loss: 2081.8953
# Epoch [161/200], Train Loss: 2681.7955, Recon Loss: 2082.1001
# Epoch [162/200], Train Loss: 2680.0329, Recon Loss: 2080.4257
# Epoch [163/200], Train Loss: 2680.4985, Recon Loss: 2083.0111
# Epoch [164/200], Train Loss: 2676.3723, Recon Loss: 2077.1514
# Epoch [165/200], Train Loss: 2680.4373, Recon Loss: 2081.8230
# Epoch [166/200], Train Loss: 2676.3658, Recon Loss: 2077.7388
# Epoch [167/200], Train Loss: 2676.5654, Recon Loss: 2074.9603
# Epoch [168/200], Train Loss: 2677.0191, Recon Loss: 2076.9808
# Epoch [169/200], Train Loss: 2672.7743, Recon Loss: 2072.9822
# Epoch [170/200], Train Loss: 2674.3127, Recon Loss: 2072.8724
# Epoch [171/200], Train Loss: 2675.8991, Recon Loss: 2075.9091
# Epoch [172/200], Train Loss: 2674.9618, Recon Loss: 2071.5183
# Epoch [173/200], Train Loss: 2675.1266, Recon Loss: 2074.0006
# Epoch [174/200], Train Loss: 2677.1048, Recon Loss: 2074.7904
# Epoch [175/200], Train Loss: 2669.6941, Recon Loss: 2069.6073
# Epoch [176/200], Train Loss: 2671.7352, Recon Loss: 2067.2308
# Epoch [177/200], Train Loss: 2674.3764, Recon Loss: 2070.6689
# Epoch [178/200], Train Loss: 2671.4549, Recon Loss: 2065.2637
# Epoch [179/200], Train Loss: 2671.0082, Recon Loss: 2069.7532
# Epoch [180/200], Train Loss: 2668.3152, Recon Loss: 2065.0037
# Epoch [181/200], Train Loss: 2671.6972, Recon Loss: 2068.1198
# Epoch [182/200], Train Loss: 2663.8242, Recon Loss: 2063.4313
# Epoch [183/200], Train Loss: 2668.8718, Recon Loss: 2067.3508
# Epoch [184/200], Train Loss: 2667.3860, Recon Loss: 2064.1843
# Epoch [185/200], Train Loss: 2661.0129, Recon Loss: 2056.1583
# Epoch [186/200], Train Loss: 2661.4901, Recon Loss: 2058.6637
# Epoch [187/200], Train Loss: 2660.9358, Recon Loss: 2056.6097
# Epoch [188/200], Train Loss: 2662.7890, Recon Loss: 2057.1878
# Epoch [189/200], Train Loss: 2665.1788, Recon Loss: 2061.7005
# Epoch [190/200], Train Loss: 2664.8653, Recon Loss: 2058.8183
# Epoch [191/200], Train Loss: 2661.8992, Recon Loss: 2056.2167
# Epoch [192/200], Train Loss: 2668.3883, Recon Loss: 2058.1676
# Epoch [193/200], Train Loss: 2660.0877, Recon Loss: 2052.8750
# Epoch [194/200], Train Loss: 2658.3779, Recon Loss: 2051.6714
# Epoch [195/200], Train Loss: 2663.1697, Recon Loss: 2055.0895
# Epoch [196/200], Train Loss: 2659.4216, Recon Loss: 2053.1144
# Epoch [197/200], Train Loss: 2657.1218, Recon Loss: 2051.2347
# Epoch [198/200], Train Loss: 2657.0189, Recon Loss: 2047.9878
# Epoch [199/200], Train Loss: 2661.0038, Recon Loss: 2053.1794
# Epoch [200/200], Train Loss: 2656.9661, Recon Loss: 2049.4404

# %%
plt.figure(figsize=(10, 8))
plt.title("Loss vs Epochs")
plt.plot(q2_train_losses, label="Training Loss")
plt.xlabel("Epochs")
plt.ylabel("Loss")
plt.legend()
plt.show()

# %%
def visualize_vae_generations(model, latent_dim, device):
    # Generate random images
    random_latents = torch.randn((10, latent_dim)).to(device)
    with torch.no_grad():
        random_images = model.decoder(random_latents)

    # Plot random images
    fig, axes = plt.subplots(2, 5, figsize=(5,2))
    for ax, img in zip(axes.flatten(), random_images):
        ax.imshow(img.cpu().reshape(28, 28), cmap='gray')
        ax.axis('off')
    plt.suptitle("Randomly Generated Images")
    plt.tight_layout()
    plt.show()

    # Generate images with varied latent dimensions
    num_variations = 20
    base_latent = torch.randn(latent_dim).to(device)
    variation_range = torch.linspace(-5, 5, num_variations).to(device)

    for dim in range(latent_dim):
        varied_latents = base_latent.repeat(num_variations, 1)
        varied_latents[:, dim] = variation_range

        with torch.no_grad():
            varied_images = model.decoder(varied_latents)

        # Plot varied dimension images
        fig, axes = plt.subplots(2, 10, figsize=(15, 4.5))
        for ax, img in zip(axes.flatten(), varied_images):
            ax.imshow(img.cpu().reshape(28, 28), cmap='gray')
            ax.axis('off')
        plt.suptitle(f"Images with Varied Latent Dimension {dim+1}")
        plt.tight_layout()
        plt.show()

# %%
latent_dim = 3
visualize_vae_generations(q2_model, latent_dim, device)

# %% [markdown]
# ## **Problem 3: Conditional GAN**

# %%
# Load MNIST
q3_transform = transforms.Compose([
    transforms.ToTensor(),
    transforms.Normalize((0.5,), (0.5,))
])

# Create datasets with the transform
q3_train_dataset = torchvision.datasets.MNIST(root='./data', train=True, download=True, transform=q3_transform)
q3_test_dataset = torchvision.datasets.MNIST(root='./data', train=False, download=True, transform=q3_transform)

# Creata dataloader
q3_train_loader = DataLoader(q3_train_dataset, batch_size=100, shuffle=True)
q3_test_loader = DataLoader(q3_test_dataset, batch_size=100, shuffle=False)

# %%
class Generator(nn.Module):
    def __init__(self, ddim_vector=100, num_classes=10):
        super(Generator, self).__init__()
        self.input_dim = ddim_vector + num_classes
        self.linear1 = nn.Linear(self.input_dim, 200)
        self.linear2 = nn.Linear(200, 400)
        self.linear3 = nn.Linear(400, 784)
        self.relu = nn.ReLU()
        self.tanh = nn.Tanh()
        self._init_weights()
    
    def _init_weights(self):
        for layer in self.modules():
            if isinstance(layer, nn.Linear):
                nn.init.xavier_uniform_(layer.weight)
                if layer.bias is not None:
                    nn.init.constant_(layer.bias, 0)
                    
    def forward(self, gen_input):
        x = self.linear1(gen_input)
        x = self.relu(x)
        x = self.linear2(x)
        x = self.relu(x)
        x = self.linear3(x)
        img = self.tanh(x)
        return img

# %%
class Discriminator(nn.Module):
    def __init__(self, num_classes=10):
        super(Discriminator, self).__init__()
        self.linear1 = nn.Linear(794, 400)
        self.linear2 = nn.Linear(400, 200)
        self.linear3 = nn.Linear(200, 100)
        self.linear4 = nn.Linear(100, 1)
        self.relu = nn.ReLU()
        self.sigmoid = nn.Sigmoid()
        self.dropout = nn.Dropout(0.2)
        self._init_weights()

    def _init_weights(self):
        for layer in self.modules():
            if isinstance(layer, nn.Linear):
                nn.init.xavier_uniform_(layer.weight)
                if layer.bias is not None:
                    nn.init.constant_(layer.bias, 0)

    def forward(self, dis_input):
        x = self.linear1(dis_input)
        x = self.relu(x)
        x = self.dropout(x)
        x = self.linear2(x)
        x = self.relu(x)
        x = self.dropout(x)
        x = self.linear3(x)
        x = self.relu(x)
        x = self.linear4(x)
        output = self.sigmoid(x)
        return output

# %%
def train_q3_model(generator, discriminator, data_loader, loss_function, generator_optimizer, discriminator_optimizer, device, num_classes=10, num_epochs=100, ddim=100):
    # Track performance metrics
    real_accuracy_per_epoch = []
    fake_accuracy_per_epoch = []

    for epoch in range(num_epochs):
        generator.train()
        discriminator.train()
        
        total_generator_loss = 0.0
        total_discriminator_loss = 0.0
        correct_real_predictions = 0
        correct_fake_predictions = 0
        
        for images, labels in data_loader:
            batch_size = images.size(0)
            images, labels = images.to(device), labels.to(device)
            
            # Flatten images and encode labels
            images = images.view(batch_size, -1)
            one_hot_labels = nn.functional.one_hot(labels, num_classes=num_classes).float().to(device)
            
            # Prepare real and fake inputs
            real_images_with_labels = torch.cat((images, one_hot_labels), dim=1)
            real_labels = torch.ones(batch_size, 1, dtype=torch.float).to(device)
            fake_labels = torch.zeros(batch_size, 1, dtype=torch.float).to(device)
        
            discriminator_optimizer.zero_grad()
            
            # Discriminator forward pass for real images
            real_predictions = discriminator(real_images_with_labels)
            real_loss = loss_function(real_predictions, real_labels)
            real_loss.backward()
            
            # Generate fake images
            random_vector = torch.randn(batch_size, ddim).to(device)
            random_vector_with_labels = torch.cat((random_vector, one_hot_labels), dim=1)
            generated_images = generator(random_vector_with_labels)
            fake_images_with_labels = torch.cat((generated_images, one_hot_labels), dim=1)
            
            # Discriminator forward pass for fake images
            fake_predictions = discriminator(fake_images_with_labels.detach())
            fake_loss = loss_function(fake_predictions, fake_labels)
            fake_loss.backward()
            discriminator_optimizer.step()
        
            generator_optimizer.zero_grad()
            
            # Generator forward pass to fool discriminator
            generator_predictions = discriminator(fake_images_with_labels)
            generator_loss = loss_function(generator_predictions, real_labels)
            generator_loss.backward()
            
            generator_optimizer.step()
            
            # Accumulate losses
            total_discriminator_loss += (real_loss.item() + fake_loss.item()) * batch_size
            total_generator_loss += generator_loss.item() * batch_size
            
            # Accumulate predictions for accuracy calculation
            with torch.no_grad():
                correct_real_predictions += real_predictions.sum().item()
                correct_fake_predictions += fake_predictions.sum().item()
        
        # Calculate epoch-level metrics
        avg_discriminator_loss = total_discriminator_loss / (2 * len(data_loader.dataset))
        avg_generator_loss = total_generator_loss / len(data_loader.dataset)
        
        real_accuracy = correct_real_predictions / len(data_loader.dataset)
        fake_accuracy = correct_fake_predictions / len(data_loader.dataset)

        real_accuracy_per_epoch.append(real_accuracy)
        fake_accuracy_per_epoch.append(fake_accuracy)
        
        # Print metrics for the current epoch
        print(f'Epoch [{epoch + 1}/{num_epochs}], Dis Loss: {avg_discriminator_loss:.4f}, Gen Loss: {avg_generator_loss:.4f}, '
               f'Real Accuracy: {real_accuracy * 100:.2f}%, Fake Accuracy: {fake_accuracy * 100:.2f}%')

    return avg_discriminator_loss, avg_generator_loss, real_accuracy_per_epoch, fake_accuracy_per_epoch

# %%
q3_generator = Generator(100, 10).to(device)
gen_optimizer = torch.optim.Adam(q3_generator.parameters(), lr=0.00015)
q3_disriminator = Discriminator(10).to(device)
dis_optimizer = torch.optim.Adam(q3_disriminator.parameters(), lr=0.00015)
q3_criterion = nn.BCELoss()

q3_dis_loss, q3_gen_loss, q3_real_accu, q3_fake_accu = train_q3_model(
    q3_generator,
    q3_disriminator,
    q3_train_loader,
    q3_criterion,
    gen_optimizer,
    dis_optimizer,
    device
)
# Out:
# Epoch [1/100], Dis Loss: 0.1155, Gen Loss: 4.0485, Real Accuracy: 95.11%, Fake Accuracy: 12.46%
# Epoch [2/100], Dis Loss: 0.0643, Gen Loss: 4.7235, Real Accuracy: 95.67%, Fake Accuracy: 5.60%
# Epoch [3/100], Dis Loss: 0.0615, Gen Loss: 5.6967, Real Accuracy: 96.09%, Fake Accuracy: 3.93%
# Epoch [4/100], Dis Loss: 0.0919, Gen Loss: 4.5497, Real Accuracy: 94.44%, Fake Accuracy: 5.66%
# Epoch [5/100], Dis Loss: 0.1078, Gen Loss: 4.2494, Real Accuracy: 93.77%, Fake Accuracy: 6.30%
# Epoch [6/100], Dis Loss: 0.0982, Gen Loss: 4.3805, Real Accuracy: 94.40%, Fake Accuracy: 5.54%
# Epoch [7/100], Dis Loss: 0.1121, Gen Loss: 4.1853, Real Accuracy: 93.68%, Fake Accuracy: 6.35%
# Epoch [8/100], Dis Loss: 0.1173, Gen Loss: 4.1691, Real Accuracy: 93.53%, Fake Accuracy: 6.59%
# Epoch [9/100], Dis Loss: 0.1280, Gen Loss: 4.0213, Real Accuracy: 92.89%, Fake Accuracy: 7.35%
# Epoch [10/100], Dis Loss: 0.1621, Gen Loss: 3.6776, Real Accuracy: 90.86%, Fake Accuracy: 9.30%
# Epoch [11/100], Dis Loss: 0.1700, Gen Loss: 3.4650, Real Accuracy: 90.19%, Fake Accuracy: 10.09%
# Epoch [12/100], Dis Loss: 0.1976, Gen Loss: 3.2875, Real Accuracy: 88.38%, Fake Accuracy: 11.94%
# Epoch [13/100], Dis Loss: 0.2158, Gen Loss: 3.0829, Real Accuracy: 87.27%, Fake Accuracy: 13.00%
# Epoch [14/100], Dis Loss: 0.2244, Gen Loss: 3.1984, Real Accuracy: 87.06%, Fake Accuracy: 13.61%
# Epoch [15/100], Dis Loss: 0.2380, Gen Loss: 3.0565, Real Accuracy: 85.88%, Fake Accuracy: 14.55%
# Epoch [16/100], Dis Loss: 0.2465, Gen Loss: 2.9465, Real Accuracy: 85.35%, Fake Accuracy: 15.00%
# Epoch [17/100], Dis Loss: 0.2623, Gen Loss: 2.7139, Real Accuracy: 84.22%, Fake Accuracy: 16.35%
# Epoch [18/100], Dis Loss: 0.2780, Gen Loss: 2.6041, Real Accuracy: 83.09%, Fake Accuracy: 17.33%
# Epoch [19/100], Dis Loss: 0.2730, Gen Loss: 2.6786, Real Accuracy: 83.50%, Fake Accuracy: 16.91%
# Epoch [20/100], Dis Loss: 0.2861, Gen Loss: 2.5379, Real Accuracy: 82.66%, Fake Accuracy: 17.81%
# Epoch [21/100], Dis Loss: 0.3016, Gen Loss: 2.3945, Real Accuracy: 81.55%, Fake Accuracy: 18.89%
# Epoch [22/100], Dis Loss: 0.3171, Gen Loss: 2.2861, Real Accuracy: 80.37%, Fake Accuracy: 19.76%
# Epoch [23/100], Dis Loss: 0.3166, Gen Loss: 2.3030, Real Accuracy: 80.52%, Fake Accuracy: 19.90%
# Epoch [24/100], Dis Loss: 0.3314, Gen Loss: 2.2324, Real Accuracy: 79.43%, Fake Accuracy: 20.90%
# Epoch [25/100], Dis Loss: 0.3437, Gen Loss: 2.1501, Real Accuracy: 78.47%, Fake Accuracy: 21.83%
# Epoch [26/100], Dis Loss: 0.3460, Gen Loss: 2.1358, Real Accuracy: 78.48%, Fake Accuracy: 22.13%
# Epoch [27/100], Dis Loss: 0.3598, Gen Loss: 2.1015, Real Accuracy: 77.45%, Fake Accuracy: 22.76%
# Epoch [28/100], Dis Loss: 0.3874, Gen Loss: 1.9214, Real Accuracy: 75.47%, Fake Accuracy: 24.79%
# Epoch [29/100], Dis Loss: 0.3843, Gen Loss: 1.9270, Real Accuracy: 75.51%, Fake Accuracy: 24.65%
# Epoch [30/100], Dis Loss: 0.4034, Gen Loss: 1.7828, Real Accuracy: 74.23%, Fake Accuracy: 26.28%
# Epoch [31/100], Dis Loss: 0.4037, Gen Loss: 1.7783, Real Accuracy: 73.99%, Fake Accuracy: 26.27%
# Epoch [32/100], Dis Loss: 0.4289, Gen Loss: 1.6557, Real Accuracy: 72.29%, Fake Accuracy: 28.00%
# Epoch [33/100], Dis Loss: 0.4463, Gen Loss: 1.5899, Real Accuracy: 71.02%, Fake Accuracy: 29.24%
# Epoch [34/100], Dis Loss: 0.4712, Gen Loss: 1.4893, Real Accuracy: 69.06%, Fake Accuracy: 30.90%
# Epoch [35/100], Dis Loss: 0.4777, Gen Loss: 1.4565, Real Accuracy: 68.45%, Fake Accuracy: 31.53%
# Epoch [36/100], Dis Loss: 0.4807, Gen Loss: 1.4333, Real Accuracy: 68.31%, Fake Accuracy: 31.84%
# Epoch [37/100], Dis Loss: 0.4889, Gen Loss: 1.4060, Real Accuracy: 67.70%, Fake Accuracy: 32.51%
# Epoch [38/100], Dis Loss: 0.4943, Gen Loss: 1.3659, Real Accuracy: 67.06%, Fake Accuracy: 33.03%
# Epoch [39/100], Dis Loss: 0.5080, Gen Loss: 1.3304, Real Accuracy: 66.16%, Fake Accuracy: 33.84%
# Epoch [40/100], Dis Loss: 0.5156, Gen Loss: 1.2783, Real Accuracy: 65.45%, Fake Accuracy: 34.68%
# Epoch [41/100], Dis Loss: 0.5264, Gen Loss: 1.2445, Real Accuracy: 64.58%, Fake Accuracy: 35.46%
# Epoch [42/100], Dis Loss: 0.5320, Gen Loss: 1.2334, Real Accuracy: 64.17%, Fake Accuracy: 35.80%
# Epoch [43/100], Dis Loss: 0.5307, Gen Loss: 1.2296, Real Accuracy: 64.14%, Fake Accuracy: 35.70%
# Epoch [44/100], Dis Loss: 0.5339, Gen Loss: 1.2240, Real Accuracy: 64.11%, Fake Accuracy: 35.88%
# Epoch [45/100], Dis Loss: 0.5390, Gen Loss: 1.2008, Real Accuracy: 63.63%, Fake Accuracy: 36.45%
# Epoch [46/100], Dis Loss: 0.5432, Gen Loss: 1.1758, Real Accuracy: 63.13%, Fake Accuracy: 36.80%
# Epoch [47/100], Dis Loss: 0.5487, Gen Loss: 1.1846, Real Accuracy: 62.90%, Fake Accuracy: 37.01%
# Epoch [48/100], Dis Loss: 0.5574, Gen Loss: 1.1358, Real Accuracy: 62.12%, Fake Accuracy: 37.85%
# Epoch [49/100], Dis Loss: 0.5709, Gen Loss: 1.0837, Real Accuracy: 60.95%, Fake Accuracy: 38.96%
# Epoch [50/100], Dis Loss: 0.5713, Gen Loss: 1.0808, Real Accuracy: 60.91%, Fake Accuracy: 39.07%
# Epoch [51/100], Dis Loss: 0.5721, Gen Loss: 1.0800, Real Accuracy: 60.74%, Fake Accuracy: 39.14%
# Epoch [52/100], Dis Loss: 0.5749, Gen Loss: 1.0720, Real Accuracy: 60.65%, Fake Accuracy: 39.36%
# Epoch [53/100], Dis Loss: 0.5760, Gen Loss: 1.0755, Real Accuracy: 60.57%, Fake Accuracy: 39.44%
# Epoch [54/100], Dis Loss: 0.5768, Gen Loss: 1.0691, Real Accuracy: 60.50%, Fake Accuracy: 39.53%
# Epoch [55/100], Dis Loss: 0.5848, Gen Loss: 1.0247, Real Accuracy: 59.79%, Fake Accuracy: 40.36%
# Epoch [56/100], Dis Loss: 0.5878, Gen Loss: 1.0292, Real Accuracy: 59.52%, Fake Accuracy: 40.43%
# Epoch [57/100], Dis Loss: 0.5899, Gen Loss: 1.0266, Real Accuracy: 59.31%, Fake Accuracy: 40.49%
# Epoch [58/100], Dis Loss: 0.5935, Gen Loss: 1.0180, Real Accuracy: 58.99%, Fake Accuracy: 40.67%
# Epoch [59/100], Dis Loss: 0.5906, Gen Loss: 1.0161, Real Accuracy: 59.25%, Fake Accuracy: 40.67%
# Epoch [60/100], Dis Loss: 0.5921, Gen Loss: 1.0115, Real Accuracy: 59.24%, Fake Accuracy: 40.88%
# Epoch [61/100], Dis Loss: 0.5959, Gen Loss: 1.0036, Real Accuracy: 58.86%, Fake Accuracy: 41.10%
# Epoch [62/100], Dis Loss: 0.6003, Gen Loss: 0.9910, Real Accuracy: 58.52%, Fake Accuracy: 41.43%
# Epoch [63/100], Dis Loss: 0.5967, Gen Loss: 0.9994, Real Accuracy: 58.73%, Fake Accuracy: 41.19%
# Epoch [64/100], Dis Loss: 0.5992, Gen Loss: 0.9897, Real Accuracy: 58.58%, Fake Accuracy: 41.44%
# Epoch [65/100], Dis Loss: 0.6008, Gen Loss: 0.9809, Real Accuracy: 58.33%, Fake Accuracy: 41.56%
# Epoch [66/100], Dis Loss: 0.6044, Gen Loss: 0.9774, Real Accuracy: 58.09%, Fake Accuracy: 41.74%
# Epoch [67/100], Dis Loss: 0.6057, Gen Loss: 0.9661, Real Accuracy: 57.97%, Fake Accuracy: 41.97%
# Epoch [68/100], Dis Loss: 0.6067, Gen Loss: 0.9640, Real Accuracy: 57.95%, Fake Accuracy: 42.07%
# Epoch [69/100], Dis Loss: 0.6060, Gen Loss: 0.9730, Real Accuracy: 57.96%, Fake Accuracy: 41.96%
# Epoch [70/100], Dis Loss: 0.6097, Gen Loss: 0.9488, Real Accuracy: 57.66%, Fake Accuracy: 42.38%
# Epoch [71/100], Dis Loss: 0.6055, Gen Loss: 0.9536, Real Accuracy: 57.97%, Fake Accuracy: 42.20%
# Epoch [72/100], Dis Loss: 0.6059, Gen Loss: 0.9699, Real Accuracy: 58.00%, Fake Accuracy: 41.96%
# Epoch [73/100], Dis Loss: 0.6096, Gen Loss: 0.9588, Real Accuracy: 57.71%, Fake Accuracy: 42.20%
# Epoch [74/100], Dis Loss: 0.6115, Gen Loss: 0.9499, Real Accuracy: 57.48%, Fake Accuracy: 42.45%
# Epoch [75/100], Dis Loss: 0.6113, Gen Loss: 0.9571, Real Accuracy: 57.55%, Fake Accuracy: 42.31%
# Epoch [76/100], Dis Loss: 0.6132, Gen Loss: 0.9469, Real Accuracy: 57.29%, Fake Accuracy: 42.56%
# Epoch [77/100], Dis Loss: 0.6161, Gen Loss: 0.9354, Real Accuracy: 57.14%, Fake Accuracy: 42.80%
# Epoch [78/100], Dis Loss: 0.6155, Gen Loss: 0.9386, Real Accuracy: 57.14%, Fake Accuracy: 42.78%
# Epoch [79/100], Dis Loss: 0.6152, Gen Loss: 0.9344, Real Accuracy: 57.17%, Fake Accuracy: 42.84%
# Epoch [80/100], Dis Loss: 0.6126, Gen Loss: 0.9443, Real Accuracy: 57.39%, Fake Accuracy: 42.54%
# Epoch [81/100], Dis Loss: 0.6183, Gen Loss: 0.9265, Real Accuracy: 56.91%, Fake Accuracy: 43.09%
# Epoch [82/100], Dis Loss: 0.6166, Gen Loss: 0.9378, Real Accuracy: 57.11%, Fake Accuracy: 42.87%
# Epoch [83/100], Dis Loss: 0.6205, Gen Loss: 0.9151, Real Accuracy: 56.71%, Fake Accuracy: 43.35%
# Epoch [84/100], Dis Loss: 0.6187, Gen Loss: 0.9256, Real Accuracy: 56.83%, Fake Accuracy: 43.10%
# Epoch [85/100], Dis Loss: 0.6215, Gen Loss: 0.9214, Real Accuracy: 56.72%, Fake Accuracy: 43.24%
# Epoch [86/100], Dis Loss: 0.6177, Gen Loss: 0.9300, Real Accuracy: 57.01%, Fake Accuracy: 43.11%
# Epoch [87/100], Dis Loss: 0.6161, Gen Loss: 0.9333, Real Accuracy: 57.16%, Fake Accuracy: 42.93%
# Epoch [88/100], Dis Loss: 0.6201, Gen Loss: 0.9276, Real Accuracy: 56.79%, Fake Accuracy: 43.13%
# Epoch [89/100], Dis Loss: 0.6178, Gen Loss: 0.9213, Real Accuracy: 56.93%, Fake Accuracy: 43.16%
# Epoch [90/100], Dis Loss: 0.6217, Gen Loss: 0.9233, Real Accuracy: 56.63%, Fake Accuracy: 43.20%
# Epoch [91/100], Dis Loss: 0.6208, Gen Loss: 0.9280, Real Accuracy: 56.73%, Fake Accuracy: 43.13%
# Epoch [92/100], Dis Loss: 0.6220, Gen Loss: 0.9149, Real Accuracy: 56.63%, Fake Accuracy: 43.37%
# Epoch [93/100], Dis Loss: 0.6226, Gen Loss: 0.9169, Real Accuracy: 56.53%, Fake Accuracy: 43.32%
# Epoch [94/100], Dis Loss: 0.6224, Gen Loss: 0.9107, Real Accuracy: 56.58%, Fake Accuracy: 43.40%
# Epoch [95/100], Dis Loss: 0.6213, Gen Loss: 0.9129, Real Accuracy: 56.63%, Fake Accuracy: 43.39%
# Epoch [96/100], Dis Loss: 0.6250, Gen Loss: 0.9073, Real Accuracy: 56.38%, Fake Accuracy: 43.60%
# Epoch [97/100], Dis Loss: 0.6219, Gen Loss: 0.9144, Real Accuracy: 56.53%, Fake Accuracy: 43.33%
# Epoch [98/100], Dis Loss: 0.6251, Gen Loss: 0.9058, Real Accuracy: 56.37%, Fake Accuracy: 43.66%
# Epoch [99/100], Dis Loss: 0.6255, Gen Loss: 0.9061, Real Accuracy: 56.27%, Fake Accuracy: 43.66%
# Epoch [100/100], Dis Loss: 0.6271, Gen Loss: 0.9013, Real Accuracy: 56.23%, Fake Accuracy: 43.78%

# %%
plt.figure(figsize=(10, 8))
plt.plot(q3_real_accu, label='Discriminator Real Accuracy', color='red')
plt.plot(q3_fake_accu, label='Discriminator Fake Accuracy', color='blue')
plt.title('Accuracy vs Epochs')
plt.xlabel("Epochs")
plt.ylabel("Accuracy Score")
plt.legend()
plt.tight_layout()
plt.show()

# %%
def q3_generate_images(generator, ddim, num_classes, device, samples_per_class=10):
    # Prepare one-hot encoded class labels
    one_hot_labels = nn.functional.one_hot(
        torch.arange(num_classes).repeat_interleave(samples_per_class), 
        num_classes=num_classes
    ).float().to(device)
    
    # Generate random latent vectors
    random_vectors = torch.randn(num_classes * samples_per_class, ddim, device=device)
    
    # Combine latent vectors with class labels
    generator_input = torch.cat((random_vectors, one_hot_labels), dim=1)
    
    # Generate fake images
    with torch.no_grad():
        generator.eval()
        generated_images = generator(generator_input)
    
    return generated_images.cpu().numpy()

# %%
q3_fake_images = q3_generate_images(q3_generator, 100, 10, device)

# %%
plt.figure(figsize=(10, 8))
plt.suptitle("Fake Generated Images")
for i in range(100):
    plt.subplot(10, 10, i+1)
    plt.imshow(q3_fake_images[i].reshape(28, 28))
    plt.axis('off')
plt.show()

# %% [markdown]
# ## **Problem 4: Missing Value Imputation using Conditional GAN**

# %%
# Load MNIST
q4_transform = transforms.Compose([
    transforms.ToTensor(),
    transforms.Normalize((0.5,), (0.5,))
])

# Create datasets with the transform
q4_train_dataset = torchvision.datasets.MNIST(root='./data', train=True, download=True, transform=q4_transform)
q4_test_dataset = torchvision.datasets.MNIST(root='./data', train=False, download=True, transform=q4_transform)

# Creata dataloader
q4_train_loader = DataLoader(q4_train_dataset, batch_size=100, shuffle=True)
q4_test_loader = DataLoader(q4_test_dataset, batch_size=100, shuffle=False)

# %%
class Q4Generator(nn.Module):
    def __init__(self):
        super(Q4Generator, self).__init__()
        self.linear1 = nn.Linear(200, 1024)
        self.linear2 = nn.Linear(1024, 2048)
        self.linear3 = nn.Linear(2048, 1024)
        self.linear4 = nn.Linear(1024, 784)
        self.relu = nn.ReLU()
        self.tanh = nn.Tanh()
        self._init_weights()
    
    def _init_weights(self):
        for layer in self.modules():
            if isinstance(layer, nn.Linear):
                nn.init.xavier_uniform_(layer.weight)
                if layer.bias is not None:
                    nn.init.constant_(layer.bias, 0)
                    
    def forward(self, gen_input):
        x = self.linear1(gen_input)
        x = self.relu(x)
        x = self.linear2(x)
        x = self.relu(x)
        x = self.linear3(x)
        x = self.relu(x)
        x = self.linear4(x)
        img = self.tanh(x)
        return img

# %%
class Q4Discriminator(nn.Module):
    def __init__(self):
        super(Q4Discriminator, self).__init__()
        self.linear1 = nn.Linear(784, 2048)
        self.linear2 = nn.Linear(2048, 1024)
        self.linear3 = nn.Linear(1024, 512)
        self.linear4 = nn.Linear(512, 256)
        self.linear5 = nn.Linear(256, 1)
        self.relu = nn.ReLU()
        self.sigmoid = nn.Sigmoid()
        self.dropout = nn.Dropout(0.2)
        self._init_weights()
    
    def _init_weights(self):
        for layer in self.modules():
            if isinstance(layer, nn.Linear):
                nn.init.xavier_uniform_(layer.weight)
                if layer.bias is not None:
                    nn.init.constant_(layer.bias, 0)
                    
    def forward(self, dis_input):
        x = self.linear1(dis_input)
        x = self.relu(x)
        x = self.dropout(x)
        x = self.linear2(x)
        x = self.relu(x)
        x = self.dropout(x)
        x = self.linear3(x)
        x = self.relu(x)
        x = self.dropout(x)
        x = self.linear4(x)
        x = self.relu(x)
        x = self.dropout(x)
        x = self.linear5(x)
        img = self.sigmoid(x)
        return img

# %%
def train_q4_model(generator, discriminator, data_loader, loss_function, generator_optimizer, discriminator_optimizer, device, lam=0.1, num_classes=10, num_epochs=100, ddim=100):
    # Track performance metrics
    real_accuracy_per_epoch = []
    fake_accuracy_per_epoch = []

    for epoch in range(num_epochs):
        generator.train()
        discriminator.train()
        
        total_generator_loss = 0.0
        total_discriminator_loss = 0.0
        correct_real_predictions = 0
        correct_fake_predictions = 0
        
        for images, labels in data_loader:
            batch_size = images.size(0)
            images, labels = images.to(device), labels.to(device)
            
            # Flatten images
            images = images.view(batch_size, -1)
            
            # Prepare discriminator targets
            real_labels = torch.ones(batch_size, 1, dtype=torch.float).to(device)
            fake_labels = torch.zeros(batch_size, 1, dtype=torch.float).to(device)
        
            discriminator_optimizer.zero_grad()
            
            # Discriminator forward pass for real images
            real_predictions = discriminator(images)
            real_loss = loss_function(real_predictions, real_labels)
            real_loss.backward()
            
            # Generate fake images
            random_vector = torch.randn(batch_size, ddim).to(device)
            center_patches = images.reshape(images.size(0), 1, 28, 28)
            center_patches = center_patches[:, :, 9:19, 9:19].reshape(center_patches.size(0), -1)
            random_vector_with_center_patch = torch.cat((random_vector, center_patches), dim=1)
            generated_images = generator(random_vector_with_center_patch)
            
            # Discriminator forward pass for fake images
            fake_predictions = discriminator(generated_images.detach())
            fake_loss = loss_function(fake_predictions, fake_labels)
            fake_loss.backward()
            discriminator_optimizer.step()
        
            generator_optimizer.zero_grad()
            
            # Generator forward pass to fool discriminator
            generator_predictions = discriminator(generated_images)
            
            # BCE loss + MSE loss for patch condition
            pred_patches = generated_images.reshape(images.size(0), 1, 28, 28)
            pred_patches = pred_patches[:, :, 9:19, 9:19].reshape(pred_patches.size(0), -1)
            mse_loss = nn.MSELoss()
            generator_loss = loss_function(generator_predictions, real_labels) + lam * mse_loss(pred_patches, center_patches)

            generator_loss.backward()
            
            generator_optimizer.step()
            
            # Accumulate losses
            total_discriminator_loss += (real_loss.item() + fake_loss.item()) * batch_size
            total_generator_loss += generator_loss.item() * batch_size
            
            # Accumulate predictions for accuracy calculation
            with torch.no_grad():
                correct_real_predictions += real_predictions.sum().item()
                correct_fake_predictions += fake_predictions.sum().item()
        
        # Calculate epoch-level metrics
        avg_discriminator_loss = total_discriminator_loss / (2 * len(data_loader.dataset))
        avg_generator_loss = total_generator_loss / len(data_loader.dataset)
        
        real_accuracy = correct_real_predictions / len(data_loader.dataset)
        fake_accuracy = correct_fake_predictions / len(data_loader.dataset)

        real_accuracy_per_epoch.append(real_accuracy)
        fake_accuracy_per_epoch.append(fake_accuracy)
 
        # Print metrics for the current epoch
        print(f'Epoch [{epoch + 1}/{num_epochs}], Dis Loss: {avg_discriminator_loss:.4f}, Gen Loss: {avg_generator_loss:.4f}, '
               f'Real Accuracy: {real_accuracy * 100:.2f}%, Fake Accuracy: {fake_accuracy * 100:.2f}%')

    return avg_discriminator_loss, avg_generator_loss, real_accuracy_per_epoch, fake_accuracy_per_epoch

# %%
q4_generator_01 = Q4Generator().to(device)
q4_gen_optimizer_01 = torch.optim.Adam(q4_generator_01.parameters(), lr=0.00015)
q4_discriminator_01 = Q4Discriminator().to(device)
q4_dis_optimizer_01 = torch.optim.Adam(q4_discriminator_01.parameters(), lr=0.00015)
q4_criterion = nn.BCELoss()

lam = 0.1

q4_dis_loss_01, q4_gen_loss_01, q4_real_acc_01, q4_fake_accu_01 = train_q4_model(
    q4_generator_01, 
    q4_discriminator_01, 
    q4_train_loader, 
    q4_criterion, 
    q4_gen_optimizer_01,
    q4_dis_optimizer_01,
    device,
    lam    
)
# Out:
# Epoch [1/100], Dis Loss: 0.1132, Gen Loss: 7.9315, Real Accuracy: 95.74%, Fake Accuracy: 9.31%
# Epoch [2/100], Dis Loss: 0.0257, Gen Loss: 8.3450, Real Accuracy: 98.80%, Fake Accuracy: 1.82%
# Epoch [3/100], Dis Loss: 0.0315, Gen Loss: 9.0395, Real Accuracy: 98.37%, Fake Accuracy: 1.85%
# Epoch [4/100], Dis Loss: 0.0473, Gen Loss: 8.2522, Real Accuracy: 97.52%, Fake Accuracy: 2.57%
# Epoch [5/100], Dis Loss: 0.0466, Gen Loss: 7.1411, Real Accuracy: 97.49%, Fake Accuracy: 2.52%
# Epoch [6/100], Dis Loss: 0.0519, Gen Loss: 6.2988, Real Accuracy: 97.21%, Fake Accuracy: 2.74%
# Epoch [7/100], Dis Loss: 0.0800, Gen Loss: 5.3375, Real Accuracy: 95.64%, Fake Accuracy: 4.34%
# Epoch [8/100], Dis Loss: 0.0955, Gen Loss: 4.6789, Real Accuracy: 94.66%, Fake Accuracy: 5.34%
# Epoch [9/100], Dis Loss: 0.1126, Gen Loss: 4.2327, Real Accuracy: 93.76%, Fake Accuracy: 6.33%
# Epoch [10/100], Dis Loss: 0.1450, Gen Loss: 3.5657, Real Accuracy: 91.79%, Fake Accuracy: 8.26%
# Epoch [11/100], Dis Loss: 0.1648, Gen Loss: 3.2632, Real Accuracy: 90.60%, Fake Accuracy: 9.58%
# Epoch [12/100], Dis Loss: 0.1901, Gen Loss: 2.9091, Real Accuracy: 89.08%, Fake Accuracy: 11.10%
# Epoch [13/100], Dis Loss: 0.2055, Gen Loss: 2.8050, Real Accuracy: 88.02%, Fake Accuracy: 12.24%
# Epoch [14/100], Dis Loss: 0.2080, Gen Loss: 2.7444, Real Accuracy: 87.81%, Fake Accuracy: 12.27%
# Epoch [15/100], Dis Loss: 0.2328, Gen Loss: 2.6354, Real Accuracy: 86.31%, Fake Accuracy: 13.97%
# Epoch [16/100], Dis Loss: 0.2483, Gen Loss: 2.4993, Real Accuracy: 85.14%, Fake Accuracy: 14.92%
# Epoch [17/100], Dis Loss: 0.2566, Gen Loss: 2.5077, Real Accuracy: 84.57%, Fake Accuracy: 15.64%
# Epoch [18/100], Dis Loss: 0.2678, Gen Loss: 2.3676, Real Accuracy: 83.76%, Fake Accuracy: 16.40%
# Epoch [19/100], Dis Loss: 0.2990, Gen Loss: 2.2556, Real Accuracy: 81.63%, Fake Accuracy: 18.50%
# Epoch [20/100], Dis Loss: 0.3218, Gen Loss: 2.1344, Real Accuracy: 79.97%, Fake Accuracy: 20.24%
# Epoch [21/100], Dis Loss: 0.3394, Gen Loss: 2.0751, Real Accuracy: 78.77%, Fake Accuracy: 21.37%
# Epoch [22/100], Dis Loss: 0.3696, Gen Loss: 1.9058, Real Accuracy: 76.50%, Fake Accuracy: 23.63%
# Epoch [23/100], Dis Loss: 0.3888, Gen Loss: 1.8736, Real Accuracy: 74.97%, Fake Accuracy: 24.94%
# Epoch [24/100], Dis Loss: 0.4023, Gen Loss: 1.8057, Real Accuracy: 74.13%, Fake Accuracy: 26.00%
# Epoch [25/100], Dis Loss: 0.4175, Gen Loss: 1.7472, Real Accuracy: 72.92%, Fake Accuracy: 27.22%
# Epoch [26/100], Dis Loss: 0.4244, Gen Loss: 1.7008, Real Accuracy: 72.40%, Fake Accuracy: 27.60%
# Epoch [27/100], Dis Loss: 0.4390, Gen Loss: 1.6593, Real Accuracy: 71.32%, Fake Accuracy: 28.82%
# Epoch [28/100], Dis Loss: 0.4491, Gen Loss: 1.6216, Real Accuracy: 70.51%, Fake Accuracy: 29.57%
# Epoch [29/100], Dis Loss: 0.4621, Gen Loss: 1.5556, Real Accuracy: 69.57%, Fake Accuracy: 30.55%
# Epoch [30/100], Dis Loss: 0.4698, Gen Loss: 1.5291, Real Accuracy: 68.91%, Fake Accuracy: 31.05%
# Epoch [31/100], Dis Loss: 0.4799, Gen Loss: 1.4938, Real Accuracy: 68.27%, Fake Accuracy: 31.92%
# Epoch [32/100], Dis Loss: 0.4899, Gen Loss: 1.4581, Real Accuracy: 67.40%, Fake Accuracy: 32.62%
# Epoch [33/100], Dis Loss: 0.4976, Gen Loss: 1.4228, Real Accuracy: 66.86%, Fake Accuracy: 33.29%
# Epoch [34/100], Dis Loss: 0.5015, Gen Loss: 1.4138, Real Accuracy: 66.50%, Fake Accuracy: 33.48%
# Epoch [35/100], Dis Loss: 0.5092, Gen Loss: 1.3937, Real Accuracy: 65.92%, Fake Accuracy: 34.10%
# Epoch [36/100], Dis Loss: 0.5132, Gen Loss: 1.3624, Real Accuracy: 65.55%, Fake Accuracy: 34.46%
# Epoch [37/100], Dis Loss: 0.5177, Gen Loss: 1.3423, Real Accuracy: 65.32%, Fake Accuracy: 34.89%
# Epoch [38/100], Dis Loss: 0.5213, Gen Loss: 1.3384, Real Accuracy: 64.97%, Fake Accuracy: 35.06%
# Epoch [39/100], Dis Loss: 0.5262, Gen Loss: 1.3151, Real Accuracy: 64.57%, Fake Accuracy: 35.53%
# Epoch [40/100], Dis Loss: 0.5267, Gen Loss: 1.3289, Real Accuracy: 64.55%, Fake Accuracy: 35.54%
# Epoch [41/100], Dis Loss: 0.5319, Gen Loss: 1.3035, Real Accuracy: 64.13%, Fake Accuracy: 35.94%
# Epoch [42/100], Dis Loss: 0.5383, Gen Loss: 1.2752, Real Accuracy: 63.65%, Fake Accuracy: 36.50%
# Epoch [43/100], Dis Loss: 0.5410, Gen Loss: 1.2708, Real Accuracy: 63.37%, Fake Accuracy: 36.66%
# Epoch [44/100], Dis Loss: 0.5424, Gen Loss: 1.2653, Real Accuracy: 63.28%, Fake Accuracy: 36.74%
# Epoch [45/100], Dis Loss: 0.5453, Gen Loss: 1.2476, Real Accuracy: 62.98%, Fake Accuracy: 37.07%
# Epoch [46/100], Dis Loss: 0.5519, Gen Loss: 1.2264, Real Accuracy: 62.51%, Fake Accuracy: 37.50%
# Epoch [47/100], Dis Loss: 0.5518, Gen Loss: 1.2144, Real Accuracy: 62.46%, Fake Accuracy: 37.71%
# Epoch [48/100], Dis Loss: 0.5548, Gen Loss: 1.2199, Real Accuracy: 62.27%, Fake Accuracy: 37.73%
# Epoch [49/100], Dis Loss: 0.5615, Gen Loss: 1.1871, Real Accuracy: 61.77%, Fake Accuracy: 38.34%
# Epoch [50/100], Dis Loss: 0.5595, Gen Loss: 1.2013, Real Accuracy: 61.88%, Fake Accuracy: 38.13%
# Epoch [51/100], Dis Loss: 0.5619, Gen Loss: 1.1891, Real Accuracy: 61.70%, Fake Accuracy: 38.44%
# Epoch [52/100], Dis Loss: 0.5624, Gen Loss: 1.1810, Real Accuracy: 61.63%, Fake Accuracy: 38.38%
# Epoch [53/100], Dis Loss: 0.5655, Gen Loss: 1.1755, Real Accuracy: 61.42%, Fake Accuracy: 38.60%
# Epoch [54/100], Dis Loss: 0.5687, Gen Loss: 1.1575, Real Accuracy: 61.10%, Fake Accuracy: 38.93%
# Epoch [55/100], Dis Loss: 0.5724, Gen Loss: 1.1424, Real Accuracy: 60.76%, Fake Accuracy: 39.29%
# Epoch [56/100], Dis Loss: 0.5742, Gen Loss: 1.1395, Real Accuracy: 60.72%, Fake Accuracy: 39.40%
# Epoch [57/100], Dis Loss: 0.5741, Gen Loss: 1.1395, Real Accuracy: 60.73%, Fake Accuracy: 39.42%
# Epoch [58/100], Dis Loss: 0.5721, Gen Loss: 1.1494, Real Accuracy: 60.78%, Fake Accuracy: 39.17%
# Epoch [59/100], Dis Loss: 0.5738, Gen Loss: 1.1358, Real Accuracy: 60.68%, Fake Accuracy: 39.44%
# Epoch [60/100], Dis Loss: 0.5757, Gen Loss: 1.1265, Real Accuracy: 60.47%, Fake Accuracy: 39.51%
# Epoch [61/100], Dis Loss: 0.5815, Gen Loss: 1.1098, Real Accuracy: 60.07%, Fake Accuracy: 39.97%
# Epoch [62/100], Dis Loss: 0.5781, Gen Loss: 1.1212, Real Accuracy: 60.26%, Fake Accuracy: 39.73%
# Epoch [63/100], Dis Loss: 0.5771, Gen Loss: 1.1322, Real Accuracy: 60.47%, Fake Accuracy: 39.59%
# Epoch [64/100], Dis Loss: 0.5797, Gen Loss: 1.1220, Real Accuracy: 60.23%, Fake Accuracy: 39.91%
# Epoch [65/100], Dis Loss: 0.5785, Gen Loss: 1.1222, Real Accuracy: 60.29%, Fake Accuracy: 39.73%
# Epoch [66/100], Dis Loss: 0.5799, Gen Loss: 1.1089, Real Accuracy: 60.13%, Fake Accuracy: 39.93%
# Epoch [67/100], Dis Loss: 0.5822, Gen Loss: 1.1058, Real Accuracy: 59.96%, Fake Accuracy: 40.08%
# Epoch [68/100], Dis Loss: 0.5797, Gen Loss: 1.1123, Real Accuracy: 60.13%, Fake Accuracy: 39.82%
# Epoch [69/100], Dis Loss: 0.5806, Gen Loss: 1.1025, Real Accuracy: 60.13%, Fake Accuracy: 40.00%
# Epoch [70/100], Dis Loss: 0.5820, Gen Loss: 1.1098, Real Accuracy: 60.04%, Fake Accuracy: 40.04%
# Epoch [71/100], Dis Loss: 0.5841, Gen Loss: 1.0986, Real Accuracy: 59.80%, Fake Accuracy: 40.23%
# Epoch [72/100], Dis Loss: 0.5843, Gen Loss: 1.0957, Real Accuracy: 59.68%, Fake Accuracy: 40.17%
# Epoch [73/100], Dis Loss: 0.5795, Gen Loss: 1.1149, Real Accuracy: 60.25%, Fake Accuracy: 39.91%
# Epoch [74/100], Dis Loss: 0.5815, Gen Loss: 1.1032, Real Accuracy: 60.00%, Fake Accuracy: 39.97%
# Epoch [75/100], Dis Loss: 0.5836, Gen Loss: 1.0987, Real Accuracy: 59.86%, Fake Accuracy: 40.20%
# Epoch [76/100], Dis Loss: 0.5862, Gen Loss: 1.0930, Real Accuracy: 59.64%, Fake Accuracy: 40.38%
# Epoch [77/100], Dis Loss: 0.5838, Gen Loss: 1.0931, Real Accuracy: 59.81%, Fake Accuracy: 40.22%
# Epoch [78/100], Dis Loss: 0.5818, Gen Loss: 1.1076, Real Accuracy: 59.94%, Fake Accuracy: 39.97%
# Epoch [79/100], Dis Loss: 0.5804, Gen Loss: 1.1096, Real Accuracy: 60.19%, Fake Accuracy: 40.01%
# Epoch [80/100], Dis Loss: 0.5871, Gen Loss: 1.0918, Real Accuracy: 59.58%, Fake Accuracy: 40.45%
# Epoch [81/100], Dis Loss: 0.5861, Gen Loss: 1.0833, Real Accuracy: 59.66%, Fake Accuracy: 40.51%
# Epoch [82/100], Dis Loss: 0.5862, Gen Loss: 1.0889, Real Accuracy: 59.58%, Fake Accuracy: 40.37%
# Epoch [83/100], Dis Loss: 0.5845, Gen Loss: 1.0802, Real Accuracy: 59.79%, Fake Accuracy: 40.46%
# Epoch [84/100], Dis Loss: 0.5825, Gen Loss: 1.1030, Real Accuracy: 59.92%, Fake Accuracy: 40.02%
# Epoch [85/100], Dis Loss: 0.5857, Gen Loss: 1.0848, Real Accuracy: 59.67%, Fake Accuracy: 40.41%
# Epoch [86/100], Dis Loss: 0.5831, Gen Loss: 1.0993, Real Accuracy: 59.82%, Fake Accuracy: 40.06%
# Epoch [87/100], Dis Loss: 0.5863, Gen Loss: 1.0795, Real Accuracy: 59.63%, Fake Accuracy: 40.53%
# Epoch [88/100], Dis Loss: 0.5866, Gen Loss: 1.0839, Real Accuracy: 59.57%, Fake Accuracy: 40.44%
# Epoch [89/100], Dis Loss: 0.5847, Gen Loss: 1.0868, Real Accuracy: 59.78%, Fake Accuracy: 40.29%
# Epoch [90/100], Dis Loss: 0.5861, Gen Loss: 1.0877, Real Accuracy: 59.51%, Fake Accuracy: 40.36%
# Epoch [91/100], Dis Loss: 0.5848, Gen Loss: 1.0901, Real Accuracy: 59.83%, Fake Accuracy: 40.25%
# Epoch [92/100], Dis Loss: 0.5856, Gen Loss: 1.0808, Real Accuracy: 59.63%, Fake Accuracy: 40.38%
# Epoch [93/100], Dis Loss: 0.5829, Gen Loss: 1.0905, Real Accuracy: 59.94%, Fake Accuracy: 40.17%
# Epoch [94/100], Dis Loss: 0.5864, Gen Loss: 1.0797, Real Accuracy: 59.54%, Fake Accuracy: 40.36%
# Epoch [95/100], Dis Loss: 0.5840, Gen Loss: 1.0840, Real Accuracy: 59.79%, Fake Accuracy: 40.26%
# Epoch [96/100], Dis Loss: 0.5845, Gen Loss: 1.0867, Real Accuracy: 59.74%, Fake Accuracy: 40.35%
# Epoch [97/100], Dis Loss: 0.5800, Gen Loss: 1.1086, Real Accuracy: 60.21%, Fake Accuracy: 39.91%
# Epoch [98/100], Dis Loss: 0.5837, Gen Loss: 1.0897, Real Accuracy: 59.75%, Fake Accuracy: 40.19%
# Epoch [99/100], Dis Loss: 0.5847, Gen Loss: 1.0912, Real Accuracy: 59.71%, Fake Accuracy: 40.15%
# Epoch [100/100], Dis Loss: 0.5801, Gen Loss: 1.0967, Real Accuracy: 60.06%, Fake Accuracy: 39.98%

# %%
q4_generator_10 = Q4Generator().to(device)
q4_gen_optimizer_10 = torch.optim.Adam(q4_generator_10.parameters(), lr=0.00015)
q4_discriminator_10 = Q4Discriminator().to(device)
q4_dis_optimizer_10 = torch.optim.Adam(q4_discriminator_10.parameters(), lr=0.00015)

lam = 10

q4_dis_loss_10, q4_gen_loss_10, q4_real_acc_10, q4_fake_accu_10 = train_q4_model(
    q4_generator_10, 
    q4_discriminator_10, 
    q4_train_loader, 
    q4_criterion, 
    q4_gen_optimizer_10,
    q4_dis_optimizer_10,
    device,
    lam    
)
# Out:
# Epoch [1/100], Dis Loss: 0.2164, Gen Loss: 13.6637, Real Accuracy: 90.05%, Fake Accuracy: 15.82%
# Epoch [2/100], Dis Loss: 0.1494, Gen Loss: 9.4539, Real Accuracy: 92.05%, Fake Accuracy: 9.62%
# Epoch [3/100], Dis Loss: 0.1940, Gen Loss: 7.2635, Real Accuracy: 88.46%, Fake Accuracy: 11.57%
# Epoch [4/100], Dis Loss: 0.2611, Gen Loss: 4.9205, Real Accuracy: 83.90%, Fake Accuracy: 15.95%
# Epoch [5/100], Dis Loss: 0.3221, Gen Loss: 3.6946, Real Accuracy: 79.68%, Fake Accuracy: 20.45%
# Epoch [6/100], Dis Loss: 0.3590, Gen Loss: 3.1866, Real Accuracy: 77.16%, Fake Accuracy: 23.14%
# Epoch [7/100], Dis Loss: 0.4183, Gen Loss: 2.6018, Real Accuracy: 72.90%, Fake Accuracy: 27.63%
# Epoch [8/100], Dis Loss: 0.4471, Gen Loss: 2.2861, Real Accuracy: 70.68%, Fake Accuracy: 29.65%
# Epoch [9/100], Dis Loss: 0.4626, Gen Loss: 2.1275, Real Accuracy: 69.54%, Fake Accuracy: 30.77%
# Epoch [10/100], Dis Loss: 0.4779, Gen Loss: 1.9774, Real Accuracy: 68.42%, Fake Accuracy: 32.03%
# Epoch [11/100], Dis Loss: 0.5066, Gen Loss: 1.8016, Real Accuracy: 66.27%, Fake Accuracy: 33.99%
# Epoch [12/100], Dis Loss: 0.5139, Gen Loss: 1.7508, Real Accuracy: 65.70%, Fake Accuracy: 34.71%
# Epoch [13/100], Dis Loss: 0.5396, Gen Loss: 1.6024, Real Accuracy: 63.60%, Fake Accuracy: 36.67%
# Epoch [14/100], Dis Loss: 0.5428, Gen Loss: 1.5619, Real Accuracy: 63.41%, Fake Accuracy: 37.00%
# Epoch [15/100], Dis Loss: 0.5569, Gen Loss: 1.4839, Real Accuracy: 62.15%, Fake Accuracy: 38.11%
# Epoch [16/100], Dis Loss: 0.5582, Gen Loss: 1.4740, Real Accuracy: 62.12%, Fake Accuracy: 38.21%
# Epoch [17/100], Dis Loss: 0.5685, Gen Loss: 1.4349, Real Accuracy: 61.39%, Fake Accuracy: 38.90%
# Epoch [18/100], Dis Loss: 0.5724, Gen Loss: 1.4067, Real Accuracy: 61.14%, Fake Accuracy: 39.34%
# Epoch [19/100], Dis Loss: 0.5546, Gen Loss: 1.4828, Real Accuracy: 62.80%, Fake Accuracy: 38.13%
# Epoch [20/100], Dis Loss: 0.5726, Gen Loss: 1.3825, Real Accuracy: 60.84%, Fake Accuracy: 39.28%
# Epoch [21/100], Dis Loss: 0.5843, Gen Loss: 1.3342, Real Accuracy: 59.97%, Fake Accuracy: 40.23%
# Epoch [22/100], Dis Loss: 0.5733, Gen Loss: 1.3744, Real Accuracy: 61.15%, Fake Accuracy: 39.43%
# Epoch [23/100], Dis Loss: 0.5888, Gen Loss: 1.3054, Real Accuracy: 59.69%, Fake Accuracy: 40.63%
# Epoch [24/100], Dis Loss: 0.5916, Gen Loss: 1.2710, Real Accuracy: 59.20%, Fake Accuracy: 40.77%
# Epoch [25/100], Dis Loss: 0.5935, Gen Loss: 1.2644, Real Accuracy: 59.16%, Fake Accuracy: 41.07%
# Epoch [26/100], Dis Loss: 0.6084, Gen Loss: 1.2450, Real Accuracy: 58.12%, Fake Accuracy: 42.12%
# Epoch [27/100], Dis Loss: 0.5967, Gen Loss: 1.2854, Real Accuracy: 58.95%, Fake Accuracy: 41.20%
# Epoch [28/100], Dis Loss: 0.5926, Gen Loss: 1.2577, Real Accuracy: 59.14%, Fake Accuracy: 41.05%
# Epoch [29/100], Dis Loss: 0.6062, Gen Loss: 1.2427, Real Accuracy: 58.31%, Fake Accuracy: 41.95%
# Epoch [30/100], Dis Loss: 0.5982, Gen Loss: 1.2366, Real Accuracy: 58.75%, Fake Accuracy: 41.48%
# Epoch [31/100], Dis Loss: 0.6008, Gen Loss: 1.2147, Real Accuracy: 58.36%, Fake Accuracy: 41.67%
# Epoch [32/100], Dis Loss: 0.6056, Gen Loss: 1.2578, Real Accuracy: 58.66%, Fake Accuracy: 41.95%
# Epoch [33/100], Dis Loss: 0.6017, Gen Loss: 1.2168, Real Accuracy: 58.34%, Fake Accuracy: 41.77%
# Epoch [34/100], Dis Loss: 0.6159, Gen Loss: 1.1723, Real Accuracy: 57.21%, Fake Accuracy: 42.71%
# Epoch [35/100], Dis Loss: 0.6126, Gen Loss: 1.2318, Real Accuracy: 57.94%, Fake Accuracy: 42.23%
# Epoch [36/100], Dis Loss: 0.6066, Gen Loss: 1.1601, Real Accuracy: 58.07%, Fake Accuracy: 42.67%
# Epoch [37/100], Dis Loss: 0.6155, Gen Loss: 1.1738, Real Accuracy: 57.60%, Fake Accuracy: 43.05%
# Epoch [38/100], Dis Loss: 0.6270, Gen Loss: 1.1300, Real Accuracy: 56.15%, Fake Accuracy: 43.54%
# Epoch [39/100], Dis Loss: 0.6262, Gen Loss: 1.1156, Real Accuracy: 56.36%, Fake Accuracy: 43.73%
# Epoch [40/100], Dis Loss: 0.6242, Gen Loss: 1.1133, Real Accuracy: 56.50%, Fake Accuracy: 43.81%
# Epoch [41/100], Dis Loss: 0.6258, Gen Loss: 1.1675, Real Accuracy: 56.74%, Fake Accuracy: 43.53%
# Epoch [42/100], Dis Loss: 0.6265, Gen Loss: 1.0844, Real Accuracy: 56.16%, Fake Accuracy: 44.11%
# Epoch [43/100], Dis Loss: 0.6323, Gen Loss: 1.1053, Real Accuracy: 55.90%, Fake Accuracy: 44.16%
# Epoch [44/100], Dis Loss: 0.6356, Gen Loss: 1.1022, Real Accuracy: 55.91%, Fake Accuracy: 44.51%
# Epoch [45/100], Dis Loss: 0.6298, Gen Loss: 1.0858, Real Accuracy: 55.97%, Fake Accuracy: 44.29%
# Epoch [46/100], Dis Loss: 0.6374, Gen Loss: 1.0702, Real Accuracy: 55.32%, Fake Accuracy: 44.72%
# Epoch [47/100], Dis Loss: 0.6259, Gen Loss: 1.1150, Real Accuracy: 56.41%, Fake Accuracy: 43.69%
# Epoch [48/100], Dis Loss: 0.6305, Gen Loss: 1.0851, Real Accuracy: 55.99%, Fake Accuracy: 44.31%
# Epoch [49/100], Dis Loss: 0.6354, Gen Loss: 1.0776, Real Accuracy: 55.64%, Fake Accuracy: 44.78%
# Epoch [50/100], Dis Loss: 0.6358, Gen Loss: 1.0887, Real Accuracy: 55.87%, Fake Accuracy: 44.63%
# Epoch [51/100], Dis Loss: 0.6301, Gen Loss: 1.0779, Real Accuracy: 55.99%, Fake Accuracy: 44.23%
# Epoch [52/100], Dis Loss: 0.6389, Gen Loss: 1.0565, Real Accuracy: 55.50%, Fake Accuracy: 45.11%
# Epoch [53/100], Dis Loss: 0.6312, Gen Loss: 1.0708, Real Accuracy: 55.95%, Fake Accuracy: 44.50%
# Epoch [54/100], Dis Loss: 0.6360, Gen Loss: 1.0741, Real Accuracy: 55.79%, Fake Accuracy: 44.76%
# Epoch [55/100], Dis Loss: 0.6401, Gen Loss: 1.0472, Real Accuracy: 55.15%, Fake Accuracy: 45.21%
# Epoch [56/100], Dis Loss: 0.6312, Gen Loss: 1.0831, Real Accuracy: 56.06%, Fake Accuracy: 44.13%
# Epoch [57/100], Dis Loss: 0.6307, Gen Loss: 1.0585, Real Accuracy: 55.99%, Fake Accuracy: 44.53%
# Epoch [58/100], Dis Loss: 0.6361, Gen Loss: 1.0548, Real Accuracy: 55.43%, Fake Accuracy: 44.68%
# Epoch [59/100], Dis Loss: 0.6491, Gen Loss: 1.0043, Real Accuracy: 54.28%, Fake Accuracy: 45.94%
# Epoch [60/100], Dis Loss: 0.6485, Gen Loss: 1.0111, Real Accuracy: 54.60%, Fake Accuracy: 45.73%
# Epoch [61/100], Dis Loss: 0.6297, Gen Loss: 1.0576, Real Accuracy: 56.69%, Fake Accuracy: 44.76%
# Epoch [62/100], Dis Loss: 0.6381, Gen Loss: 1.0271, Real Accuracy: 55.36%, Fake Accuracy: 45.20%
# Epoch [63/100], Dis Loss: 0.6393, Gen Loss: 1.0256, Real Accuracy: 55.57%, Fake Accuracy: 45.28%
# Epoch [64/100], Dis Loss: 0.6407, Gen Loss: 1.0024, Real Accuracy: 55.00%, Fake Accuracy: 45.34%
# Epoch [65/100], Dis Loss: 0.6518, Gen Loss: 0.9824, Real Accuracy: 53.94%, Fake Accuracy: 46.07%
# Epoch [66/100], Dis Loss: 0.6323, Gen Loss: 1.0309, Real Accuracy: 56.58%, Fake Accuracy: 44.89%
# Epoch [67/100], Dis Loss: 0.6386, Gen Loss: 0.9958, Real Accuracy: 55.37%, Fake Accuracy: 45.35%
# Epoch [68/100], Dis Loss: 0.6439, Gen Loss: 0.9968, Real Accuracy: 54.66%, Fake Accuracy: 45.39%
# Epoch [69/100], Dis Loss: 0.6500, Gen Loss: 0.9778, Real Accuracy: 54.16%, Fake Accuracy: 45.98%
# Epoch [70/100], Dis Loss: 0.6531, Gen Loss: 0.9668, Real Accuracy: 53.84%, Fake Accuracy: 46.15%
# Epoch [71/100], Dis Loss: 0.6542, Gen Loss: 0.9651, Real Accuracy: 53.69%, Fake Accuracy: 46.26%
# Epoch [72/100], Dis Loss: 0.6563, Gen Loss: 0.9543, Real Accuracy: 53.46%, Fake Accuracy: 46.47%
# Epoch [73/100], Dis Loss: 0.6591, Gen Loss: 0.9525, Real Accuracy: 53.28%, Fake Accuracy: 46.54%
# Epoch [74/100], Dis Loss: 0.6606, Gen Loss: 0.9412, Real Accuracy: 53.09%, Fake Accuracy: 46.81%
# Epoch [75/100], Dis Loss: 0.6613, Gen Loss: 0.9482, Real Accuracy: 52.98%, Fake Accuracy: 46.61%
# Epoch [76/100], Dis Loss: 0.6527, Gen Loss: 0.9416, Real Accuracy: 53.95%, Fake Accuracy: 46.32%
# Epoch [77/100], Dis Loss: 0.6620, Gen Loss: 0.9300, Real Accuracy: 53.00%, Fake Accuracy: 46.99%
# Epoch [78/100], Dis Loss: 0.6605, Gen Loss: 0.9376, Real Accuracy: 53.07%, Fake Accuracy: 46.75%
# Epoch [79/100], Dis Loss: 0.6598, Gen Loss: 0.9387, Real Accuracy: 53.30%, Fake Accuracy: 46.80%
# Epoch [80/100], Dis Loss: 0.6573, Gen Loss: 0.9441, Real Accuracy: 53.27%, Fake Accuracy: 46.45%
# Epoch [81/100], Dis Loss: 0.6610, Gen Loss: 0.9349, Real Accuracy: 52.85%, Fake Accuracy: 46.70%
# Epoch [82/100], Dis Loss: 0.6551, Gen Loss: 0.9490, Real Accuracy: 53.58%, Fake Accuracy: 46.29%
# Epoch [83/100], Dis Loss: 0.6588, Gen Loss: 0.9362, Real Accuracy: 53.23%, Fake Accuracy: 46.68%
# Epoch [84/100], Dis Loss: 0.6602, Gen Loss: 0.9374, Real Accuracy: 53.07%, Fake Accuracy: 46.71%
# Epoch [85/100], Dis Loss: 0.6575, Gen Loss: 0.9338, Real Accuracy: 53.41%, Fake Accuracy: 46.62%
# Epoch [86/100], Dis Loss: 0.6553, Gen Loss: 0.9532, Real Accuracy: 53.36%, Fake Accuracy: 46.12%
# Epoch [87/100], Dis Loss: 0.6541, Gen Loss: 0.9493, Real Accuracy: 53.79%, Fake Accuracy: 46.37%
# Epoch [88/100], Dis Loss: 0.6583, Gen Loss: 0.9396, Real Accuracy: 53.14%, Fake Accuracy: 46.50%
# Epoch [89/100], Dis Loss: 0.6571, Gen Loss: 0.9394, Real Accuracy: 53.44%, Fake Accuracy: 46.55%
# Epoch [90/100], Dis Loss: 0.6579, Gen Loss: 0.9339, Real Accuracy: 53.37%, Fake Accuracy: 46.67%
# Epoch [91/100], Dis Loss: 0.6589, Gen Loss: 0.9319, Real Accuracy: 53.14%, Fake Accuracy: 46.61%
# Epoch [92/100], Dis Loss: 0.6586, Gen Loss: 0.9343, Real Accuracy: 53.35%, Fake Accuracy: 46.70%
# Epoch [93/100], Dis Loss: 0.6593, Gen Loss: 0.9289, Real Accuracy: 53.04%, Fake Accuracy: 46.59%
# Epoch [94/100], Dis Loss: 0.6598, Gen Loss: 0.9274, Real Accuracy: 53.01%, Fake Accuracy: 46.60%
# Epoch [95/100], Dis Loss: 0.6629, Gen Loss: 0.9177, Real Accuracy: 52.87%, Fake Accuracy: 47.05%
# Epoch [96/100], Dis Loss: 0.6577, Gen Loss: 0.9271, Real Accuracy: 53.36%, Fake Accuracy: 46.68%
# Epoch [97/100], Dis Loss: 0.6612, Gen Loss: 0.9229, Real Accuracy: 52.97%, Fake Accuracy: 46.86%
# Epoch [98/100], Dis Loss: 0.6584, Gen Loss: 0.9319, Real Accuracy: 53.22%, Fake Accuracy: 46.59%
# Epoch [99/100], Dis Loss: 0.6599, Gen Loss: 0.9210, Real Accuracy: 53.15%, Fake Accuracy: 46.84%
# Epoch [100/100], Dis Loss: 0.6564, Gen Loss: 0.9329, Real Accuracy: 53.40%, Fake Accuracy: 46.42%

# %%
# Generate random input
random_vector = torch.randn(100, 100).to(device)

# Use the sample_by_class function to get 10 images per digit
class_samples = sample_by_class(q4_test_loader, sample_size=10)

# Create an ordered list of images
real_imgs = []
for digit in range(10):  # 0 to 9
    real_imgs.extend([sample[0] for sample in class_samples[digit]])

# Convert to tensor and move to device
real_imgs = torch.stack(real_imgs).to(device)

# Extract center patches as condition
center_patches = real_imgs.view(100, 1, 28, 28)
center_patches = center_patches[:, :, 9:19, 9:19].reshape(100, -1)

# Concatenate random input with condition
gen_input = torch.cat((random_vector, center_patches), dim=1)

# %%
# Generate fake images with q4_generator_01
q4_generator_01.eval()
with torch.no_grad():
    q4_fake_images_01 = q4_generator_01(gen_input)
q4_fake_images_01 = q4_fake_images_01.cpu().numpy()

# %%
plt.figure(figsize=(10, 8))
plt.suptitle("Generated Images using lambda=0.1")
for i in range(100):
    plt.subplot(10, 10, i+1)
    plt.imshow(q4_fake_images_01[i].reshape(28, 28), cmap='gray')
    plt.axis('off')
plt.show()

# %%
# Generate fake images with q4_generator_10
q4_generator_10.eval()
with torch.no_grad():
    q4_fake_images_10 = q4_generator_10(gen_input)
q4_fake_images_10 = q4_fake_images_10.cpu().numpy()

# %%
plt.figure(figsize=(10, 8))
plt.suptitle("Generated Images using lambda=10")
for i in range(100):
    plt.subplot(10, 10, i+1)
    plt.imshow(q4_fake_images_10[i].reshape(28, 28), cmap='gray')
    plt.axis('off')
plt.show()
